# %%
from sklearn.neighbors.kde import KernelDensity
import scipy.stats as stats

# %%
f = lambda x: KernelDensity(kernel='gaussian').fit(np.random.randn(x))
kd1 = f(100)
kd2 = f(100)

# %%
n = 100
vals = [np.random.randn(n),
        np.random.randn(n)]

kde2d = stats.gaussian_kde(vals, bw_method=0.001)

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import load_digits
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.grid_search import GridSearchCV

# creating data
n = 100
frag_GC_len = np.array([np.random.normal(loc=50, scale=5, size=n),
                       np.random.normal(loc=9000, scale=500, size=n)])



# project the 64-dimensional data to a lower dimension
#pca = PCA(n_components=15, whiten=False)
#data = pca.fit_transform(frag_GC_len)

# use grid search cross-validation to optimize the bandwidth
#params = {'bandwidth': np.logspace(-10, 1, 20)}
#grid = GridSearchCV(KernelDensity(), params)
#grid.fit(data)

kde2d = KernelDensity(kernel='gaussian').fit(frag_GC_len)

# %%
kde2d.sample()
# Out:
# array([[  9219.8219628 ,   9151.0201936 ,   8812.90722086,   8967.36285039,
#           9029.82688696,   8951.53023345,   8588.27464719,   9047.71158239,
#           9793.34616576,   8894.63970582,   8697.24330903,   9232.81071165,
#           9846.74119575,   9219.44331398,   9153.70144306,   7924.31976878,
#           8123.05361622,   8673.99254927,   8644.34200164,   8438.56743974,
#          10031.73251997,   7774.35357438,   8730.65662231,   7741.59780738,
#           9495.10110994,   9177.98577903,   9030.77938994,   9809.90060109,
#           8123.04697428,   9112.19480726,   9529.2481136 ,   8791.09946756,
#           9315.70593057,   9231.93646796,   7977.67312384,   9244.10022767,
#           8923.83520431,   8979.63106527,   8734.53644146,   9237.50428527,
#           9758.64080818,   8910.20188941,   9044.01222208,   9655.29678541,
#           8705.83425374,   8841.2645952 ,   8951.19269076,   9314.62430433,
#           9206.04119007,   8681.26352146,   8817.3978402 ,   9330.89943528,
#           9296.11927806,   8672.37752839,   8374.94801092,   9077.38960594,
#           9404.07396403,   8857.5129553 ,   8880.56401069,   9415.9385786 ,
#           8998.00147269,   8444.38250238,   8461.23420117,   9625.47298891,
#           8474.23452314,   9079.0240809 ,   8680.76377737,   8700.85912272,
#           8432.61017689,   8338.52929071,   9056.08973161,   8715.22146546,
#           7926.25893577,   8655.34166053,   9781.69360748,   8893.1535596 ,
#           9016.32131853,   7980.76754354,   9867.27059314,   9114.38762971,
#           8212.19120814,   8966.49678734,   9622.15283056,   8793.88639896,
#           8762.40763847,   9303.54478623,   8847.54476343,   9220.07858838,
#           9194.69326094,   9297.65363307,   9547.45783764,   8753.0101757 ,
#           9218.41115836,   9677.51088176,   9320.88084009,   9149.3874263 ,
#           8698.67483192,   9031.37321775,   8393.2585986 ,   9100.86296066]])

# %%
KernelDensity(kernel='gaussian').fit(vals)
# Out:
# KernelDensity(algorithm='auto', atol=0, bandwidth=1.0, breadth_first=True,
#        kernel='gaussian', leaf_size=40, metric='euclidean',
#        metric_params=None, rtol=0)

# %%
data = digits.data
data
# Out:
# array([[  0.,   0.,   5., ...,   0.,   0.,   0.],
#        [  0.,   0.,   0., ...,  10.,   0.,   0.],
#        [  0.,   0.,   0., ...,  16.,   9.,   0.],
#        ...,
#        [  0.,   0.,   1., ...,   6.,   0.,   0.],
#        [  0.,   0.,   2., ...,  12.,   0.,   0.],
#        [  0.,   0.,  10., ...,  12.,   1.,   0.]])

# %%
frag_GC_len
# Out:
# array([[    50.55608418,     50.52723638,     43.71238668,     40.41632553,
#             52.1306761 ,     58.24285729,     50.11516611,     53.19719617,
#             47.59547027,     42.34772784,     51.19789921,     57.62119259,
#             49.92206766,     55.92559973,     47.46128667,     44.076775  ,
#             49.16762267,     58.40742059,     55.87324279,     44.17827519,
#             49.15130547,     57.19270522,     43.69718779,     50.30005721,
#             49.14768148,     50.26177961,     45.24521856,     49.99488105,
#             42.46889286,     55.66178844,     54.80107813,     46.07042142,
#             47.52189225,     47.02730042,     45.16429433,     54.49268501,
#             40.80279089,     43.64538545,     47.97089911,     54.03608793,
#             55.65723441,     45.80385467,     49.13607257,     56.32935241,
#             52.23678365,     44.70754368,     44.32681503,     50.53768594,
#             51.1702634 ,     46.90230163,     59.46634643,     45.13552415,
#             44.71986038,     51.05816776,     53.88780922,     59.87426372,
#             53.62868215,     42.82708918,     45.75442012,     39.50583879,
#             51.07279571,     51.64186598,     45.98403031,     45.71270867,
#             56.12249888,     52.75615422,     57.35789215,     45.05989032,
#             44.96914738,     50.74403002,     60.32716985,     38.63692763,
#             51.75908442,     47.26717824,     48.98403185,     44.44529403,
#             54.87320687,     50.23139408,     46.29742727,     37.98730482,
#             45.85212443,     51.54022719,     50.41702971,     48.73849846,
#             47.87017183,     42.99478585,     43.06564248,     51.69222351,
#             50.27632892,     50.34167526,     51.67163106,     56.39852821,
#             50.0041413 ,     48.95021677,     49.40772558,     45.56322652,
#             43.85091956,     50.55710015,     57.32879561,     48.27535145],
#        [  7897.73409155,   8728.73162534,   9691.53320423,   8908.07569099,
#           9475.89947782,   9471.89402945,   9121.69230458,   8247.15776668,
#           8300.14617483,   9576.89968375,   8303.66511434,   8586.58212028,
#           8561.23281699,   8826.76277808,   8715.59587636,   8989.50271265,
#           8305.77468697,   8435.26323487,   9952.29249248,   8247.57657118,
#           8851.02696517,   8466.19070389,   9228.05797765,   8491.92122452,
#           9911.0836438 ,   9183.64324824,   8096.24823359,   8880.15288978,
#           9183.53710028,   9532.26910263,   9473.56111669,   9280.42283125,
#           8977.69002228,   8677.31021753,   8510.37398504,   8831.6381197 ,
#           9036.99645696,   9223.33369823,   8113.9818501 ,   9051.80038807,
#           8851.84026342,   8466.38092717,   8151.71145957,   9515.70884737,
#           9532.48877882,   9812.69604589,   9550.13070416,   8330.9484202 ,
#           9974.4384417 ,   9511.51092717,   8803.45766842,   8948.20952305,
#           9068.73079752,   8468.60200722,   9826.43692263,   9157.84858642,
#           8800.05015791,  10137.36416647,   8383.86722835,   9220.98964396,
#           9166.50935454,   9795.43833946,  10400.28061947,   9173.93659048,
#           8928.06244239,   8140.32177451,   8639.32464739,   8855.94826007,
#           8919.72874811,   8978.41442178,   9072.02706215,   8873.83875816,
#           7330.35227853,   8943.36027444,   9236.34426475,   9590.81781384,
#           9805.68823662,   9666.09586293,   9522.47018379,   8546.5919209 ,
#           9415.96367747,   8866.14333793,   8493.59292171,   8164.85343235,
#           9744.9020001 ,   8807.83009313,   8781.74328099,   8425.3236228 ,
#           8932.73673329,   9714.49998915,   8262.59076575,   8668.60400831,
#           9309.52765145,   9170.91906114,  10015.86058933,   9063.81041104,
#           9471.41620711,   9046.55377013,   9507.24958897,   8573.86095685]])
