# %% [markdown]
# # Goal
#
# __Question:__ how is incorporator identification accuracy affected by the percent isotope incorporation of taxa?
#
# * Using genome dataset created in the "dataset" notebook
#
# * Simulates isotope dilution or short incubations
#   * Method
#     * 25% taxa incorporate
#     * incorporation % same for all incorporators
#     * incorporation % treatments: 10, 20, 40, 60, 80, 100%
#     * Total treatments: 6
# * ALSO, testing the use of differing BD ranges on sensitivity/specificity

# %% [markdown]
# # User variables

# %%
workDir = '/home/nick/notebook/SIPSim/dev/bac_genome1210/'
genomeDir = '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/'
R_dir = '/home/nick/notebook/SIPSim/lib/R/'

# %% [markdown]
# # Init

# %%
import glob
import itertools
from os.path import abspath
import nestly

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# library(gridExtra)

# %% [markdown]
# # Using nestly: different incorporation percentages

# %%
# building tree structure
nest = nestly.Nest()

## varying params
### perc incorporation
nest.add('percIncorp', range(0,101,20))
### BD range
BD_min = np.arange(1.67, 1.77, 0.02).tolist()
BD_max = [x + 0.04 for x in BD_min]
f = lambda x: {'BD_range': str(x[0]) + '-' + str(x[1]), 
               'BD_min':x[0], 
               'BD_max':x[1]}
BD_range = [f(x) for x in itertools.product(BD_min, BD_max) 
            if x[0] < x[1]]
#### contains BD_min & BD_max
nest.add('BD_range', BD_range, update=True)

## set params
nest.add('padj', [0.1], create_dir=False)
nest.add('log2', [0.25], create_dir=False)
nest.add('topTaxaToPlot', [100], create_dir=False)

## input/output files
#nest.add('fileName', ['ampFrags'], create_dir=False)
nest.add('perc_incorp_dir', ['/home/nick/notebook/SIPSim/dev/bac_genome1210/percIncorpUnif/'], create_dir=False)
nest.add('otu_file', ['OTU_n2_abs1e10_sub20000_w.txt'], create_dir=False)
nest.add('otu_metadata', ['OTU_n2_abs1e10_sub20000_meta.txt'], create_dir=False)
nest.add('BD_shift', ['ampFrags_kde_dif_incorp_BD-shift.txt'], create_dir=False)
nest.add('R_dir', [R_dir], create_dir=False)

# building directory tree
buildDir = os.path.join(workDir, 'percIncorpUnif_difBD')
nest.build(buildDir)

# %%
bashFile = os.path.join(workDir, 'SIPSimRun.sh')

# %%
# %%writefile $bashFile
# #!/bin/bash
#
# # copying files from perc_incorp_unif
# cp {perc_incorp_dir}{percIncorp}/{otu_file} .
# cp {perc_incorp_dir}{percIncorp}/{otu_metadata} .
# cp {perc_incorp_dir}{percIncorp}/{BD_shift} .
#
# #-- R analysis --#
# export PATH={R_dir}:$PATH
# # running DeSeq2 and making confusion matrix on predicting incorporators
# ## making phyloseq object from OTU table
# phyloseq_make.r \
#     {otu_file} \
#     -s {otu_metadata} \
#     > {otu_file}.physeq
#
# ## filtering phyloseq object to just taxa/samples of interest
# phyloseq_edit.r \
#     {otu_file}.physeq \
#     --BD_min {BD_min} --BD_max {BD_max} \
#     > {otu_file}_filt.physeq
# ## making ordination
# phyloseq_ordination.r \
#     {otu_file}_filt.physeq \
#     {otu_file}_bray-NMDS.pdf
# ## DESeq2
# phyloseq_DESeq2.r \
#     {otu_file}_filt.physeq \
#     > {otu_file}_DESeq2
# ## Confusion matrix
# DESeq2_confuseMtx.r \
#     {BD_shift} \
#     {otu_file}_DESeq2 \
#     --padj {padj} --log2 {log2}
# Out:
# Overwriting /home/nick/notebook/SIPSim/dev/bac_genome1210/SIPSimRun.sh

# %%
# !chmod 775 $bashFile

# %%
# !cd $workDir; \
    nestrun -j 30 --template-file $bashFile -d percIncorpUnif_difBD --log-file log.txt
# Out:
# 2015-07-14 13:21:57,364 * INFO * Template: ./SIPSimRun.sh
# 2015-07-14 13:21:57,366 * INFO * [153984] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.67-1.79
# 2015-07-14 13:21:57,368 * INFO * [153985] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.73-1.77
# 2015-07-14 13:21:57,370 * INFO * [153987] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.69-1.77
# 2015-07-14 13:21:57,371 * INFO * [153991] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.71-1.75
# 2015-07-14 13:21:57,373 * INFO * [153995] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.75-1.81
# 2015-07-14 13:21:57,374 * INFO * [153999] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.71-1.73
# 2015-07-14 13:21:57,376 * INFO * [154004] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.73-1.79
# 2015-07-14 13:21:57,378 * INFO * [154011] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.69-1.71
# 2015-07-14 13:21:57,380 * INFO * [154022] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.77-1.81
# 2015-07-14 13:21:57,383 * INFO * [154028] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.69-1.73
# 2015-07-14 13:21:57,385 * INFO * [154039] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.69-1.79
# 2015-07-14 13:21:57,386 * INFO * [154054] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.67-1.77
# 2015-07-14 13:21:57,389 * INFO * [154069] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.75-1.79
# 2015-07-14 13:21:57,392 * INFO * [154083] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.69-1.75
# 2015-07-14 13:21:57,396 * INFO * [154105] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.67-1.75
# 2015-07-14 13:21:57,398 * INFO * [154109] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.75-1.77
# 2015-07-14 13:21:57,399 * INFO * [154118] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.67-1.81
# 2015-07-14 13:21:57,401 * INFO * [154125] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.73-1.75
# 2015-07-14 13:21:57,404 * INFO * [154136] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.71-1.77
# 2015-07-14 13:21:57,406 * INFO * [154140] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.69-1.81
# 2015-07-14 13:21:57,408 * INFO * [154154] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.67-1.71
# 2015-07-14 13:21:57,410 * INFO * [154163] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.73-1.81
# 2015-07-14 13:21:57,411 * INFO * [154168] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.71-1.81
# 2015-07-14 13:21:57,412 * INFO * [154180] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.71-1.79
# 2015-07-14 13:21:57,414 * INFO * [154194] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.67-1.73
# 2015-07-14 13:21:57,416 * INFO * [154201] Started ./SIPSimRun.sh in percIncorpUnif_difBD/80/1.77-1.79
# 2015-07-14 13:21:57,418 * INFO * [154210] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.67-1.79
# 2015-07-14 13:21:57,420 * INFO * [154223] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.73-1.77
# 2015-07-14 13:21:57,422 * INFO * [154234] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.69-1.77
# 2015-07-14 13:21:57,424 * INFO * [154243] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.71-1.75
# 2015-07-14 13:23:13,850 * INFO * [154125] percIncorpUnif_difBD/80/1.73-1.75 Finished with 0
# 2015-07-14 13:23:13,853 * INFO * [156060] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.75-1.81
# 2015-07-14 13:23:14,355 * INFO * [154163] percIncorpUnif_difBD/80/1.73-1.81 Finished with 0
# 2015-07-14 13:23:14,357 * INFO * [156082] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.71-1.73
# 2015-07-14 13:23:17,757 * INFO * [153991] percIncorpUnif_difBD/80/1.71-1.75 Finished with 0
# 2015-07-14 13:23:17,760 * INFO * [156202] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.73-1.79
# 2015-07-14 13:23:18,890 * INFO * [154234] percIncorpUnif_difBD/20/1.69-1.77 Finished with 0
# 2015-07-14 13:23:18,892 * INFO * [156236] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.69-1.71
# 2015-07-14 13:23:19,961 * INFO * [154028] percIncorpUnif_difBD/80/1.69-1.73 Finished with 0
# 2015-07-14 13:23:19,964 * INFO * [156263] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.77-1.81
# 2015-07-14 13:23:20,046 * INFO * [154180] percIncorpUnif_difBD/80/1.71-1.79 Finished with 0
# 2015-07-14 13:23:20,049 * INFO * [156278] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.69-1.73
# 2015-07-14 13:23:20,905 * INFO * [153987] percIncorpUnif_difBD/80/1.69-1.77 Finished with 0
# 2015-07-14 13:23:20,908 * INFO * [156296] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.69-1.79
# 2015-07-14 13:23:21,726 * INFO * [154194] percIncorpUnif_difBD/80/1.67-1.73 Finished with 0
# 2015-07-14 13:23:21,728 * INFO * [156314] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.67-1.77
# 2015-07-14 13:23:21,962 * INFO * [154243] percIncorpUnif_difBD/20/1.71-1.75 Finished with 0
# 2015-07-14 13:23:21,966 * INFO * [156326] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.75-1.79
# 2015-07-14 13:23:22,271 * INFO * [153985] percIncorpUnif_difBD/80/1.73-1.77 Finished with 0
# 2015-07-14 13:23:22,274 * INFO * [156338] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.69-1.75
# 2015-07-14 13:23:22,473 * INFO * [154004] percIncorpUnif_difBD/80/1.73-1.79 Finished with 0
# 2015-07-14 13:23:22,476 * INFO * [156356] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.67-1.75
# 2015-07-14 13:23:23,662 * INFO * [154069] percIncorpUnif_difBD/80/1.75-1.79 Finished with 0
# 2015-07-14 13:23:23,665 * INFO * [156380] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.75-1.77
# 2015-07-14 13:23:25,188 * INFO * [154011] percIncorpUnif_difBD/80/1.69-1.71 Finished with 0
# 2015-07-14 13:23:25,191 * INFO * [156410] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.67-1.81
# 2015-07-14 13:23:26,022 * INFO * [154022] percIncorpUnif_difBD/80/1.77-1.81 Finished with 0
# 2015-07-14 13:23:26,024 * INFO * [156437] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.73-1.75
# 2015-07-14 13:23:26,712 * INFO * [154201] percIncorpUnif_difBD/80/1.77-1.79 Finished with 0
# 2015-07-14 13:23:26,714 * INFO * [156456] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.71-1.77
# 2015-07-14 13:23:27,269 * INFO * [153999] percIncorpUnif_difBD/80/1.71-1.73 Finished with 0
# 2015-07-14 13:23:27,271 * INFO * [156477] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.69-1.81
# 2015-07-14 13:23:27,305 * INFO * [154039] percIncorpUnif_difBD/80/1.69-1.79 Finished with 0
# 2015-07-14 13:23:27,308 * INFO * [156488] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.67-1.71
# 2015-07-14 13:23:27,814 * INFO * [154118] percIncorpUnif_difBD/80/1.67-1.81 Finished with 0
# 2015-07-14 13:23:27,816 * INFO * [156510] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.73-1.81
# 2015-07-14 13:23:28,367 * INFO * [154109] percIncorpUnif_difBD/80/1.75-1.77 Finished with 0
# 2015-07-14 13:23:28,369 * INFO * [156523] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.71-1.81
# 2015-07-14 13:23:28,614 * INFO * [154223] percIncorpUnif_difBD/20/1.73-1.77 Finished with 0
# 2015-07-14 13:23:28,616 * INFO * [156540] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.71-1.79
# 2015-07-14 13:23:29,692 * INFO * [153995] percIncorpUnif_difBD/80/1.75-1.81 Finished with 0
# 2015-07-14 13:23:29,695 * INFO * [156594] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.67-1.73
# 2015-07-14 13:23:30,578 * INFO * [154054] percIncorpUnif_difBD/80/1.67-1.77 Finished with 0
# 2015-07-14 13:23:30,580 * INFO * [156634] Started ./SIPSimRun.sh in percIncorpUnif_difBD/20/1.77-1.79
# 2015-07-14 13:23:30,897 * INFO * [154083] percIncorpUnif_difBD/80/1.69-1.75 Finished with 0
# 2015-07-14 13:23:30,900 * INFO * [156652] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.67-1.79
# 2015-07-14 13:23:31,139 * INFO * [153984] percIncorpUnif_difBD/80/1.67-1.79 Finished with 0
# 2015-07-14 13:23:31,141 * INFO * [156670] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.73-1.77
# 2015-07-14 13:23:31,331 * INFO * [154210] percIncorpUnif_difBD/20/1.67-1.79 Finished with 0
# 2015-07-14 13:23:31,333 * INFO * [156685] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.69-1.77
# 2015-07-14 13:23:31,704 * INFO * [154154] percIncorpUnif_difBD/80/1.67-1.71 Finished with 0
# 2015-07-14 13:23:31,707 * INFO * [156702] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.71-1.75
# 2015-07-14 13:23:31,730 * INFO * [154140] percIncorpUnif_difBD/80/1.69-1.81 Finished with 0
# 2015-07-14 13:23:31,733 * INFO * [156712] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.75-1.81
# 2015-07-14 13:23:32,034 * INFO * [154105] percIncorpUnif_difBD/80/1.67-1.75 Finished with 0
# 2015-07-14 13:23:32,036 * INFO * [156724] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.71-1.73
# 2015-07-14 13:23:32,571 * INFO * [154136] percIncorpUnif_difBD/80/1.71-1.77 Finished with 0
# 2015-07-14 13:23:32,574 * INFO * [156742] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.73-1.79
# 2015-07-14 13:23:33,412 * INFO * [154168] percIncorpUnif_difBD/80/1.71-1.81 Finished with 0
# 2015-07-14 13:23:33,414 * INFO * [156760] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.69-1.71
# 2015-07-14 13:24:36,917 * INFO * [156060] percIncorpUnif_difBD/20/1.75-1.81 Finished with 0
# 2015-07-14 13:24:36,920 * INFO * [158356] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.77-1.81
# 2015-07-14 13:24:39,430 * INFO * [156314] percIncorpUnif_difBD/20/1.67-1.77 Finished with 0
# 2015-07-14 13:24:39,433 * INFO * [158438] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.69-1.73
# 2015-07-14 13:24:40,468 * INFO * [156278] percIncorpUnif_difBD/20/1.69-1.73 Finished with 0
# 2015-07-14 13:24:40,470 * INFO * [158496] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.69-1.79
# 2015-07-14 13:24:42,059 * INFO * [156082] percIncorpUnif_difBD/20/1.71-1.73 Finished with 0
# 2015-07-14 13:24:42,061 * INFO * [158534] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.67-1.77
# 2015-07-14 13:24:44,486 * INFO * [156236] percIncorpUnif_difBD/20/1.69-1.71 Finished with 0
# 2015-07-14 13:24:44,489 * INFO * [158572] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.75-1.79
# 2015-07-14 13:24:46,050 * INFO * [156263] percIncorpUnif_difBD/20/1.77-1.81 Finished with 0
# 2015-07-14 13:24:46,053 * INFO * [158629] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.69-1.75
# 2015-07-14 13:24:47,578 * INFO * [156437] percIncorpUnif_difBD/20/1.73-1.75 Finished with 0
# 2015-07-14 13:24:47,581 * INFO * [158666] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.67-1.75
# 2015-07-14 13:24:47,960 * INFO * [156202] percIncorpUnif_difBD/20/1.73-1.79 Finished with 0
# 2015-07-14 13:24:47,962 * INFO * [158678] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.75-1.77
# 2015-07-14 13:24:48,577 * INFO * [156380] percIncorpUnif_difBD/20/1.75-1.77 Finished with 0
# 2015-07-14 13:24:48,580 * INFO * [158716] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.67-1.81
# 2015-07-14 13:24:49,674 * INFO * [156296] percIncorpUnif_difBD/20/1.69-1.79 Finished with 0
# 2015-07-14 13:24:49,677 * INFO * [158745] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.73-1.75
# 2015-07-14 13:24:50,489 * INFO * [156410] percIncorpUnif_difBD/20/1.67-1.81 Finished with 0
# 2015-07-14 13:24:50,492 * INFO * [158768] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.71-1.77
# 2015-07-14 13:24:51,860 * INFO * [156523] percIncorpUnif_difBD/20/1.71-1.81 Finished with 0
# 2015-07-14 13:24:51,863 * INFO * [158808] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.69-1.81
# 2015-07-14 13:24:51,964 * INFO * [156338] percIncorpUnif_difBD/20/1.69-1.75 Finished with 0
# 2015-07-14 13:24:51,967 * INFO * [158826] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.67-1.71
# 2015-07-14 13:24:53,142 * INFO * [156488] percIncorpUnif_difBD/20/1.67-1.71 Finished with 0
# 2015-07-14 13:24:53,145 * INFO * [158853] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.73-1.81
# 2015-07-14 13:24:53,783 * INFO * [156670] percIncorpUnif_difBD/0/1.73-1.77 Finished with 0
# 2015-07-14 13:24:53,786 * INFO * [158874] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.71-1.81
# 2015-07-14 13:24:53,920 * INFO * [156685] percIncorpUnif_difBD/0/1.69-1.77 Finished with 0
# 2015-07-14 13:24:53,923 * INFO * [158886] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.71-1.79
# 2015-07-14 13:24:54,373 * INFO * [156594] percIncorpUnif_difBD/20/1.67-1.73 Finished with 0
# 2015-07-14 13:24:54,376 * INFO * [158904] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.67-1.73
# 2015-07-14 13:24:54,682 * INFO * [156456] percIncorpUnif_difBD/20/1.71-1.77 Finished with 0
# 2015-07-14 13:24:54,685 * INFO * [158916] Started ./SIPSimRun.sh in percIncorpUnif_difBD/0/1.77-1.79
# 2015-07-14 13:24:55,154 * INFO * [156356] percIncorpUnif_difBD/20/1.67-1.75 Finished with 0
# 2015-07-14 13:24:55,157 * INFO * [158931] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.67-1.79
# 2015-07-14 13:24:55,249 * INFO * [156326] percIncorpUnif_difBD/20/1.75-1.79 Finished with 0
# 2015-07-14 13:24:55,251 * INFO * [158946] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.73-1.77
# 2015-07-14 13:24:57,268 * INFO * [156634] percIncorpUnif_difBD/20/1.77-1.79 Finished with 0
# 2015-07-14 13:24:57,270 * INFO * [158986] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.69-1.77
# 2015-07-14 13:24:59,031 * INFO * [156724] percIncorpUnif_difBD/0/1.71-1.73 Finished with 0
# 2015-07-14 13:24:59,034 * INFO * [159022] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.71-1.75
# 2015-07-14 13:25:00,679 * INFO * [156702] percIncorpUnif_difBD/0/1.71-1.75 Finished with 0
# 2015-07-14 13:25:00,681 * INFO * [159090] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.75-1.81
# 2015-07-14 13:25:01,543 * INFO * [156510] percIncorpUnif_difBD/20/1.73-1.81 Finished with 0
# 2015-07-14 13:25:01,546 * INFO * [159107] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.71-1.73
# 2015-07-14 13:25:01,554 * INFO * [156477] percIncorpUnif_difBD/20/1.69-1.81 Finished with 0
# 2015-07-14 13:25:01,556 * INFO * [159112] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.73-1.79
# 2015-07-14 13:25:01,641 * INFO * [156540] percIncorpUnif_difBD/20/1.71-1.79 Finished with 0
# 2015-07-14 13:25:01,644 * INFO * [159129] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.69-1.71
# 2015-07-14 13:25:01,864 * INFO * [156760] percIncorpUnif_difBD/0/1.69-1.71 Finished with 0
# 2015-07-14 13:25:01,867 * INFO * [159147] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.77-1.81
# 2015-07-14 13:25:02,705 * INFO * [156742] percIncorpUnif_difBD/0/1.73-1.79 Finished with 0
# 2015-07-14 13:25:02,708 * INFO * [159181] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.69-1.73
# 2015-07-14 13:25:04,715 * INFO * [156652] percIncorpUnif_difBD/0/1.67-1.79 Finished with 0
# 2015-07-14 13:25:04,719 * INFO * [159231] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.69-1.79
# 2015-07-14 13:25:07,631 * INFO * [156712] percIncorpUnif_difBD/0/1.75-1.81 Finished with 0
# 2015-07-14 13:25:07,635 * INFO * [159321] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.67-1.77
# 2015-07-14 13:26:01,810 * INFO * [158356] percIncorpUnif_difBD/0/1.77-1.81 Finished with 0
# 2015-07-14 13:26:01,812 * INFO * [160977] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.75-1.79
# 2015-07-14 13:26:04,258 * INFO * [158496] percIncorpUnif_difBD/0/1.69-1.79 Finished with 0
# 2015-07-14 13:26:04,260 * INFO * [161047] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.69-1.75
# 2015-07-14 13:26:09,040 * INFO * [158629] percIncorpUnif_difBD/0/1.69-1.75 Finished with 0
# 2015-07-14 13:26:09,041 * INFO * [161141] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.67-1.75
# 2015-07-14 13:26:12,937 * INFO * [158534] percIncorpUnif_difBD/0/1.67-1.77 Finished with 0
# 2015-07-14 13:26:12,940 * INFO * [161267] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.75-1.77
# 2015-07-14 13:26:13,103 * INFO * [158678] percIncorpUnif_difBD/0/1.75-1.77 Finished with 0
# 2015-07-14 13:26:13,105 * INFO * [161298] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.67-1.81
# 2015-07-14 13:26:13,137 * INFO * [158438] percIncorpUnif_difBD/0/1.69-1.73 Finished with 0
# 2015-07-14 13:26:13,140 * INFO * [161323] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.73-1.75
# 2015-07-14 13:26:13,557 * INFO * [158826] percIncorpUnif_difBD/0/1.67-1.71 Finished with 0
# 2015-07-14 13:26:13,559 * INFO * [161341] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.71-1.77
# 2015-07-14 13:26:13,661 * INFO * [158572] percIncorpUnif_difBD/0/1.75-1.79 Finished with 0
# 2015-07-14 13:26:13,663 * INFO * [161353] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.69-1.81
# 2015-07-14 13:26:14,545 * INFO * [158853] percIncorpUnif_difBD/0/1.73-1.81 Finished with 0
# 2015-07-14 13:26:14,548 * INFO * [161381] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.67-1.71
# 2015-07-14 13:26:15,687 * INFO * [158716] percIncorpUnif_difBD/0/1.67-1.81 Finished with 0
# 2015-07-14 13:26:15,689 * INFO * [161403] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.73-1.81
# 2015-07-14 13:26:15,885 * INFO * [158666] percIncorpUnif_difBD/0/1.67-1.75 Finished with 0
# 2015-07-14 13:26:15,888 * INFO * [161415] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.71-1.81
# 2015-07-14 13:26:19,491 * INFO * [158768] percIncorpUnif_difBD/0/1.71-1.77 Finished with 0
# 2015-07-14 13:26:19,495 * INFO * [161522] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.71-1.79
# 2015-07-14 13:26:20,252 * INFO * [158745] percIncorpUnif_difBD/0/1.73-1.75 Finished with 0
# 2015-07-14 13:26:20,253 * INFO * [161545] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.67-1.73
# 2015-07-14 13:26:20,354 * INFO * [158808] percIncorpUnif_difBD/0/1.69-1.81 Finished with 0
# 2015-07-14 13:26:20,356 * INFO * [161557] Started ./SIPSimRun.sh in percIncorpUnif_difBD/60/1.77-1.79
# 2015-07-14 13:26:20,930 * INFO * [158904] percIncorpUnif_difBD/0/1.67-1.73 Finished with 0
# 2015-07-14 13:26:20,933 * INFO * [161581] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.67-1.79
# 2015-07-14 13:26:23,380 * INFO * [158916] percIncorpUnif_difBD/0/1.77-1.79 Finished with 0
# 2015-07-14 13:26:23,382 * INFO * [161611] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.73-1.77
# 2015-07-14 13:26:24,267 * INFO * [158886] percIncorpUnif_difBD/0/1.71-1.79 Finished with 0
# 2015-07-14 13:26:24,270 * INFO * [161629] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.69-1.77
# 2015-07-14 13:26:24,874 * INFO * [158946] percIncorpUnif_difBD/60/1.73-1.77 Finished with 0
# 2015-07-14 13:26:24,876 * INFO * [161665] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.71-1.75
# 2015-07-14 13:26:26,244 * INFO * [159022] percIncorpUnif_difBD/60/1.71-1.75 Finished with 0
# 2015-07-14 13:26:26,246 * INFO * [161707] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.75-1.81
# 2015-07-14 13:26:27,115 * INFO * [158931] percIncorpUnif_difBD/60/1.67-1.79 Finished with 0
# 2015-07-14 13:26:27,117 * INFO * [161735] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.71-1.73
# 2015-07-14 13:26:27,301 * INFO * [158986] percIncorpUnif_difBD/60/1.69-1.77 Finished with 0
# 2015-07-14 13:26:27,304 * INFO * [161753] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.73-1.79
# 2015-07-14 13:26:27,689 * INFO * [158874] percIncorpUnif_difBD/0/1.71-1.81 Finished with 0
# 2015-07-14 13:26:27,692 * INFO * [161771] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.69-1.71
# 2015-07-14 13:26:29,060 * INFO * [159147] percIncorpUnif_difBD/60/1.77-1.81 Finished with 0
# 2015-07-14 13:26:29,063 * INFO * [161811] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.77-1.81
# 2015-07-14 13:26:30,119 * INFO * [159129] percIncorpUnif_difBD/60/1.69-1.71 Finished with 0
# 2015-07-14 13:26:30,122 * INFO * [161841] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.69-1.73
# 2015-07-14 13:26:30,868 * INFO * [159090] percIncorpUnif_difBD/60/1.75-1.81 Finished with 0
# 2015-07-14 13:26:30,870 * INFO * [161869] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.69-1.79
# 2015-07-14 13:26:31,270 * INFO * [159321] percIncorpUnif_difBD/60/1.67-1.77 Finished with 0
# 2015-07-14 13:26:31,273 * INFO * [161917] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.67-1.77
# 2015-07-14 13:26:32,031 * INFO * [159107] percIncorpUnif_difBD/60/1.71-1.73 Finished with 0
# 2015-07-14 13:26:32,034 * INFO * [161951] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.75-1.79
# 2015-07-14 13:26:33,405 * INFO * [159231] percIncorpUnif_difBD/60/1.69-1.79 Finished with 0
# 2015-07-14 13:26:33,407 * INFO * [161991] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.69-1.75
# 2015-07-14 13:26:33,576 * INFO * [159181] percIncorpUnif_difBD/60/1.69-1.73 Finished with 0
# 2015-07-14 13:26:33,578 * INFO * [162003] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.67-1.75
# 2015-07-14 13:26:35,391 * INFO * [159112] percIncorpUnif_difBD/60/1.73-1.79 Finished with 0
# 2015-07-14 13:26:35,395 * INFO * [162055] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.75-1.77
# 2015-07-14 13:27:24,339 * INFO * [160977] percIncorpUnif_difBD/60/1.75-1.79 Finished with 0
# 2015-07-14 13:27:24,343 * INFO * [163286] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.67-1.81
# 2015-07-14 13:27:35,779 * INFO * [161047] percIncorpUnif_difBD/60/1.69-1.75 Finished with 0
# 2015-07-14 13:27:35,782 * INFO * [163510] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.73-1.75
# 2015-07-14 13:27:39,521 * INFO * [161381] percIncorpUnif_difBD/60/1.67-1.71 Finished with 0
# 2015-07-14 13:27:39,524 * INFO * [163614] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.71-1.77
# 2015-07-14 13:27:40,421 * INFO * [161341] percIncorpUnif_difBD/60/1.71-1.77 Finished with 0
# 2015-07-14 13:27:40,424 * INFO * [163658] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.69-1.81
# 2015-07-14 13:27:40,726 * INFO * [161323] percIncorpUnif_difBD/60/1.73-1.75 Finished with 0
# 2015-07-14 13:27:40,729 * INFO * [163682] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.67-1.71
# 2015-07-14 13:27:40,740 * INFO * [161267] percIncorpUnif_difBD/60/1.75-1.77 Finished with 0
# 2015-07-14 13:27:40,743 * INFO * [163692] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.73-1.81
# 2015-07-14 13:27:42,598 * INFO * [161353] percIncorpUnif_difBD/60/1.69-1.81 Finished with 0
# 2015-07-14 13:27:42,601 * INFO * [163742] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.71-1.81
# 2015-07-14 13:27:44,702 * INFO * [161611] percIncorpUnif_difBD/100/1.73-1.77 Finished with 0
# 2015-07-14 13:27:44,705 * INFO * [163776] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.71-1.79
# 2015-07-14 13:27:47,170 * INFO * [161141] percIncorpUnif_difBD/60/1.67-1.75 Finished with 0
# 2015-07-14 13:27:47,173 * INFO * [163830] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.67-1.73
# 2015-07-14 13:27:48,112 * INFO * [161403] percIncorpUnif_difBD/60/1.73-1.81 Finished with 0
# 2015-07-14 13:27:48,113 * INFO * [163864] Started ./SIPSimRun.sh in percIncorpUnif_difBD/100/1.77-1.79
# 2015-07-14 13:27:48,867 * INFO * [161557] percIncorpUnif_difBD/60/1.77-1.79 Finished with 0
# 2015-07-14 13:27:48,870 * INFO * [163876] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.67-1.79
# 2015-07-14 13:27:49,875 * INFO * [161545] percIncorpUnif_difBD/60/1.67-1.73 Finished with 0
# 2015-07-14 13:27:49,878 * INFO * [163920] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.73-1.77
# 2015-07-14 13:27:50,102 * INFO * [161522] percIncorpUnif_difBD/60/1.71-1.79 Finished with 0
# 2015-07-14 13:27:50,105 * INFO * [163932] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.69-1.77
# 2015-07-14 13:27:52,309 * INFO * [161735] percIncorpUnif_difBD/100/1.71-1.73 Finished with 0
# 2015-07-14 13:27:52,312 * INFO * [163988] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.71-1.75
# 2015-07-14 13:27:53,704 * INFO * [161707] percIncorpUnif_difBD/100/1.75-1.81 Finished with 0
# 2015-07-14 13:27:53,706 * INFO * [164024] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.75-1.81
# 2015-07-14 13:27:54,491 * INFO * [161841] percIncorpUnif_difBD/100/1.69-1.73 Finished with 0
# 2015-07-14 13:27:54,494 * INFO * [164061] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.71-1.73
# 2015-07-14 13:27:55,474 * INFO * [161415] percIncorpUnif_difBD/60/1.71-1.81 Finished with 0
# 2015-07-14 13:27:55,476 * INFO * [164099] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.73-1.79
# 2015-07-14 13:27:55,747 * INFO * [161753] percIncorpUnif_difBD/100/1.73-1.79 Finished with 0
# 2015-07-14 13:27:55,749 * INFO * [164117] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.69-1.71
# 2015-07-14 13:27:56,455 * INFO * [161298] percIncorpUnif_difBD/60/1.67-1.81 Finished with 0
# 2015-07-14 13:27:56,458 * INFO * [164151] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.77-1.81
# 2015-07-14 13:27:57,572 * INFO * [161581] percIncorpUnif_difBD/100/1.67-1.79 Finished with 0
# 2015-07-14 13:27:57,575 * INFO * [164185] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.69-1.73
# 2015-07-14 13:27:57,981 * INFO * [161771] percIncorpUnif_difBD/100/1.69-1.71 Finished with 0
# 2015-07-14 13:27:57,984 * INFO * [164217] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.69-1.79
# 2015-07-14 13:27:58,768 * INFO * [161951] percIncorpUnif_difBD/100/1.75-1.79 Finished with 0
# 2015-07-14 13:27:58,770 * INFO * [164241] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.67-1.77
# 2015-07-14 13:27:59,513 * INFO * [161869] percIncorpUnif_difBD/100/1.69-1.79 Finished with 0
# 2015-07-14 13:27:59,516 * INFO * [164253] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.75-1.79
# 2015-07-14 13:28:00,314 * INFO * [161665] percIncorpUnif_difBD/100/1.71-1.75 Finished with 0
# 2015-07-14 13:28:00,316 * INFO * [164265] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.69-1.75
# 2015-07-14 13:28:00,871 * INFO * [161629] percIncorpUnif_difBD/100/1.69-1.77 Finished with 0
# 2015-07-14 13:28:00,873 * INFO * [164283] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.67-1.75
# 2015-07-14 13:28:04,501 * INFO * [161991] percIncorpUnif_difBD/100/1.69-1.75 Finished with 0
# 2015-07-14 13:28:04,503 * INFO * [164369] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.75-1.77
# 2015-07-14 13:28:06,247 * INFO * [161811] percIncorpUnif_difBD/100/1.77-1.81 Finished with 0
# 2015-07-14 13:28:06,249 * INFO * [164423] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.67-1.81
# 2015-07-14 13:28:06,513 * INFO * [161917] percIncorpUnif_difBD/100/1.67-1.77 Finished with 0
# 2015-07-14 13:28:06,516 * INFO * [164435] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.73-1.75
# 2015-07-14 13:28:07,247 * INFO * [162055] percIncorpUnif_difBD/100/1.75-1.77 Finished with 0
# 2015-07-14 13:28:07,250 * INFO * [164475] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.71-1.77
# 2015-07-14 13:28:09,195 * INFO * [162003] percIncorpUnif_difBD/100/1.67-1.75 Finished with 0
# 2015-07-14 13:28:09,198 * INFO * [164533] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.69-1.81
# 2015-07-14 13:28:52,270 * INFO * [163286] percIncorpUnif_difBD/100/1.67-1.81 Finished with 0
# 2015-07-14 13:28:52,273 * INFO * [165657] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.67-1.71
# 2015-07-14 13:29:02,657 * INFO * [163692] percIncorpUnif_difBD/100/1.73-1.81 Finished with 0
# 2015-07-14 13:29:02,660 * INFO * [165889] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.73-1.81
# 2015-07-14 13:29:04,375 * INFO * [163682] percIncorpUnif_difBD/100/1.67-1.71 Finished with 0
# 2015-07-14 13:29:04,378 * INFO * [165941] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.71-1.81
# 2015-07-14 13:29:05,375 * INFO * [163510] percIncorpUnif_difBD/100/1.73-1.75 Finished with 0
# 2015-07-14 13:29:05,378 * INFO * [165965] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.71-1.79
# 2015-07-14 13:29:05,834 * INFO * [163614] percIncorpUnif_difBD/100/1.71-1.77 Finished with 0
# 2015-07-14 13:29:05,836 * INFO * [165993] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.67-1.73
# 2015-07-14 13:29:07,794 * INFO * [163920] percIncorpUnif_difBD/40/1.73-1.77 Finished with 0
# 2015-07-14 13:29:07,796 * INFO * [166057] Started ./SIPSimRun.sh in percIncorpUnif_difBD/40/1.77-1.79
# 2015-07-14 13:29:10,143 * INFO * [163988] percIncorpUnif_difBD/40/1.71-1.75 Finished with 0
# 2015-07-14 13:29:11,548 * INFO * [163776] percIncorpUnif_difBD/100/1.71-1.79 Finished with 0
# 2015-07-14 13:29:12,302 * INFO * [163742] percIncorpUnif_difBD/100/1.71-1.81 Finished with 0
# 2015-07-14 13:29:13,134 * INFO * [163658] percIncorpUnif_difBD/100/1.69-1.81 Finished with 0
# 2015-07-14 13:29:14,621 * INFO * [163830] percIncorpUnif_difBD/100/1.67-1.73 Finished with 0
# 2015-07-14 13:29:17,850 * INFO * [163864] percIncorpUnif_difBD/100/1.77-1.79 Finished with 0
# 2015-07-14 13:29:18,311 * INFO * [164024] percIncorpUnif_difBD/40/1.75-1.81 Finished with 0
# 2015-07-14 13:29:19,246 * INFO * [164117] percIncorpUnif_difBD/40/1.69-1.71 Finished with 0
# 2015-07-14 13:29:19,324 * INFO * [164061] percIncorpUnif_difBD/40/1.71-1.73 Finished with 0
# 2015-07-14 13:29:20,146 * INFO * [163876] percIncorpUnif_difBD/40/1.67-1.79 Finished with 0
# 2015-07-14 13:29:20,219 * INFO * [163932] percIncorpUnif_difBD/40/1.69-1.77 Finished with 0
# 2015-07-14 13:29:20,250 * INFO * [164151] percIncorpUnif_difBD/40/1.77-1.81 Finished with 0
# 2015-07-14 13:29:21,061 * INFO * [164099] percIncorpUnif_difBD/40/1.73-1.79 Finished with 0
# 2015-07-14 13:29:22,579 * INFO * [164185] percIncorpUnif_difBD/40/1.69-1.73 Finished with 0
# 2015-07-14 13:29:23,886 * INFO * [164241] percIncorpUnif_difBD/40/1.67-1.77 Finished with 0
# 2015-07-14 13:29:24,138 * INFO * [164253] percIncorpUnif_difBD/40/1.75-1.79 Finished with 0
# 2015-07-14 13:29:24,705 * INFO * [164435] percIncorpUnif_difBD/40/1.73-1.75 Finished with 0
# 2015-07-14 13:29:25,321 * INFO * [164369] percIncorpUnif_difBD/40/1.75-1.77 Finished with 0
# 2015-07-14 13:29:29,513 * INFO * [164217] percIncorpUnif_difBD/40/1.69-1.79 Finished with 0
# 2015-07-14 13:29:29,538 * INFO * [164265] percIncorpUnif_difBD/40/1.69-1.75 Finished with 0
# 2015-07-14 13:29:31,264 * INFO * [164475] percIncorpUnif_difBD/40/1.71-1.77 Finished with 0
# 2015-07-14 13:29:31,518 * INFO * [164283] percIncorpUnif_difBD/40/1.67-1.75 Finished with 0
# 2015-07-14 13:29:32,232 * INFO * [164423] percIncorpUnif_difBD/40/1.67-1.81 Finished with 0
# 2015-07-14 13:29:32,375 * INFO * [164533] percIncorpUnif_difBD/40/1.69-1.81 Finished with 0
# 2015-07-14 13:29:58,991 * INFO * [165657] percIncorpUnif_difBD/40/1.67-1.71 Finished with 0
# 2015-07-14 13:30:04,541 * INFO * [165889] percIncorpUnif_difBD/40/1.73-1.81 Finished with 0
# 2015-07-14 13:30:06,867 * INFO * [166057] percIncorpUnif_difBD/40/1.77-1.79 Finished with 0
# 2015-07-14 13:30:07,634 * INFO * [165965] percIncorpUnif_difBD/40/1.71-1.79 Finished with 0
# 2015-07-14 13:30:08,449 * INFO * [165993] percIncorpUnif_difBD/40/1.67-1.73 Finished with 0
# 2015-07-14 13:30:10,386 * INFO * [165941] percIncorpUnif_difBD/40/1.71-1.81 Finished with 0

# %%
# aggregating confusion matrix data
## table
# !cd $workDir; \
    nestagg delim \
        -d percIncorpUnif_difBD \
        -k percIncorp,BD_min,BD_max \
        -o ./percIncorpUnif_difBD/DESeq2-cMtx_table.csv \
        DESeq2-cMtx_table.csv

## overall
# !cd $workDir; \
    nestagg delim \
        -d percIncorpUnif_difBD \
        -k percIncorp,BD_min,BD_max \
        -o ./percIncorpUnif_difBD/DESeq2-cMtx_overall.csv \
        DESeq2-cMtx_overall.csv
    
## byClass
# !cd $workDir; \
    nestagg delim \
        -d percIncorpUnif_difBD \
        -k percIncorp,BD_min,BD_max \
        -o ./percIncorpUnif_difBD/DESeq2-cMtx_byClass.csv \
        DESeq2-cMtx_byClass.csv

# %% [markdown]
# ### Plotting results

# %%
# %%R -i workDir -w 600 -h 600
# setwd(workDir)
#
# byClass = read.csv('./percIncorpUnif_difBD/DESeq2-cMtx_byClass.csv')
#
# byClass$byClass[is.na(byClass$byClass)] = 0
#
# cat.str = function(x,y, col=':'){
#     x = as.character(x)
#     y = as.character(y)
#     z = paste(c(x,y),collapse=col)
#     return(z)
#     }
#
# byClass = byClass %>%
#     mutate(BD_range = mapply(cat.str, BD_min, BD_max)) %>%
#     mutate(BD_min = as.character(BD_min),
#            BD_max = as.character(BD_max))

# %%
# %%R -w 800 -h 750
#
# col2keep = c('Balanced Accuracy', 'Sensitivity','Specificity')
# byClass.f = byClass %>%
#     filter(X %in% col2keep) %>%
#     mutate(BD_min = as.numeric(BD_min),
#            BD_max = as.numeric(BD_max),
#            byClass = as.numeric(byClass),
#            byClass.inv = 1 - byClass)
#
# byClass.fs = byClass.f %>%
#     group_by(X, percIncorp) %>%
#     summarize(byClass.max = max(byClass))
#
# just.true = function(x){
#     if(x == TRUE){
#         return(1)
#         } else{
#         return(NA)
#         }
#     }
#
# byClass.j = inner_join(byClass.f, byClass.fs, c('X' = 'X',
#                                                 'percIncorp' = 'percIncorp')) %>%
#     mutate(max_val = as.numeric(byClass == byClass.max))
# byClass.jf = byClass.j %>%
#     filter(max_val == 1)
#
# x.breaks = unique(byClass.j$BD_min)
#
# p = ggplot(byClass.j, aes(BD_min, BD_max, fill=byClass.inv)) +
#     geom_tile() +
#     geom_point(data=byClass.jf, aes(color='red')) +
#     scale_x_continuous(breaks=x.breaks) +
#     labs(x='Minimum BD', y='Maximum BD') +
#     facet_grid(percIncorp ~ X) +
#     theme_bw() +
#     theme(
#         text=element_text(size=16),
#         axis.text.x=element_text(angle=90, hjust=1, vjust=0.5)
#         )
# p

# %%
# %%R -w 800 -h 750
#
# col2keep = c('Balanced Accuracy', 'Sensitivity','Specificity')
# byClass.f = byClass %>%
#     filter(X %in% col2keep) %>%
#     mutate(BD_min = as.numeric(BD_min),
#            BD_max = as.numeric(BD_max),
#            byClass = as.numeric(byClass),
#            byClass.inv = 1 - byClass)
#
# byClass.fs = byClass.f %>%
#     group_by(X, percIncorp) %>%
#     summarize(byClass.max = max(byClass))
#
# just.true = function(x){
#     if(x == TRUE){
#         return(1)
#         } else{
#         return(NA)
#         }
#     }
#
# byClass.j = inner_join(byClass.f, byClass.fs, c('X' = 'X',
#                                                 'percIncorp' = 'percIncorp')) %>%
#     mutate(max_val = as.numeric(byClass == byClass.max),
#            byClass.txt = round(byClass, 2))
# byClass.jf = byClass.j %>%
#     filter(max_val == 1)
#
# x.breaks = unique(byClass.j$BD_min)
#
# p = ggplot(byClass.j, aes(BD_min, BD_max, fill=byClass.inv)) +
#     geom_tile() +
#     geom_text(data=byClass.jf, aes(label=byClass.txt), color=c('white')) +
#     scale_x_continuous(breaks=x.breaks) +
#     labs(x='Minimum Buoyant Density', y='Maximum Buoyant Density') +
#     facet_grid(percIncorp ~ X) +
#     theme_bw() +
#     theme(
#         text=element_text(size=16),
#         axis.text.x=element_text(angle=90, hjust=1, vjust=0.5)
#         )
# p

# %%
# %%R -w 800 -h 750
#
# col2keep = c('Balanced Accuracy', 'Sensitivity','Specificity')
# byClass.f = byClass %>%
#     filter(X %in% col2keep) %>%
#     mutate(BD_min = as.numeric(BD_min),
#            BD_max = as.numeric(BD_max),
#            byClass = as.numeric(byClass),
#            byClass.inv = 1 - byClass)
#
# byClass.fs = byClass.f %>%
#     group_by(X, percIncorp) %>%
#     summarize(byClass.max = max(byClass))
#
# just.true = function(x){
#     if(x == TRUE){
#         return(1)
#         } else{
#         return(NA)
#         }
#     }
#
# byClass.j = inner_join(byClass.f, byClass.fs, c('X' = 'X',
#                                                 'percIncorp' = 'percIncorp')) %>%
#     mutate(max_val = as.numeric(byClass == byClass.max),
#            byClass.txt = round(byClass, 2))
# byClass.jf = byClass.j %>%
#     filter(max_val == 1)
#
# x.breaks = unique(byClass.j$BD_min)
#
# p = ggplot(byClass.j, aes(BD_min, BD_max, fill=byClass.inv)) +
#     geom_tile() +
#     geom_text(aes(label=byClass.txt), color=c('white'), size=4) +
#     geom_text(data=byClass.jf, aes(label=byClass.txt), color=c('red'), size=4) +
#     scale_x_continuous(breaks=x.breaks) +
#     labs(x='Minimum Buoyant Density', y='Maximum Buoyant Density') +
#     facet_grid(percIncorp ~ X) +
#     theme_bw() +
#     theme(
#         text=element_text(size=16),
#         axis.text.x=element_text(angle=90, hjust=1, vjust=0.5)
#         )
# p

# %% [markdown]
# ***
#
# # Sandbox

# %% [markdown]
# ### Enrichment of TP for abundant incorporators?
#
# * What is the abundance distribution of TP and FP?
#   * Are more abundant incorporators being detected more than low abundant taxa

# %%
# %%R -i workDir
#
# setwd(workDir)
#
# tbl.c = read.csv('percIncorpUnif/100/DESeq2-cMtx_data.csv')
# tbl.otu = read.delim('percIncorpUnif/100/OTU_n2_abs1e10_sub20000.txt', sep='\t')

# %%
# %%R
# # OTU total counts
# tbl.otu.sum = tbl.otu %>%
#     group_by(library, taxon) %>%
#     summarize(total_count = sum(count))
# tbl.otu.sum %>% head
# Out:
# Source: local data frame [6 x 3]
# Groups: library
#
#   library                                taxon total_count
# 1       1       Acaryochloris_marina_MBIC11017           0
# 2       1       Acetobacterium_woodii_DSM_1030           0
# 3       1 Acetobacter_pasteurianus_IFO_3283-12         751
# 4       1    Acetohalobium_arabaticum_DSM_5501           9
# 5       1         Acholeplasma_laidlawii_PG-8A         238
# 6       1        Achromobacter_xylosoxidans_A8          17

# %%
# %%R
# #
# label.tp.fn = function(known, pred){
#     if(is.na(known) | is.na(pred)){
#         return(NA)
#         } else
#     if(known==TRUE & pred==TRUE){
#         return('TP')
#         } else
#     if(known==TRUE & pred==FALSE){
#         return('FN')
#         } else {
#         return(NA)
#         }
#     }
#
# tbl.c.tp.fn = tbl.c %>%
#     mutate(tp.fn = mapply(label.tp.fn, incorp.known, incorp.pred)) %>%
#     filter(! is.na(tp.fn))
#
# tbl.tp.fn = inner_join(tbl.c.tp.fn, tbl.otu.sum, c('taxon' = 'taxon'))
# tbl.tp.fn %>% head
# Out:
#   lib1 lib2                              taxon  BD_shift incorp.known  baseMean
# 1   NA    2 Actinobacillus_equuli_subsp_equuli 0.9999269         TRUE 1.8646755
# 2   NA    2 Actinobacillus_equuli_subsp_equuli 0.9999269         TRUE 1.8646755
# 3   NA    2 Candidatus_Moranella_endobia_PCVAL 0.9997449         TRUE 0.4688403
# 4   NA    2 Candidatus_Moranella_endobia_PCVAL 0.9997449         TRUE 0.4688403
# 5   NA    2     Alkaliphilus_oremlandii_OhILAs 0.9997434         TRUE 0.3118965
# 6   NA    2     Alkaliphilus_oremlandii_OhILAs 0.9997434         TRUE 0.3118965
#   log2FoldChange    lfcSE       stat       pvalue       padj            p
# 1     5.37154211 1.267839 4.23676891 2.267593e-05 0.00111679 2.677315e-05
# 2     5.37154211 1.267839 4.23676891 2.267593e-05 0.00111679 2.677315e-05
# 3     0.04533956 1.501490 0.03019637 9.759104e-01 1.00000000 5.542099e-01
# 4     0.04533956 1.501490 0.03019637 9.759104e-01 1.00000000 5.542099e-01
# 5     5.33532814 1.665671 3.20311065 1.359517e-03 0.02434772 1.132750e-03
# 6     5.33532814 1.665671 3.20311065 1.359517e-03 0.02434772 1.132750e-03
#       padj.BH incorp.pred tp.fn library total_count
# 1 0.001318578        TRUE    TP       1        1728
# 2 0.001318578        TRUE    TP       2        1554
# 3 1.000000000       FALSE    FN       1         371
# 4 1.000000000       FALSE    FN       2        1981
# 5 0.022315185        TRUE    TP       1         183
# 6 0.022315185        TRUE    TP       2         247

# %%
# %%R
# # how many TP & FN?
# tbl.tp.fn %>%
#     group_by(library, tp.fn) %>%
#     summarize(n = n())
# Out:
# Source: local data frame [4 x 3]
# Groups: library
#
#   library tp.fn  n
# 1       1    FN 63
# 2       1    TP  9
# 3       2    FN 63
# 4       2    TP  9

# %%
# %%R -h 350
# tbl.tp.fn$library = as.character(tbl.tp.fn$library)
# ggplot(tbl.tp.fn, aes(library, total_count, color=tp.fn)) +
#     geom_boxplot() +
#     labs(y='Total count') +
#     theme(
#         text = element_text(size=18)
#         )

# %%
# %%R -h 700 -w 900
# tbl.tp.fn$library = as.character(tbl.tp.fn$library)
# ggplot(tbl.tp.fn, aes(taxon, total_count, group=taxon, color=library)) +
#     geom_point(size=3) +
#     geom_line() +
#     scale_y_log10() +
#     labs(y='Total count') +
#     facet_grid(. ~ tp.fn, scales='free_x') +
#     theme(
#         text = element_text(size=18),
#         axis.text.x = element_text(angle=90, hjust=1)
#         )

# %% [markdown]
# __Notes:__
#
# * FNs can be abundant
# * __TP can have a lower abundance in the 'treatment' library__

# %% [markdown]
# ### Just looking at the 'heavy' fractions

# %%
# %%R
# # OTU total counts
#
# heavy.cut = 1.71
#
# tbl.otu.sum = tbl.otu %>%
#     filter(! grepl('inf', fraction)) %>%
#     separate(fraction, into = c('BD_min','BD_max'), sep='-', convert=TRUE) %>%
#     filter(BD_min >= heavy.cut & BD_max <= 2) %>%
#     group_by(library, taxon) %>%
#     summarize(total_count = sum(count))
# tbl.otu.sum %>% head
# Out:
# Source: local data frame [6 x 3]
# Groups: library
#
#   library                                taxon total_count
# 1       1       Acaryochloris_marina_MBIC11017           0
# 2       1       Acetobacterium_woodii_DSM_1030           0
# 3       1 Acetobacter_pasteurianus_IFO_3283-12         564
# 4       1    Acetohalobium_arabaticum_DSM_5501           0
# 5       1         Acholeplasma_laidlawii_PG-8A           0
# 6       1        Achromobacter_xylosoxidans_A8          17

# %%
# %%R
#
# tbl.tp.fn = inner_join(tbl.c.tp.fn, tbl.otu.sum, c('taxon' = 'taxon'))
# tbl.tp.fn %>% head
# Out:
#   lib1 lib2                              taxon  BD_shift incorp.known  baseMean
# 1   NA    2 Actinobacillus_equuli_subsp_equuli 0.9999269         TRUE 1.8646755
# 2   NA    2 Actinobacillus_equuli_subsp_equuli 0.9999269         TRUE 1.8646755
# 3   NA    2 Candidatus_Moranella_endobia_PCVAL 0.9997449         TRUE 0.4688403
# 4   NA    2 Candidatus_Moranella_endobia_PCVAL 0.9997449         TRUE 0.4688403
# 5   NA    2     Alkaliphilus_oremlandii_OhILAs 0.9997434         TRUE 0.3118965
# 6   NA    2     Alkaliphilus_oremlandii_OhILAs 0.9997434         TRUE 0.3118965
#   log2FoldChange    lfcSE       stat       pvalue       padj            p
# 1     5.37154211 1.267839 4.23676891 2.267593e-05 0.00111679 2.677315e-05
# 2     5.37154211 1.267839 4.23676891 2.267593e-05 0.00111679 2.677315e-05
# 3     0.04533956 1.501490 0.03019637 9.759104e-01 1.00000000 5.542099e-01
# 4     0.04533956 1.501490 0.03019637 9.759104e-01 1.00000000 5.542099e-01
# 5     5.33532814 1.665671 3.20311065 1.359517e-03 0.02434772 1.132750e-03
# 6     5.33532814 1.665671 3.20311065 1.359517e-03 0.02434772 1.132750e-03
#       padj.BH incorp.pred tp.fn library total_count
# 1 0.001318578        TRUE    TP       1        1383
# 2 0.001318578        TRUE    TP       2        1554
# 3 1.000000000       FALSE    FN       1          30
# 4 1.000000000       FALSE    FN       2        1981
# 5 0.022315185        TRUE    TP       1           0
# 6 0.022315185        TRUE    TP       2         246

# %%
# %%R -h 350
# tbl.tp.fn$library = as.character(tbl.tp.fn$library)
# ggplot(tbl.tp.fn, aes(library, total_count, color=tp.fn)) +
#     geom_boxplot() +
#     labs(y='Total count') +
#     theme(
#         text = element_text(size=18)
#         )

# %%
# %%R -h 700 -w 900
# tbl.tp.fn$library = as.character(tbl.tp.fn$library)
# ggplot(tbl.tp.fn, aes(taxon, total_count, group=taxon, color=library)) +
#     geom_point(size=3) +
#     geom_line() +
#     scale_y_log10() +
#     labs(y='Total count') +
#     facet_grid(. ~ tp.fn, scales='free_x') +
#     theme(
#         text = element_text(size=18),
#         axis.text.x = element_text(angle=90, hjust=1)
#         )

# %%
# %%R -i workDir -w 1000 -h 450
# setwd(workDir)
#
# tbl.ds = read.csv('DESeq2-cMtx_data.csv')
#
# # loading file
# tbl.otu = read.delim('OTU_abs1e10.txt', sep='\t')
#
# tbl.otu = tbl.otu %>%
#     filter(!grepl('inf', fraction, ignore.case=T)) %>%
#     separate(fraction, into = c('BD_min','BD_max'), sep='-', convert=TRUE) %>%
#
# tbl.j = inner_join(tbl.otu, tbl.ds, c('taxon' = 'taxon'))

# %% [markdown]
# __Notes:__
#
# * The TPs (for the most part) are dramatically different in abundance between control and treatment

# %% [markdown]
# ***

# %% [markdown]
# # Sandbox

# %%
# building tree structure
from os.path import abspath
nest = nestly.Nest()

##  values
vals = [str(x) for x in range(1,5)]
nest.add('vals', vals)


## input files
nest.add('--np', [1], create_dir=False)

buildDir = '/home/nick/t/nestly/' #os.path.join(workDir, 'vals')
nest.build(buildDir)

# %%
# %%writefile /home/nick/t/example.sh
# #!/bin/bash
#
# export TIME='elapsed,maxmem,exitstatus\n%e,%M,%x'
#
# echo {--np} > {--np}_test.txt
# Out:
# Writing /home/nick/t/example.sh

# %%
# !cd /home/nick/t/; \
    chmod 777 example.sh

# %%
# !cd /home/nick/t/; \
    nestrun -j 2 --template-file example.sh -d nestly
# Out:
# 2015-06-24 12:13:25,688 * INFO * Template: ./example.sh
# 2015-06-24 12:13:25,690 * INFO * [204263] Started ./example.sh in nestly/3
# 2015-06-24 12:13:25,692 * INFO * [204264] Started ./example.sh in nestly/2
# 2015-06-24 12:13:25,692 * INFO * [204263] nestly/3 Finished with 0
# 2015-06-24 12:13:25,694 * INFO * [204265] Started ./example.sh in nestly/1
# 2015-06-24 12:13:25,694 * INFO * [204264] nestly/2 Finished with 0
# 2015-06-24 12:13:25,696 * INFO * [204266] Started ./example.sh in nestly/4
# 2015-06-24 12:13:25,696 * INFO * [204265] nestly/1 Finished with 0
# 2015-06-24 12:13:25,696 * INFO * [204266] nestly/4 Finished with 0
