# %% [markdown]
# # Goal
#
# * Follow-up to: `atomIncorp_taxaIncorp`
# * Determining the effect of 'heavy' BD window (number of windows & window sizes) on HR-SIP accuracy
# * Apply a sparsity cutoff *after* to selecting 'heavy' fraction samples
#   * In other words, taxa must be present in just most of the 'heavy' fraction sampels
#
# ### Variable parameters:
#
# * 'heavy' BD window sizes

# %% [markdown]
# ## Init

# %%
import os
import glob
import itertools
import nestly

# %%
# %load_ext rpy2.ipython
# %load_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# library(gridExtra)
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘dplyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %% [markdown]
# ### BD min/max

# %%
## min G+C cutoff
min_GC = 13.5
## max G+C cutoff
max_GC = 80
## max G+C shift
max_13C_shift_in_BD = 0.036


min_BD = min_GC/100.0 * 0.098 + 1.66    
max_BD = max_GC/100.0 * 0.098 + 1.66    

max_BD = max_BD + max_13C_shift_in_BD

print 'Min BD: {}'.format(min_BD)
print 'Max BD: {}'.format(max_BD)
# Out:
# Min BD: 1.67323
# Max BD: 1.7744

# %% [markdown]
# # Nestly
#
# * assuming fragments already simulated

# %%
# paths
workDir = '/home/nick/notebook/SIPSim/dev/bac_genome1147/'
buildDir = os.path.join(workDir, 'atomIncorp_taxaIncorp_MW-HR-SIP_postSpar')
dataDir = os.path.join(workDir, 'atomIncorp_taxaIncorp')

# %%
if not os.path.isdir(buildDir):
    os.makedirs(buildDir)
# %cd $buildDir
# Out:
# /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar

# %%
# making an experimental design file for qSIP
x = range(1,7)
y = ['control', 'treatment']

expDesignFile = os.path.join(buildDir, 'qSIP_exp_design.txt')
with open(expDesignFile, 'wb') as outFH:
    for i,z in itertools.izip(x,itertools.cycle(y)):
        line = '\t'.join([str(i),z])
        outFH.write(line + '\n')

# !head $expDesignFile
# Out:
# 1	control
# 2	treatment
# 3	control
# 4	treatment
# 5	control
# 6	treatment

# %% [markdown]
# ## Nestly params

# %%
# building tree structure
nest = nestly.Nest()

# varying params
nest.add('percIncorp', [0, 15, 25, 50, 100])
nest.add('percTaxa', [1, 5, 10, 25, 50])
nest.add('rep', range(1,11))

## set params
nest.add('abs', ['1e9'], create_dir=False)
nest.add('np', [10], create_dir=False)
nest.add('Monte_rep', [100000], create_dir=False)
nest.add('subsample_dist', ['lognormal'], create_dir=False)
nest.add('subsample_mean', [9.432], create_dir=False)
nest.add('subsample_scale', [0.5], create_dir=False)
nest.add('subsample_min', [10000], create_dir=False)
nest.add('subsample_max', [30000], create_dir=False)
nest.add('min_BD', [min_BD], create_dir=False)
nest.add('max_BD', [max_BD], create_dir=False)
nest.add('DBL_scaling', [0.5], create_dir=False)
nest.add('bandwidth', [0.8], create_dir=False)
nest.add('heavy_BD_min', [1.71], create_dir=False)
nest.add('heavy_BD_max', [1.75], create_dir=False)
nest.add('topTaxaToPlot', [100], create_dir=False)
nest.add('padj', [0.1], create_dir=False)
nest.add('log2', [0.25], create_dir=False)
nest.add('occurs', ['0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5'], create_dir=False)

### input/output files
nest.add('buildDir', [buildDir], create_dir=False)
nest.add('exp_design', [expDesignFile], create_dir=False)


# building directory tree
nest.build(buildDir)

# bash file to run
bashFile = os.path.join(buildDir, 'SIPSimRun.sh')

# %% [markdown]
# # Copying input files

# %%
files = !find . -name "*.json"
dirs = [os.path.split(x)[0] for x in files]

srcFiles = ['OTU_abs1e9_PCR_sub_w.txt', 'OTU_abs1e9_PCR_sub_meta.txt', 'BD-shift_stats.txt']

for d in dirs:
    for f in srcFiles:
        f1 = os.path.join(dataDir, d, f)
        f2 = os.path.join(buildDir, d, f)
        cmd = 'cp -f {} {}'.format(f1, f2)
        # !$cmd

# %% [markdown]
# ## Multi-window HR-SIP

# %%
bashFileTmp = os.path.splitext(bashFile)[0] + '_HRSIP_multi.sh'
bashFileTmp
# Out:
# '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/SIPSimRun_HRSIP_multi.sh'

# %%
# %%writefile $bashFileTmp
# #!/bin/bash
#
# # phyloseq
# ## making phyloseq object from OTU table
# SIPSimR phyloseq_make \
#     OTU_abs{abs}_PCR_sub_w.txt \
#     -s OTU_abs{abs}_PCR_sub_meta.txt \
#     > OTU_abs{abs}_PCR_sub.physeq
#
# ## HR SIP pipeline
# SIPSimR phyloseq_DESeq2 \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     --occur_heavy {occurs} \
#     -w 1.71-1.75 \
#     --all OTU_abs1e9_PCR_sub_MW1_all.txt \
#     OTU_abs{abs}_PCR_sub.physeq \
#     > OTU_abs1e9_PCR_sub_MW1_DESeq2
#
# SIPSimR phyloseq_DESeq2 \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     --occur_heavy {occurs} \
#     -w 1.69-1.74,1.73-1.78 \
#     --all OTU_abs1e9_PCR_sub_MW2_all.txt \
#     OTU_abs{abs}_PCR_sub.physeq \
#     > OTU_abs1e9_PCR_sub_MW2_DESeq2
#
# SIPSimR phyloseq_DESeq2 \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     --occur_heavy {occurs} \
#     -w 1.70-1.73,1.72-1.75,1.74-1.77 \
#     --all OTU_abs1e9_PCR_sub_MW3_all.txt \
#     OTU_abs{abs}_PCR_sub.physeq \
#     > OTU_abs1e9_PCR_sub_MW3_DESeq2
#
# SIPSimR phyloseq_DESeq2 \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     --occur_heavy {occurs} \
#     -w 1.69-1.73,1.72-1.76,1.75-1.79 \
#     --all OTU_abs1e9_PCR_sub_MW4_all.txt \
#     OTU_abs{abs}_PCR_sub.physeq \
#     > OTU_abs1e9_PCR_sub_MW4_DESeq2
# Out:
# Writing /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/SIPSimRun_HRSIP_multi.sh

# %%
# !chmod 777 $bashFileTmp
# !cd $workDir; \
    nestrun --template-file $bashFileTmp -d $buildDir --log-file HR-SIP_multi.log -j 10
# Out:
# 2016-04-13 15:01:09,625 * INFO * Template: ./SIPSimRun_HRSIP_multi.sh
# 2016-04-13 15:01:09,627 * INFO * [117997] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/7
# 2016-04-13 15:01:09,628 * INFO * [117998] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/9
# 2016-04-13 15:01:09,630 * INFO * [118000] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/8
# 2016-04-13 15:01:09,631 * INFO * [118002] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/3
# 2016-04-13 15:01:09,633 * INFO * [118004] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/10
# 2016-04-13 15:01:09,634 * INFO * [118006] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/2
# 2016-04-13 15:01:09,635 * INFO * [118008] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/1
# 2016-04-13 15:01:09,637 * INFO * [118010] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/4
# 2016-04-13 15:01:09,638 * INFO * [118012] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/5
# 2016-04-13 15:01:09,640 * INFO * [118015] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/6
# 2016-04-13 15:07:59,012 * INFO * [118006] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/2 Finished with 0
# 2016-04-13 15:07:59,013 * INFO * [122442] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/7
# 2016-04-13 15:08:15,723 * INFO * [117998] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/9 Finished with 0
# 2016-04-13 15:08:15,724 * INFO * [122705] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/9
# 2016-04-13 15:08:20,926 * INFO * [118012] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/5 Finished with 0
# 2016-04-13 15:08:20,928 * INFO * [122792] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/8
# 2016-04-13 15:08:22,150 * INFO * [118015] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/6 Finished with 0
# 2016-04-13 15:08:22,151 * INFO * [122817] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/3
# 2016-04-13 15:08:26,167 * INFO * [117997] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/7 Finished with 0
# 2016-04-13 15:08:26,169 * INFO * [122888] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/10
# 2016-04-13 15:08:27,156 * INFO * [118008] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/1 Finished with 0
# 2016-04-13 15:08:27,158 * INFO * [122933] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/2
# 2016-04-13 15:08:32,147 * INFO * [118004] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/10 Finished with 0
# 2016-04-13 15:08:32,149 * INFO * [123078] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/1
# 2016-04-13 15:08:35,094 * INFO * [118010] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/4 Finished with 0
# 2016-04-13 15:08:35,096 * INFO * [123137] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/4
# 2016-04-13 15:08:49,706 * INFO * [118000] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/8 Finished with 0
# 2016-04-13 15:08:49,708 * INFO * [123368] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/5
# 2016-04-13 15:08:58,735 * INFO * [118002] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/3 Finished with 0
# 2016-04-13 15:08:58,737 * INFO * [123465] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/6
# 2016-04-13 15:15:36,488 * INFO * [122792] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/8 Finished with 0
# 2016-04-13 15:15:36,490 * INFO * [126720] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/7
# 2016-04-13 15:15:54,432 * INFO * [122442] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/7 Finished with 0
# 2016-04-13 15:15:54,434 * INFO * [127049] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/9
# 2016-04-13 15:16:08,421 * INFO * [122817] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/3 Finished with 0
# 2016-04-13 15:16:08,423 * INFO * [127206] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/8
# 2016-04-13 15:16:11,133 * INFO * [123078] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/1 Finished with 0
# 2016-04-13 15:16:11,135 * INFO * [127237] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/3
# 2016-04-13 15:16:13,578 * INFO * [122888] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/10 Finished with 0
# 2016-04-13 15:16:13,585 * INFO * [127292] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/10
# 2016-04-13 15:16:14,331 * INFO * [122933] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/2 Finished with 0
# 2016-04-13 15:16:14,333 * INFO * [127317] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/2
# 2016-04-13 15:16:24,189 * INFO * [122705] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/9 Finished with 0
# 2016-04-13 15:16:24,191 * INFO * [127467] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/1
# 2016-04-13 15:16:29,047 * INFO * [123137] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/4 Finished with 0
# 2016-04-13 15:16:29,060 * INFO * [127568] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/4
# 2016-04-13 15:16:35,869 * INFO * [123368] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/5 Finished with 0
# 2016-04-13 15:16:35,871 * INFO * [127635] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/5
# 2016-04-13 15:16:42,188 * INFO * [123465] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/6 Finished with 0
# 2016-04-13 15:16:42,190 * INFO * [128276] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/6
# 2016-04-13 15:24:23,416 * INFO * [127206] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/8 Finished with 0
# 2016-04-13 15:24:23,418 * INFO * [131500] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/7
# 2016-04-13 15:24:55,074 * INFO * [126720] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/7 Finished with 0
# 2016-04-13 15:24:55,080 * INFO * [131794] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/9
# 2016-04-13 15:24:58,437 * INFO * [127237] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/3 Finished with 0
# 2016-04-13 15:24:58,444 * INFO * [131831] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/8
# 2016-04-13 15:25:10,980 * INFO * [127049] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/9 Finished with 0
# 2016-04-13 15:25:10,983 * INFO * [132064] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/3
# 2016-04-13 15:25:17,977 * INFO * [127292] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/10 Finished with 0
# 2016-04-13 15:25:17,984 * INFO * [132137] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/10
# **OUTPUT MUTED**

# %%
# %pushnote postSpar MW-HR-SIP complete

# %% [markdown]
# ## Making confusion matrices

# %%
bashFileTmp = os.path.splitext(bashFile)[0] + '_cMtx.sh'
bashFileTmp
# Out:
# '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/SIPSimRun_cMtx.sh'

# %%
# %%writefile $bashFileTmp
# #!/bin/bash
#
# # HR-SIP multiple 'heavy' BD windows
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_MW1-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_MW1_DESeq2
#
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_MW2-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_MW2_DESeq2
#
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_MW3-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_MW3_DESeq2
#
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_MW4-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_MW4_DESeq2
# Out:
# Writing /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/SIPSimRun_cMtx.sh

# %%
# !chmod 777 $bashFileTmp
# !cd $workDir; \
    nestrun --template-file $bashFileTmp -d $buildDir --log-file cMtx.log -j 10
# Out:
# 2016-04-13 18:53:21,271 * INFO * Template: ./SIPSimRun_cMtx.sh
# 2016-04-13 18:53:21,273 * INFO * [237520] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/7
# 2016-04-13 18:53:21,275 * INFO * [237521] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/9
# 2016-04-13 18:53:21,277 * INFO * [237523] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/8
# 2016-04-13 18:53:21,279 * INFO * [237525] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/3
# 2016-04-13 18:53:21,280 * INFO * [237527] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/10
# 2016-04-13 18:53:21,287 * INFO * [237529] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/2
# 2016-04-13 18:53:21,289 * INFO * [237532] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/1
# 2016-04-13 18:53:21,291 * INFO * [237533] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/4
# 2016-04-13 18:53:21,294 * INFO * [237535] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/5
# 2016-04-13 18:53:21,296 * INFO * [237537] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/6
# 2016-04-13 18:53:40,748 * INFO * [237527] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/10 Finished with 0
# 2016-04-13 18:53:40,750 * INFO * [239283] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/7
# 2016-04-13 18:53:40,838 * INFO * [237535] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/5 Finished with 0
# 2016-04-13 18:53:40,844 * INFO * [239293] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/9
# 2016-04-13 18:53:40,882 * INFO * [237529] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/2 Finished with 0
# 2016-04-13 18:53:40,888 * INFO * [239301] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/8
# 2016-04-13 18:53:41,062 * INFO * [237533] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/4 Finished with 0
# 2016-04-13 18:53:41,064 * INFO * [239309] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/3
# 2016-04-13 18:53:41,068 * INFO * [237523] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/8 Finished with 0
# 2016-04-13 18:53:41,070 * INFO * [239311] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/10
# 2016-04-13 18:53:41,110 * INFO * [237520] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/7 Finished with 0
# 2016-04-13 18:53:41,113 * INFO * [239313] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/2
# 2016-04-13 18:53:41,264 * INFO * [237537] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/6 Finished with 0
# 2016-04-13 18:53:41,266 * INFO * [239333] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/1
# 2016-04-13 18:53:41,267 * INFO * [237521] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/9 Finished with 0
# 2016-04-13 18:53:41,271 * INFO * [239343] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/4
# 2016-04-13 18:53:41,565 * INFO * [237532] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/1 Finished with 0
# 2016-04-13 18:53:41,567 * INFO * [239404] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/5
# 2016-04-13 18:53:41,700 * INFO * [237525] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/50/3 Finished with 0
# 2016-04-13 18:53:41,703 * INFO * [239441] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/6
# 2016-04-13 18:54:00,020 * INFO * [239283] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/7 Finished with 0
# 2016-04-13 18:54:00,022 * INFO * [241016] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/7
# 2016-04-13 18:54:00,372 * INFO * [239293] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/9 Finished with 0
# 2016-04-13 18:54:00,384 * INFO * [241045] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/9
# 2016-04-13 18:54:00,566 * INFO * [239313] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/2 Finished with 0
# 2016-04-13 18:54:00,568 * INFO * [241070] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/8
# 2016-04-13 18:54:00,878 * INFO * [239301] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/8 Finished with 0
# 2016-04-13 18:54:00,880 * INFO * [241095] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/3
# 2016-04-13 18:54:00,901 * INFO * [239333] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/1 Finished with 0
# 2016-04-13 18:54:00,907 * INFO * [241113] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/10
# 2016-04-13 18:54:01,057 * INFO * [239309] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/3 Finished with 0
# 2016-04-13 18:54:01,058 * INFO * [241135] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/2
# 2016-04-13 18:54:01,219 * INFO * [239311] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/10 Finished with 0
# 2016-04-13 18:54:01,222 * INFO * [241150] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/1
# 2016-04-13 18:54:01,246 * INFO * [239404] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/5 Finished with 0
# 2016-04-13 18:54:01,248 * INFO * [241155] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/4
# 2016-04-13 18:54:01,340 * INFO * [239441] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/6 Finished with 0
# 2016-04-13 18:54:01,343 * INFO * [241184] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/5
# 2016-04-13 18:54:01,732 * INFO * [239343] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/25/4 Finished with 0
# 2016-04-13 18:54:01,734 * INFO * [241245] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/6
# 2016-04-13 18:54:20,071 * INFO * [241045] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/9 Finished with 0
# 2016-04-13 18:54:20,073 * INFO * [242790] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/7
# 2016-04-13 18:54:20,123 * INFO * [241016] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/7 Finished with 0
# 2016-04-13 18:54:20,125 * INFO * [242802] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/9
# 2016-04-13 18:54:20,149 * INFO * [241070] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/8 Finished with 0
# 2016-04-13 18:54:20,156 * INFO * [242805] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/8
# 2016-04-13 18:54:20,426 * INFO * [241095] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/3 Finished with 0
# 2016-04-13 18:54:20,428 * INFO * [242827] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/3
# 2016-04-13 18:54:20,618 * INFO * [241150] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/1 Finished with 0
# 2016-04-13 18:54:20,620 * INFO * [242893] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/10
# 2016-04-13 18:54:20,686 * INFO * [241113] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/10/10 Finished with 0
# 2016-04-13 18:54:20,687 * INFO * [242899] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/50/1/2
# **OUTPUT MUTED**

# %% [markdown]
# ### Aggregating the confusion matrix data

# %%
def agg_cMtx(prefix):
    # all data
    #!nestagg delim \
    #    -d $buildDir \
    #    -k percIncorp,percTaxa,rep \
    #    -o $prefix-cMtx_data.txt \
    #    --tab \
    #    $prefix-cMtx_data.txt

    # overall
    x = prefix + '-cMtx_overall.txt'
    # !nestagg delim \
        -d $buildDir \
        -k percIncorp,percTaxa,rep \
        -o $x \
        --tab \
        $x

    # by class
    x = prefix + '-cMtx_byClass.txt'
    # !nestagg delim \
        -d $buildDir \
        -k percIncorp,percTaxa,rep \
        -o $x \
        --tab \
        $x
        
agg_cMtx('DESeq2_MW1')
agg_cMtx('DESeq2_MW2')
agg_cMtx('DESeq2_MW3')
agg_cMtx('DESeq2_MW4')

# %%
# %pushnote postSpar MW-HR-SIP run complete!

# %% [markdown]
# ***
# # --End of simulation--#
# ***

# %% [markdown]
# # Plotting results

# %%
F = os.path.join(buildDir, '*-cMtx_byClass.txt')
files = glob.glob(F)
files
# Out:
# ['/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/DESeq2_MW1-cMtx_byClass.txt',
#  '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/DESeq2_MW3-cMtx_byClass.txt',
#  '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/DESeq2_MW4-cMtx_byClass.txt',
#  '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP_postSpar/DESeq2_MW2-cMtx_byClass.txt']

# %%
# %%R -i files
#
# df_byClass = list()
# for (f in files){
#     ff = strsplit(f, '/') %>% unlist
#     fff = ff[length(ff)]
#     df_byClass[[fff]] = read.delim(f, sep='\t')
# }
#
# df_byClass = do.call(rbind, df_byClass)
# df_byClass$file = gsub('\\.[0-9]+$', '', rownames(df_byClass))
# df_byClass$method = gsub('-cMtx.+', '', df_byClass$file)
# rownames(df_byClass) = 1:nrow(df_byClass)
#
# df_byClass %>% head(n=3)
# Out:
#   library      variables values percIncorp percTaxa rep
# 1       2    Sensitivity   0.45         50       50   7
# 2       2    Specificity   1.00         50       50   7
# 3       2 Pos Pred Value   1.00         50       50   7
#                          file     method
# 1 DESeq2_MW1-cMtx_byClass.txt DESeq2_MW1
# 2 DESeq2_MW1-cMtx_byClass.txt DESeq2_MW1
# 3 DESeq2_MW1-cMtx_byClass.txt DESeq2_MW1

# %%
# %%R
# # renaming method
# rename = data.frame(method = c('DESeq2_MW1', 'DESeq2_MW2', 'DESeq2_MW3', 'DESeq2_MW4'),
#                     method_new = c('1.71-1.75',
#                                    '1.69-1.74,1.73-1.78',
#                                    '1.70-1.73,1.72-1.75,1.74-1.77',
#                                    '1.69-1.73,1.72-1.76,1.75-1.79'))
#
# df_byClass = inner_join(df_byClass, rename, c('method'='method')) %>%
#     select(-method) %>%
#     rename('method' = method_new)
#
# df_byClass$method = factor(df_byClass$method, levels=rename$method_new %>% as.vector)
#
# df_byClass %>% head(n=3)
# Out:
#   library      variables values percIncorp percTaxa rep
# 1       2    Sensitivity   0.45         50       50   7
# 2       2    Specificity   1.00         50       50   7
# 3       2 Pos Pred Value   1.00         50       50   7
#                          file    method
# 1 DESeq2_MW1-cMtx_byClass.txt 1.71-1.75
# 2 DESeq2_MW1-cMtx_byClass.txt 1.71-1.75
# 3 DESeq2_MW1-cMtx_byClass.txt 1.71-1.75

# %%
# %%R -w 800 -h 550
# # summarize by SIPSim rep & library rep
# df_byClass.s = df_byClass %>%
#     group_by(method, percIncorp, percTaxa, variables) %>%
#     summarize(mean_value = mean(values),
#               sd_value = sd(values))
#
# # plotting
# ggplot(df_byClass.s, aes(variables, mean_value, color=method,
#                          ymin=mean_value-sd_value,
#                          ymax=mean_value+sd_value)) +
#     geom_pointrange(alpha=0.8, size=0.2) +
#     labs(y='Value') +
#     facet_grid(percTaxa ~ percIncorp) +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.title.x = element_blank(),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R -w 850 -h 600
# # summarize by SIPSim rep & library rep
# vars = c('Balanced Accuracy', 'Sensitivity', 'Specificity')
# df_byClass.s.f = df_byClass.s %>%
#     filter(variables %in% vars)
#
# # plotting
# ggplot(df_byClass.s.f, aes(variables, mean_value, fill=method,
#                          ymin=mean_value-sd_value,
#                          ymax=mean_value+sd_value)) +
#     #geom_pointrange(alpha=0.8, size=0.2) +
#     geom_bar(stat='identity', position='dodge', width=0.8) +
#     geom_errorbar(stat='identity', position='dodge', width=0.8) +
#     scale_y_continuous(breaks=seq(0, 1, 0.2)) +
#     scale_fill_discrete('"Heavy" BD window(s)') +
#     facet_grid(percTaxa ~ percIncorp) +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.title.x = element_blank(),
#         axis.text.x = element_text(angle=45, hjust=1),
#         axis.title.y = element_blank()
#     )
