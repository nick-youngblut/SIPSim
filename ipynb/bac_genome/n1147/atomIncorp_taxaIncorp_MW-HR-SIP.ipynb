# %% [markdown]
# # Goal
#
# * Follow-up to: `atomIncorp_taxaIncorp`
# * Determining the effect of 'heavy' BD window (number of windows & window sizes) on HR-SIP accuracy
#
# ### Variable parameters:
#
# * 'heavy' BD window sizes

# %% [markdown]
# ## Init

# %%
import os
import glob
import itertools
import nestly

# %%
# %load_ext rpy2.ipython
# %load_ext pushnote
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The pushnote extension is already loaded. To reload it, use:
#   %reload_ext pushnote

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# library(gridExtra)

# %% [markdown]
# ### BD min/max

# %%
## min G+C cutoff
min_GC = 13.5
## max G+C cutoff
max_GC = 80
## max G+C shift
max_13C_shift_in_BD = 0.036


min_BD = min_GC/100.0 * 0.098 + 1.66    
max_BD = max_GC/100.0 * 0.098 + 1.66    

max_BD = max_BD + max_13C_shift_in_BD

print 'Min BD: {}'.format(min_BD)
print 'Max BD: {}'.format(max_BD)
# Out:
# Min BD: 1.67323
# Max BD: 1.7744

# %% [markdown]
# # Nestly
#
# * assuming fragments already simulated

# %%
# paths
workDir = '/home/nick/notebook/SIPSim/dev/bac_genome1147/'
buildDir = os.path.join(workDir, 'atomIncorp_taxaIncorp_MW-HR-SIP')
dataDir = os.path.join(workDir, 'atomIncorp_taxaIncorp')

# %%
if not os.path.isdir(buildDir):
    os.makedirs(buildDir)
# %cd $buildDir
# Out:
# /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP

# %%
# making an experimental design file for qSIP
x = range(1,7)
y = ['control', 'treatment']

expDesignFile = os.path.join(buildDir, 'qSIP_exp_design.txt')
with open(expDesignFile, 'wb') as outFH:
    for i,z in itertools.izip(x,itertools.cycle(y)):
        line = '\t'.join([str(i),z])
        outFH.write(line + '\n')

# !head $expDesignFile
# Out:
# 1	control
# 2	treatment
# 3	control
# 4	treatment
# 5	control
# 6	treatment

# %% [markdown]
# ## Nestly params

# %%
# building tree structure
nest = nestly.Nest()


# varying params
nest.add('percIncorp', [0, 15, 25, 50, 100])
nest.add('percTaxa', [1, 5, 10, 25, 50])
nest.add('rep', range(1,11))

## set params
nest.add('abs', ['1e9'], create_dir=False)
nest.add('np', [10], create_dir=False)
nest.add('Monte_rep', [100000], create_dir=False)
nest.add('subsample_dist', ['lognormal'], create_dir=False)
nest.add('subsample_mean', [9.432], create_dir=False)
nest.add('subsample_scale', [0.5], create_dir=False)
nest.add('subsample_min', [10000], create_dir=False)
nest.add('subsample_max', [30000], create_dir=False)
nest.add('min_BD', [min_BD], create_dir=False)
nest.add('max_BD', [max_BD], create_dir=False)
nest.add('DBL_scaling', [0.5], create_dir=False)
nest.add('bandwidth', [0.8], create_dir=False)
nest.add('heavy_BD_min', [1.71], create_dir=False)
nest.add('heavy_BD_max', [1.75], create_dir=False)
nest.add('topTaxaToPlot', [100], create_dir=False)
nest.add('padj', [0.1], create_dir=False)
nest.add('log2', [0.25], create_dir=False)

### input/output files
nest.add('buildDir', [buildDir], create_dir=False)
nest.add('exp_design', [expDesignFile], create_dir=False)


# building directory tree
nest.build(buildDir)

# bash file to run
bashFile = os.path.join(buildDir, 'SIPSimRun.sh')

# %% [markdown]
# # Copying input files

# %%
files = !find . -name "*.json"
dirs = [os.path.split(x)[0] for x in files]

srcFiles = ['OTU_abs1e9_PCR_sub_w.txt', 'OTU_abs1e9_PCR_sub_meta.txt', 'BD-shift_stats.txt']

for d in dirs:
    for f in srcFiles:
        f1 = os.path.join(dataDir, d, f)
        f2 = os.path.join(buildDir, d, f)
        cmd = 'cp -f {} {}'.format(f1, f2)
        # !$cmd

# %% [markdown]
# ## Multi-window HR-SIP

# %%
bashFileTmp = os.path.splitext(bashFile)[0] + '_HRSIP_multi.sh'
bashFileTmp
# Out:
# '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/SIPSimRun_HRSIP_multi.sh'

# %%
# %%writefile $bashFileTmp
# #!/bin/bash
#
# # phyloseq
# ## making phyloseq object from OTU table
# SIPSimR phyloseq_make \
#     OTU_abs{abs}_PCR_sub_w.txt \
#     -s OTU_abs{abs}_PCR_sub_meta.txt \
#     > OTU_abs{abs}_PCR_sub.physeq
#
# ## HR SIP pipeline
# SIPSim HRSIP \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     -w 1.71-1.75 \
#     --prefix OTU_abs{abs}_PCR_sub_BD3-1 \
#     OTU_abs{abs}_PCR_sub.physeq
#
# ## HR SIP pipeline
# SIPSim HRSIP \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     -w 1.69-1.74,1.73-1.78 \
#     --prefix OTU_abs{abs}_PCR_sub_BD3-2 \
#     OTU_abs{abs}_PCR_sub.physeq
#
# SIPSim HRSIP \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     -w 1.70-1.73,1.72-1.75,1.74-1.77 \
#     --prefix OTU_abs{abs}_PCR_sub_BD3-3 \
#     OTU_abs{abs}_PCR_sub.physeq
#
# SIPSim HRSIP \
#     --log2 {log2} \
#     --hypo greater \
#     --cont 1,3,5 \
#     --treat 2,4,6 \
#     -w 1.69-1.73,1.72-1.76,1.75-1.79 \
#     --prefix OTU_abs{abs}_PCR_sub_BD3-4 \
#     OTU_abs{abs}_PCR_sub.physeq
# Out:
# Writing /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/SIPSimRun_HRSIP_multi.sh

# %%
# !chmod 777 $bashFileTmp
# !cd $workDir; \
    nestrun --template-file $bashFileTmp -d $buildDir --log-file HR-SIP_multi.log -j 10
# Out:
# 2016-04-06 17:44:56,904 * INFO * Template: ./SIPSimRun_HRSIP_multi.sh
# 2016-04-06 17:44:56,906 * INFO * [117413] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/7
# 2016-04-06 17:44:56,908 * INFO * [117414] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/9
# 2016-04-06 17:44:56,910 * INFO * [117416] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/8
# 2016-04-06 17:44:56,914 * INFO * [117418] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/3
# 2016-04-06 17:44:56,922 * INFO * [117421] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/10
# 2016-04-06 17:44:56,924 * INFO * [117423] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/2
# 2016-04-06 17:44:56,926 * INFO * [117424] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/1
# 2016-04-06 17:44:56,928 * INFO * [117425] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/4
# 2016-04-06 17:44:56,932 * INFO * [117428] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/5
# 2016-04-06 17:44:56,934 * INFO * [117430] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/6
# 2016-04-06 17:49:39,574 * INFO * [117424] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/1 Finished with 0
# 2016-04-06 17:49:39,577 * INFO * [122607] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/7
# 2016-04-06 17:49:45,462 * INFO * [117414] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/9 Finished with 0
# 2016-04-06 17:49:45,468 * INFO * [122703] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/9
# 2016-04-06 17:49:48,792 * INFO * [117423] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/2 Finished with 0
# 2016-04-06 17:49:48,796 * INFO * [122757] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/8
# 2016-04-06 17:49:50,496 * INFO * [117430] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/6 Finished with 0
# 2016-04-06 17:49:50,503 * INFO * [122788] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/3
# 2016-04-06 17:49:52,122 * INFO * [117428] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/5 Finished with 0
# 2016-04-06 17:49:52,128 * INFO * [122840] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/10
# 2016-04-06 17:49:55,604 * INFO * [117413] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/7 Finished with 0
# 2016-04-06 17:49:55,612 * INFO * [122935] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/2
# 2016-04-06 17:49:58,078 * INFO * [117418] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/3 Finished with 0
# 2016-04-06 17:49:58,080 * INFO * [122985] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/1
# 2016-04-06 17:49:59,583 * INFO * [117421] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/10 Finished with 0
# 2016-04-06 17:49:59,585 * INFO * [123057] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/4
# 2016-04-06 17:49:59,894 * INFO * [117425] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/4 Finished with 0
# 2016-04-06 17:49:59,896 * INFO * [123072] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/5
# 2016-04-06 17:50:00,823 * INFO * [117416] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/8 Finished with 0
# 2016-04-06 17:50:00,828 * INFO * [123122] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/6
# 2016-04-06 17:54:34,033 * INFO * [122607] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/7 Finished with 0
# 2016-04-06 17:54:34,036 * INFO * [127660] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/7
# 2016-04-06 17:54:37,061 * INFO * [122840] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/10 Finished with 0
# 2016-04-06 17:54:37,063 * INFO * [127711] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/9
# 2016-04-06 17:54:38,896 * INFO * [122935] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/2 Finished with 0
# 2016-04-06 17:54:38,898 * INFO * [127745] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/8
# 2016-04-06 17:54:39,543 * INFO * [122757] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/8 Finished with 0
# 2016-04-06 17:54:39,548 * INFO * [127770] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/3
# 2016-04-06 17:54:47,233 * INFO * [123057] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/4 Finished with 0
# 2016-04-06 17:54:47,235 * INFO * [127947] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/10
# 2016-04-06 17:54:47,240 * INFO * [122788] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/3 Finished with 0
# 2016-04-06 17:54:47,242 * INFO * [127949] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/2
# 2016-04-06 17:54:47,494 * INFO * [122703] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/9 Finished with 0
# 2016-04-06 17:54:47,496 * INFO * [127955] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/1
# 2016-04-06 17:54:50,795 * INFO * [122985] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/1 Finished with 0
# 2016-04-06 17:54:50,798 * INFO * [128097] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/4
# 2016-04-06 17:54:52,754 * INFO * [123122] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/6 Finished with 0
# 2016-04-06 17:54:52,756 * INFO * [128189] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/5
# 2016-04-06 17:54:56,588 * INFO * [123072] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/5 Finished with 0
# 2016-04-06 17:54:56,590 * INFO * [128255] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/6
# 2016-04-06 17:59:03,949 * INFO * [127660] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/7 Finished with 0
# 2016-04-06 17:59:03,951 * INFO * [132552] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/7
# 2016-04-06 17:59:12,949 * INFO * [127745] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/8 Finished with 0
# 2016-04-06 17:59:12,951 * INFO * [132712] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/9
# 2016-04-06 17:59:20,513 * INFO * [128097] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/4 Finished with 0
# 2016-04-06 17:59:20,516 * INFO * [132855] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/8
# 2016-04-06 17:59:23,193 * INFO * [127711] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/9 Finished with 0
# 2016-04-06 17:59:23,195 * INFO * [132919] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/3
# 2016-04-06 17:59:23,258 * INFO * [127770] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/3 Finished with 0
# 2016-04-06 17:59:23,264 * INFO * [132921] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/10
# 2016-04-06 17:59:23,730 * INFO * [128255] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/6 Finished with 0
# 2016-04-06 17:59:23,732 * INFO * [132952] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/2
# 2016-04-06 17:59:24,374 * INFO * [127955] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/1 Finished with 0
# 2016-04-06 17:59:24,376 * INFO * [133006] Started ./SIPSimRun_HRSIP_multi.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/1
# **OUTPUT MUTED**

# %%
# %pushnote HR-SIP multi window complete

# %% [markdown]
# ## Making confusion matrices

# %%
bashFileTmp = os.path.splitext(bashFile)[0] + '_cMtx.sh'
bashFileTmp
# Out:
# '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/SIPSimRun_cMtx.sh'

# %%
# %%writefile $bashFileTmp
# #!/bin/bash
#
# # HR-SIP multiple 'heavy' BD windows
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_BD3-1-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_BD3-1_DESeq2
#
#
# # HR-SIP multiple 'heavy' BD windows
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_BD3-2-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_BD3-2_DESeq2
#
# # HR-SIP multiple 'heavy' BD windows
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_BD3-3-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_BD3-3_DESeq2
#
# # HR-SIP multiple 'heavy' BD windows
# SIPSimR DESeq2_confuseMtx \
#     --libs 2,4,6 \
#     --padj {padj} \
#     -o DESeq2_BD3-4-cMtx \
#     BD-shift_stats.txt \
#     OTU_abs1e9_PCR_sub_BD3-4_DESeq2
# Out:
# Writing /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/SIPSimRun_cMtx.sh

# %%
# !chmod 777 $bashFileTmp
# !cd $workDir; \
    nestrun --template-file $bashFileTmp -d $buildDir --log-file cMtx.log -j 10
# Out:
# 2016-04-06 19:47:36,994 * INFO * Template: ./SIPSimRun_cMtx.sh
# 2016-04-06 19:47:36,996 * INFO * [7461] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/7
# 2016-04-06 19:47:36,999 * INFO * [7462] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/9
# 2016-04-06 19:47:37,000 * INFO * [7464] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/8
# 2016-04-06 19:47:37,004 * INFO * [7466] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/3
# 2016-04-06 19:47:37,020 * INFO * [7468] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/10
# 2016-04-06 19:47:37,023 * INFO * [7470] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/2
# 2016-04-06 19:47:37,030 * INFO * [7473] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/1
# 2016-04-06 19:47:37,039 * INFO * [7475] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/4
# 2016-04-06 19:47:37,047 * INFO * [7477] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/5
# 2016-04-06 19:47:37,055 * INFO * [7479] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/6
# 2016-04-06 19:48:05,819 * INFO * [7475] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/4 Finished with 0
# 2016-04-06 19:48:05,822 * INFO * [8432] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/7
# 2016-04-06 19:48:06,212 * INFO * [7464] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/8 Finished with 0
# 2016-04-06 19:48:06,215 * INFO * [8438] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/9
# 2016-04-06 19:48:06,215 * INFO * [7462] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/9 Finished with 0
# 2016-04-06 19:48:06,217 * INFO * [8439] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/8
# 2016-04-06 19:48:07,316 * INFO * [7461] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/7 Finished with 0
# 2016-04-06 19:48:07,318 * INFO * [8501] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/3
# 2016-04-06 19:48:08,076 * INFO * [7473] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/1 Finished with 0
# 2016-04-06 19:48:08,078 * INFO * [8520] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/10
# 2016-04-06 19:48:08,134 * INFO * [7466] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/3 Finished with 0
# 2016-04-06 19:48:08,140 * INFO * [8522] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/2
# 2016-04-06 19:48:08,968 * INFO * [7468] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/10 Finished with 0
# 2016-04-06 19:48:08,970 * INFO * [8560] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/1
# 2016-04-06 19:48:08,987 * INFO * [7477] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/5 Finished with 0
# 2016-04-06 19:48:08,989 * INFO * [8562] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/4
# 2016-04-06 19:48:09,971 * INFO * [7470] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/2 Finished with 0
# 2016-04-06 19:48:09,974 * INFO * [8624] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/5
# 2016-04-06 19:48:10,371 * INFO * [7479] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/50/6 Finished with 0
# 2016-04-06 19:48:10,373 * INFO * [8665] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/6
# 2016-04-06 19:48:35,828 * INFO * [8438] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/9 Finished with 0
# 2016-04-06 19:48:35,840 * INFO * [9442] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/7
# 2016-04-06 19:48:36,391 * INFO * [8439] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/8 Finished with 0
# 2016-04-06 19:48:36,412 * INFO * [9466] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/9
# 2016-04-06 19:48:37,480 * INFO * [8432] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/7 Finished with 0
# 2016-04-06 19:48:37,484 * INFO * [9510] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/8
# 2016-04-06 19:48:37,848 * INFO * [8560] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/1 Finished with 0
# 2016-04-06 19:48:37,856 * INFO * [9520] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/3
# 2016-04-06 19:48:38,789 * INFO * [8520] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/10 Finished with 0
# 2016-04-06 19:48:38,794 * INFO * [9562] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/10
# 2016-04-06 19:48:39,228 * INFO * [8501] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/3 Finished with 0
# 2016-04-06 19:48:39,232 * INFO * [9579] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/2
# 2016-04-06 19:48:40,368 * INFO * [8522] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/2 Finished with 0
# 2016-04-06 19:48:40,376 * INFO * [9624] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/1
# 2016-04-06 19:48:41,014 * INFO * [8624] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/5 Finished with 0
# 2016-04-06 19:48:41,017 * INFO * [9639] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/4
# 2016-04-06 19:48:41,545 * INFO * [8562] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/4 Finished with 0
# 2016-04-06 19:48:41,556 * INFO * [9662] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/5
# 2016-04-06 19:48:42,596 * INFO * [8665] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/25/6 Finished with 0
# 2016-04-06 19:48:42,604 * INFO * [9687] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/6
# 2016-04-06 19:49:10,772 * INFO * [9442] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/7 Finished with 0
# 2016-04-06 19:49:10,784 * INFO * [10430] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/7
# 2016-04-06 19:49:10,873 * INFO * [9510] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/8 Finished with 0
# 2016-04-06 19:49:10,896 * INFO * [10443] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/9
# 2016-04-06 19:49:11,427 * INFO * [9466] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/9 Finished with 0
# 2016-04-06 19:49:11,429 * INFO * [10474] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/8
# 2016-04-06 19:49:12,940 * INFO * [9579] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/2 Finished with 0
# 2016-04-06 19:49:12,952 * INFO * [10516] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/3
# 2016-04-06 19:49:13,504 * INFO * [9520] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/3 Finished with 0
# 2016-04-06 19:49:13,516 * INFO * [10531] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/10
# 2016-04-06 19:49:14,227 * INFO * [9562] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/10 Finished with 0
# 2016-04-06 19:49:14,230 * INFO * [10556] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/2
# 2016-04-06 19:49:14,586 * INFO * [9624] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/1 Finished with 0
# 2016-04-06 19:49:14,588 * INFO * [10566] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/1
# 2016-04-06 19:49:15,328 * INFO * [9662] /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/10/5 Finished with 0
# 2016-04-06 19:49:15,330 * INFO * [10604] Started ./SIPSimRun_cMtx.sh in /home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/50/1/4
# **OUTPUT MUTED**

# %% [markdown]
# ### Aggregating the confusion matrix data

# %%
def agg_cMtx(prefix):
    # all data
    #!nestagg delim \
    #    -d $buildDir \
    #    -k percIncorp,percTaxa,rep \
    #    -o $prefix-cMtx_data.txt \
    #    --tab \
    #    $prefix-cMtx_data.txt

    # overall
    x = prefix + '-cMtx_overall.txt'
    # !nestagg delim \
        -d $buildDir \
        -k percIncorp,percTaxa,rep \
        -o $x \
        --tab \
        $x

    # by class
    x = prefix + '-cMtx_byClass.txt'
    # !nestagg delim \
        -d $buildDir \
        -k percIncorp,percTaxa,rep \
        -o $x \
        --tab \
        $x
        
agg_cMtx('DESeq2_BD3-1')
agg_cMtx('DESeq2_BD3-2')
agg_cMtx('DESeq2_BD3-3')
agg_cMtx('DESeq2_BD3-4')

# %%
# %pushnote MW-HR-SIP complete!

# %% [markdown]
# ***
# # --End of simulation--#
# ***

# %% [markdown]
# # Plotting results

# %%
F = os.path.join(buildDir, '*-cMtx_byClass.txt')
files = glob.glob(F)
files
# Out:
# ['/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/DESeq2_BD3-4-cMtx_byClass.txt',
#  '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/DESeq2_BD3-2-cMtx_byClass.txt',
#  '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/DESeq2_BD3-1-cMtx_byClass.txt',
#  '/home/nick/notebook/SIPSim/dev/bac_genome1147/atomIncorp_taxaIncorp_MW-HR-SIP/DESeq2_BD3-3-cMtx_byClass.txt']

# %%
# %%R -i files
#
# df_byClass = list()
# for (f in files){
#     ff = strsplit(f, '/') %>% unlist
#     fff = ff[length(ff)]
#     df_byClass[[fff]] = read.delim(f, sep='\t')
# }
#
# df_byClass = do.call(rbind, df_byClass)
# df_byClass$file = gsub('\\.[0-9]+$', '', rownames(df_byClass))
# df_byClass$method = gsub('-cMtx.+', '', df_byClass$file)
# rownames(df_byClass) = 1:nrow(df_byClass)
#
# df_byClass %>% head(n=3)
# Out:
#   library      variables    values percIncorp percTaxa rep
# 1       2    Sensitivity 0.6732673         50       50   7
# 2       2    Specificity 1.0000000         50       50   7
# 3       2 Pos Pred Value 1.0000000         50       50   7
#                            file       method
# 1 DESeq2_BD3-4-cMtx_byClass.txt DESeq2_BD3-4
# 2 DESeq2_BD3-4-cMtx_byClass.txt DESeq2_BD3-4
# 3 DESeq2_BD3-4-cMtx_byClass.txt DESeq2_BD3-4

# %%
# %%R
# # renaming method
# rename = data.frame(method = c('DESeq2_BD3-1', 'DESeq2_BD3-2', 'DESeq2_BD3-3', 'DESeq2_BD3-4'),
#                    method_new = c('1.71-1.75','1.69-1.74,1.73-1.78',
#                                   '1.70-1.73,1.72-1.75,1.74-1.77',
#                                   '1.69-1.73,1.72-1.76,1.75-1.79'))
#
# df_byClass = inner_join(df_byClass, rename, c('method'='method')) %>%
#     select(-method) %>%
#     rename('method' = method_new)
#
# df_byClass$method = factor(df_byClass$method, levels=rename$method_new %>% as.vector)
#
# df_byClass %>% head(n=3)
# Out:
#   library      variables    values percIncorp percTaxa rep
# 1       2    Sensitivity 0.6732673         50       50   7
# 2       2    Specificity 1.0000000         50       50   7
# 3       2 Pos Pred Value 1.0000000         50       50   7
#                            file                        method
# 1 DESeq2_BD3-4-cMtx_byClass.txt 1.69-1.73,1.72-1.76,1.75-1.79
# 2 DESeq2_BD3-4-cMtx_byClass.txt 1.69-1.73,1.72-1.76,1.75-1.79
# 3 DESeq2_BD3-4-cMtx_byClass.txt 1.69-1.73,1.72-1.76,1.75-1.79

# %%
# %%R -w 800 -h 550
# # summarize by SIPSim rep & library rep
# df_byClass.s = df_byClass %>%
#     group_by(method, percIncorp, percTaxa, variables) %>%
#     summarize(mean_value = mean(values),
#               sd_value = sd(values))
#
# # plotting
# ggplot(df_byClass.s, aes(variables, mean_value, color=method,
#                          ymin=mean_value-sd_value,
#                          ymax=mean_value+sd_value)) +
#     geom_pointrange(alpha=0.8, size=0.2) +
#     labs(y='Value') +
#     facet_grid(percTaxa ~ percIncorp) +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.title.x = element_blank(),
#         axis.text.x = element_text(angle=45, hjust=1)
#     )

# %%
# %%R -w 800 -h 600
# # summarize by SIPSim rep & library rep
# vars = c('Balanced Accuracy', 'Sensitivity', 'Specificity')
# df_byClass.s.f = df_byClass.s %>%
#     filter(variables %in% vars)
#
# # plotting
# ggplot(df_byClass.s.f, aes(variables, mean_value, fill=method,
#                          ymin=mean_value-sd_value,
#                          ymax=mean_value+sd_value)) +
#     #geom_pointrange(alpha=0.8, size=0.2) +
#     geom_bar(stat='identity', position='dodge') +
#     geom_errorbar(stat='identity', position='dodge') +
#     scale_y_continuous(breaks=seq(0, 1, 0.2)) +
#     facet_grid(percTaxa ~ percIncorp) +
#     theme_bw() +
#     theme(
#         text = element_text(size=16),
#         axis.title.x = element_blank(),
#         axis.text.x = element_text(angle=45, hjust=1),
#         axis.title.y = element_blank()
#     )
