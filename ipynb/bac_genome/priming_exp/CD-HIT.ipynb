# %% [markdown]
# # Goal:
#
# * Running CD-HIT priming_exp OTUs & bac_genome1210 16S rRNA gene dataset
#   * cutoff 97% seqID
#   * ID OTUs with taxa from both datasets
#     * target genomes

# %% [markdown]
# # User variables

# %%
baseDir = '/home/nick/notebook/SIPSim/dev/priming_exp/'
workDir = os.path.join(baseDir, 'CD-HIT')
rnammerDir = '/home/nick/notebook/SIPSim/dev/bac_genome1210/rnammer/'
otuRepFile = '/var/seq_data/priming_exp/otusn.pick.fasta'
otuTaxFile = '/var/seq_data/priming_exp/otusn_tax/otusn_tax_assignments.txt'
genomeDir = '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/'
bulkOTUs = os.path.join(baseDir, 'exp_info', 'bulk_OTU_abund_stats.txt')

# %% [markdown]
# # Init

# %%
import re
import glob
from pprint import pprint

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# library(gridExtra)

# %%
if not os.path.isdir(workDir):
    os.makedirs(workDir)

# %% [markdown]
# # Filtering OTU rep sequences to just OTUs in bulk soil samples
#
# * Only bulk soil OTUs used because they are the only ones with relative abundance info on the 'original' community

# %%
# loading bulk OTUs

bulk_OTUs = []
with open(bulkOTUs, 'rb') as iFH:
    for line in iFH:
        line = line.rstrip().split('\t')
        if line[0] != 'OTUId':
            bulk_OTUs.append(line[0])

bulk_OTUs = set(bulk_OTUs)
print 'Number of OTUs: {}'.format(len(bulk_OTUs))
# Out:
# Number of OTUs: 5695

# %%
# loading OTU reps
OTU_seq = {}
with open(otuRepFile, 'rb') as iFH:
    taxon = None
    for line in iFH:
        line = line.rstrip()
        if line.startswith('>'):
            taxon = line.lstrip('>')
            if taxon in bulk_OTUs:
                OTU_seq[taxon] = ''
            else:
                taxon = None
        else:
            if taxon is not None:
                OTU_seq[taxon] += line

print 'Number of OTU rep sequences: {}'.format(len(OTU_seq.keys()))
# Out:
# Number of OTU rep sequences: 5695

# %%
# writing out filtered OTUs
bulk_OTU_rep = os.path.join(workDir, 'otusn.pick.bulk.fasta')

with open(bulk_OTU_rep, 'wb') as oFH:
    for taxon,seq in OTU_seq.items():
        oFH.write('>{}\n{}\n'.format(taxon, seq))

# %% [markdown]
# #### Notes
#
# * Just printing exp bulk soil OTUs

# %% [markdown]
# # Symlinking sequences

# %%
# priming_exp otu rep sequences
# !printf "Number of sequences: "
# !cd $workDir; \
    grep -c ">" $bulk_OTU_rep   
    
# bac_genome sequences    
# !cd $workDir; \
    ln -s -f $rnammerDir/bac_genome1210_16S.fna .
    
# !printf "Number of sequences: "
# !cd $workDir; \
    grep -c ">" $rnammerDir/bac_genome1210_16S.fna
# Out:
# Number of sequences: 5695
# Number of sequences: 4557

# %%
# combining sequences
# !cd $workDir; \
    cat $bulk_OTU_rep bac_genome1210_16S.fna > ssu_all.fna
# !printf "Number of sequences: "
# !cd $workDir; \
    grep -c ">" ssu_all.fna
# Out:
# Number of sequences: 10252

# %% [markdown]
# # CD-HIT run

# %%
# !cd $workDir; \
    cd-hit-est -i ssu_all.fna -o ssu_all_cdhit -c 0.97 -d 0
# Out:
# ================================================================
# Program: CD-HIT, V4.6, Feb 20 2014, 09:04:54
# Command: cd-hit-est -i ssu_all.fna -o ssu_all_cdhit -c 0.97 -d
#          0
#
# Started: Sun Aug 23 07:18:22 2015
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 10252
# longest and shortest : 3286 and 362
# Total letters: 9099117
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 10M
# Buffer          : 1 X 12M = 12M
# Table           : 1 X 16M = 16M
# Miscellaneous   : 4M
# Total           : 44M
#
# Table limit with the given memory limit:
# Max number of representatives: 465868
# Max number of word counting entries: 94413254
#
# comparing sequences from          0  to      10252
# ..........    10000  finished       6050  clusters
#
#     10252  finished       6285  clusters
#
# Apprixmated maximum memory consumption: 71M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 8.72

# %% [markdown]
# ## Finding clusters with sequences from both datasets

# %%
inFile = os.path.join(workDir, 'ssu_all_cdhit.clstr')

tbl = {}
with open(inFile, 'rb') as inFH:
    clst_id = None
    for line in inFH:
        line = line.rstrip()
        if line.startswith('>'):
            clst_id = line.lstrip('>Cluster ')
            tbl[clst_id] = []
        else:
            tbl[clst_id].append(re.split('\t|, ', line))
            
print "Number of clusters: {}".format(len(tbl.keys()))
# Out:
# Number of clusters: 6285

# %%
# clusters that have '>OTU'  and '>rRNA' (OTU and genome)
def shared_clust(x):
    otus = any([y[2].startswith('>OTU') for y in x])
    genomes = any([y[2].startswith('>rRNA') for y in x])    
    return otus == True and genomes == True

tbl_f = {x:y for x,y in tbl.items() if shared_clust(y)}
print "Number of clusters with OTUs and genomes: {}".format(len(tbl_f.keys()))
# Out:
# Number of clusters with OTUs and genomes: 152

# %% [markdown]
# ### Getting taxonomic classification of OTUs in target clusters

# %%
# loading tax file
tax = {}
with open(otuTaxFile, 'rb') as inFH:
    for line in inFH:
        line = line.rstrip()
        if not line.startswith('OTU'):
            continue
        otu,cls,boot,_ = line.split('\t')
        cls = [x.lstrip(' __') for x in cls.split(';')]
        for i in range(8):
            try:
                len(cls[i])
            except IndexError:
                cls.append('Unclassified')
        tax[otu] = cls

# %%
def printDict(d, n=10):
    cnt = 0
    for x,y in d.items():
        pprint(x)
        print(y)
        cnt += 1
        if cnt >= n:
            break

# %%
printDict(tax, n=3)
# Out:
# 'OTU.8469'
# ['Unassigned', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified']
# 'OTU.11582'
# ['Unassigned', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified', 'Unclassified']
# 'OTU.5687'
# ['Bacteria', 'Firmicutes', 'Clostridia', 'Clostridiales', 'Peptococcaceae', 'Thermincola', 'Unclassified', 'Unclassified']

# %%
# adding taxonomic classifications to OTUs in target clusters

for clstr,x in tbl_f.items():
    for y in x:
        ID = y[2].lstrip('>')
        ID = re.sub('\.\.\..+','', ID)
        #print 'ID: "{}"'.format(ID)
        try:
            y.append(tax[ID])
        except KeyError:
            y.append(None)

# %%
# gut check: printing classifications & genomes names 

for clstr,x in tbl_f.items():
    print 'Cluster: {}'.format(clstr)
    for y in x:
        ID = y[2].lstrip('>')
        if ID.startswith('OTU'):
            # classifications
            try:
                print ':'.join(y[3])[:100]
            except IndexError:
                print ':'.join(y[3])
        elif ID.startswith('rRNA'):
            # genome names
            try:
                print ID[:100]
            except IndexError:
                print ID
# Out:
# Cluster: 210
# Bacteria:Proteobacteria:Gammaproteobacteria:Xanthomonadales:Xanthomonadaceae:Pseudoxanthomonas:Uncla
# rRNA_CP003093_Pseudoxanthomonas_spadix_BD_a59_3414517-3416053_DIR-... *
# Cluster: 664
# Bacteria:Actinobacteria:Micromonosporales:Micromonosporaceae:Micromonospora:Unclassified:Unclassifie
# Bacteria:Actinobacteria:Micromonosporales:Micromonosporaceae:Planosporangium:uncultured_bacterium:Un
# Bacteria:Actinobacteria:Micromonosporales:Micromonosporaceae:Micromonospora:Unclassified:Unclassifie
# Bacteria:Actinobacteria:Micromonosporales:Micromonosporaceae:Unclassified:Unclassified:Unclassified:
# Bacteria:Actinobacteria:Micromonosporales:Micromonosporaceae:Unclassified:Unclassified:Unclassified:
# rRNA_CP002162_Micromonospora_aurantiaca_ATCC_27029_2546563-2548065_DIR+... at +/97.67%
# rRNA_CP002162_Micromonospora_aurantiaca_ATCC_27029_5533833-5535335_DIR-... at +/97.67%
# rRNA_CP002162_Micromonospora_aurantiaca_ATCC_27029_6680542-6682043_DIR-... at +/97.67%
# rRNA_CP000850_Salinispora_arenicola_CNS_205_222631-224134_DIR+... *
# rRNA_CP000850_Salinispora_arenicola_CNS_205_4414872-4416375_DIR-... at +/100.00%
# rRNA_CP000850_Salinispora_arenicola_CNS_205_2184758-2186261_DIR+... at +/100.00%
# rRNA_CP000667_Salinispora_tropica_CNB_440_202585-204088_DIR+... at +/99.53%
# rRNA_CP000667_Salinispora_tropica_CNB_440_4012956-4014459_DIR-... at +/99.53%
# rRNA_CP000667_Salinispora_tropica_CNB_440_2172807-2174310_DIR+... at +/99.53%
# Cluster: 218
# Bacteria:Actinobacteria:Thermoleophilia:Solirubrobacterales:Unclassified:Unclassified:Unclassified:U
# rRNA_CP001854_Conexibacter_woesei_DSM_14684_3764582-3766117_DIR-... *
# Cluster: 132
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfuromonadales:Desulfuromonadaceae:Pelobacter:Unclas
# rRNA_CP000482_Pelobacter_propionicus_DSM_2379_1352684-1354229_DIR+... *
# rRNA_CP000482_Pelobacter_propionicus_DSM_2379_2886442-2887987_DIR-... at +/100.00%
# rRNA_CP000482_Pelobacter_propionicus_DSM_2379_3334716-3336261_DIR-... at +/100.00%
# rRNA_CP000482_Pelobacter_propionicus_DSM_2379_1803507-1805052_DIR+... at +/100.00%
# Cluster: 131
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfuromonadales:Desulfuromonadaceae:Desulfuromonas:Un
# rRNA_CP000142_Pelobacter_carbinolicus_DSM_2380_2756171-2757716_DIR-... *
# rRNA_CP000142_Pelobacter_carbinolicus_DSM_2380_2750589-2752134_DIR-... at +/99.74%
# Cluster: 135
# Bacteria:Proteobacteria:Deltaproteobacteria:Myxococcales:Sorangiineae:Polyangiaceae:Sorangium:Polyan
# rRNA_AM746676_Sorangium_cellulosum__So_ce_56_3027066-3028610_DIR+... at +/100.00%
# rRNA_AM746676_Sorangium_cellulosum__So_ce_56_5523319-5524864_DIR-... *
# rRNA_AM746676_Sorangium_cellulosum__So_ce_56_10340262-10341806_DIR-... at +/100.00%
# rRNA_AM746676_Sorangium_cellulosum__So_ce_56_3486020-3487564_DIR+... at +/100.00%
# Cluster: 226
# Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Moraxellaceae:Acinetobacter:Unclassified
# rRNA_CP003846_Acinetobacter_baumannii_BJAB07104_3823-5347_DIR-... at +/97.64%
# rRNA_CP003846_Acinetobacter_baumannii_BJAB07104_56186-57710_DIR+... at +/97.64%
# rRNA_CP003846_Acinetobacter_baumannii_BJAB07104_3486230-3487754_DIR-... at +/97.64%
# rRNA_CP003846_Acinetobacter_baumannii_BJAB07104_729835-731359_DIR+... at +/97.64%
# rRNA_CP003846_Acinetobacter_baumannii_BJAB07104_227256-228780_DIR+... at +/97.64%
# rRNA_CP003846_Acinetobacter_baumannii_BJAB07104_3453868-3455392_DIR-... at +/97.64%
# rRNA_CP002177_Acinetobacter_calcoaceticus_PHEA_2_3321374-3322899_DIR+... at +/99.67%
# rRNA_CP002177_Acinetobacter_calcoaceticus_PHEA_2_2678134-2679660_DIR-... at +/99.80%
# rRNA_CP002080_Acinetobacter_oleivorans_DR1_3479770-3481295_DIR-... at +/100.00%
# rRNA_CP002080_Acinetobacter_oleivorans_DR1_18773-20298_DIR+... at +/100.00%
# rRNA_CP002080_Acinetobacter_oleivorans_DR1_4120139-4121673_DIR-... *
# rRNA_CP002080_Acinetobacter_oleivorans_DR1_541439-542964_DIR+... at +/100.00%
# rRNA_CP002080_Acinetobacter_oleivorans_DR1_505907-507432_DIR+... at +/99.93%
# rRNA_CP002080_Acinetobacter_oleivorans_DR1_3939237-3940762_DIR-... at +/100.00%
# Cluster: 494
# Bacteria:Actinobacteria:Micrococcales:Bogoriellaceae:Georgenia:Unclassified:Unclassified:Unclassifie
# rRNA_CP001618_Beutenbergia_cavernae_DSM_12333_1605359-1606875_DIR+... *
# rRNA_CP001618_Beutenbergia_cavernae_DSM_12333_2648720-2650236_DIR-... at +/100.00%
# Cluster: 692
# Bacteria:Bacteroidetes:Flavobacteria:Flavobacteriales:Flavobacteriaceae:Flavobacterium:uncultured_ba
# Bacteria:Bacteroidetes:Flavobacteria:Flavobacteriales:Flavobacteriaceae:Flavobacterium:uncultured_ba
# rRNA_FQ859183_Flavobacterium_branchiophilum_FL_15_1179124-1180623_DIR+... *
# rRNA_FQ859183_Flavobacterium_branchiophilum_FL_15_2694248-2695747_DIR-... at +/100.00%
# rRNA_FQ859183_Flavobacterium_branchiophilum_FL_15_2932498-2933996_DIR-... at +/100.00%
# Cluster: 542
# Bacteria:Actinobacteria:Streptosporangiales:Streptosporangiaceae:Streptosporangium:Unclassified:Uncl
# rRNA_CP001814_Streptosporangium_roseum_DSM_43021_6654434-6655946_DIR-... *
# rRNA_CP001814_Streptosporangium_roseum_DSM_43021_2067480-2068992_DIR+... at +/100.00%
# rRNA_CP001814_Streptosporangium_roseum_DSM_43021_9203836-9205348_DIR-... at +/100.00%
# rRNA_CP001814_Streptosporangium_roseum_DSM_43021_9889847-9891359_DIR-... at +/100.00%
# rRNA_CP001814_Streptosporangium_roseum_DSM_43021_4414101-4415613_DIR+... at +/100.00%
# rRNA_CP001814_Streptosporangium_roseum_DSM_43021_8042254-8043766_DIR-... at +/100.00%
# Cluster: 819
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Sphingomonas:Unclassi
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Sphingomonas:Unclassi
# rRNA_CP000699_Sphingomonas_wittichii_RW1_3844823-3846297_DIR+... *
# rRNA_CP000699_Sphingomonas_wittichii_RW1_2812340-2813814_DIR-... at +/100.00%
# Cluster: 403
# Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Unclassifie
# rRNA_CP010415_Azotobacter_chroococcum_NCIMB_8003_2524922-2526445_DIR-... *
# rRNA_CP010415_Azotobacter_chroococcum_NCIMB_8003_185358-186881_DIR+... at +/99.93%
# rRNA_CP010415_Azotobacter_chroococcum_NCIMB_8003_1658523-1660046_DIR+... at +/99.93%
# rRNA_CP010415_Azotobacter_chroococcum_NCIMB_8003_914527-916050_DIR+... at +/100.00%
# rRNA_CP010415_Azotobacter_chroococcum_NCIMB_8003_609300-610823_DIR+... at +/100.00%
# rRNA_CP010415_Azotobacter_chroococcum_NCIMB_8003_3228034-3229557_DIR-... at +/100.00%
# Cluster: 400
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:Comamonas:Unclassified:Unc
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:uncultured:uncultured_bact
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:Polaromonas:uncultured_bac
# rRNA_CP000267_Rhodoferax_ferrireducens_T118_4118290-4119814_DIR-... *
# rRNA_CP000267_Rhodoferax_ferrireducens_T118_4112646-4114170_DIR-... at +/100.00%
# Cluster: 813
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Sphingobium:Unclassif
# rRNA_CP002798_Sphingobium_chlorophenolicum_L_1_chromosome_1__complete_sequence_2454169-2455644_DIR+.
# rRNA_CP002799_Sphingobium_chlorophenolicum_L_1_chromosome_2__complete_sequence_1220613-1222088_DIR-.
# rRNA_CP002799_Sphingobium_chlorophenolicum_L_1_chromosome_2__complete_sequence_586311-587786_DIR+...
# rRNA_AP010804_Sphingobium_japonicum_UT26S_DNA__chromosome_2_119257-120731_DIR+... at +/97.69%
# rRNA_AP010803_Sphingobium_japonicum_UT26S_DNA__chromosome_1_68200-69674_DIR+... at +/97.69%
# rRNA_AP010804_Sphingobium_japonicum_UT26S_DNA__chromosome_2_308559-310033_DIR+... at +/97.90%
# Cluster: 348
# Bacteria:Proteobacteria:Betaproteobacteria:Nitrosomonadales:Gallionellaceae:Sideroxydans:Unclassifie
# rRNA_CP001965_Sideroxydans_lithotrophicus_ES_1_357388-358915_DIR+... *
# rRNA_CP001965_Sideroxydans_lithotrophicus_ES_1_1926830-1928357_DIR-... at +/100.00%
# Cluster: 815
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Beijerinckiaceae:uncultured:Unclassified:Unc
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Unclassified:Unclassified:Unclassified:Uncla
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:alphaI_cluster:Unclassified:Unclassified:Unc
# rRNA_CP001016_Beijerinckia_indica_subsp__indica_ATCC_9039_680554-682028_DIR+... *
# rRNA_CP001016_Beijerinckia_indica_subsp__indica_ATCC_9039_3418482-3419956_DIR-... at +/99.93%
# rRNA_CP001016_Beijerinckia_indica_subsp__indica_ATCC_9039_3932131-3933605_DIR-... at +/100.00%
# rRNA_CP001280_Methylocella_silvestris_BL2_2446870-2448344_DIR-... at +/97.22%
# rRNA_CP001280_Methylocella_silvestris_BL2_1934569-1936043_DIR-... at +/97.22%
# Cluster: 817
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Methylobacteriaceae:Methylobacterium:uncultu
# rRNA_CP003811_Methylobacterium_oryzae_CBMB20_1919737-1921207_DIR+... at +/100.00%
# rRNA_CP003811_Methylobacterium_oryzae_CBMB20_2866611-2868082_DIR-... at +/99.93%
# rRNA_CP003811_Methylobacterium_oryzae_CBMB20_4009478-4010952_DIR-... *
# rRNA_CP003811_Methylobacterium_oryzae_CBMB20_5089417-5090889_DIR+... at +/99.86%
# rRNA_CP001001_Methylobacterium_radiotolerans_JCM_2831_1589195-1590665_DIR+... at +/99.39%
# rRNA_CP001001_Methylobacterium_radiotolerans_JCM_2831_2541184-2542654_DIR-... at +/99.39%
# rRNA_CP001001_Methylobacterium_radiotolerans_JCM_2831_3701113-3702583_DIR-... at +/99.39%
# rRNA_CP001001_Methylobacterium_radiotolerans_JCM_2831_4684074-4685544_DIR+... at +/99.39%
# Cluster: 679
# Bacteria:Planctomycetes:Planctomycetacia:Planctomycetales:Planctomycetaceae:Singulisphaera:unculture
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_7835090-7836591_DIR-... *
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_4641583-4643084_DIR+... at +/100.00%
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_7450454-7451955_DIR-... at +/100.00%
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_4141975-4143476_DIR+... at +/100.00%
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_7355417-7356918_DIR-... at +/99.93%
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_4719468-4720969_DIR+... at +/100.00%
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_3325973-3327474_DIR+... at +/99.80%
# rRNA_CP003364_Singulisphaera_acidiphila_DSM_18658_5823227-5824728_DIR+... at +/99.80%
# Cluster: 719
# Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:Unclassified:Unclassified
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_103266-104760_DIR+... *
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_59529-61023_DIR+... at +/99.93%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_112457-113951_DIR+... at +/100.00%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_3974970-3976464_DIR-... at +/100.00%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_50224-51718_DIR+... at +/100.00%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_1554411-1555905_DIR+... at +/99.93%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_69045-70539_DIR+... at +/100.00%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_9698-11192_DIR+... at +/100.00%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_3710749-3712243_DIR-... at +/99.87%
# rRNA_CP009267_Clostridium_pasteurianum_DSM_525___ATCC_6013_82923-84417_DIR+... at +/99.87%
# Cluster: 577
# Bacteria:Bacteroidetes:Cytophagia:Cytophagales:Flammeovirgaceae:Candidatus_Amoebophilus:Unclassified
# rRNA_CP001102_Candidatus_Amoebophilus_asiaticus_5a2_596541-598050_DIR+... *
# Cluster: 714
# Bacteria:Chloroflexi:Thermomicrobia:Sphaerobacteridae:Sphaerobacterales:Sphaerobacterineae:Sphaeroba
# rRNA_CP001823_Sphaerobacter_thermophilus_DSM_20745_chromosome_1__complete_sequence_579562-581058_DIR
# rRNA_CP001824_Sphaerobacter_thermophilus_DSM_20745_chromosome_2__complete_sequence_554481-555976_DIR
# Cluster: 260
# Bacteria:Proteobacteria:Gammaproteobacteria:Xanthomonadales:Xanthomonadaceae:Pseudoxanthomonas:Uncla
# rRNA_CP002446_Pseudoxanthomonas_suwonensis_11_1_1425078-1426609_DIR+... at +/99.93%
# rRNA_CP002446_Pseudoxanthomonas_suwonensis_11_1_3230694-3232226_DIR-... *
# Cluster: 764
# Bacteria:Acidobacteria:Acidobacteriales:Acidobacteriaceae:Acidobacterium:uncultured_bacterium:Unclas
# rRNA_CP001472_Acidobacterium_capsulatum_ATCC_51196_2863335-2864822_DIR+... *
# Cluster: 24
# Bacteria:Firmicutes:Clostridia:Clostridiales:Peptococcaceae:Desulfitobacterium:uncultured_bacterium:
# rRNA_CP003344_Desulfitobacterium_dichloroeliminans_LMG_P_21439_2245532-2247252_DIR-... *
# rRNA_CP003344_Desulfitobacterium_dichloroeliminans_LMG_P_21439_1812554-1814274_DIR+... at +/99.83%
# Cluster: 129
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfuromonadales:BVA18:Unclassified:Unclassified:Uncla
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfuromonadales:Geobacteraceae:Geobacter:Unclassified
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfuromonadales:Geobacteraceae:Geobacter:Unclassified
# rRNA_CP001089_Geobacter_lovleyi_SZ_768668-770213_DIR+... *
# rRNA_CP001089_Geobacter_lovleyi_SZ_1712343-1713888_DIR+... at +/100.00%
# Cluster: 594
# Bacteria:Actinobacteria:Micrococcales:Microbacteriaceae:Cryobacterium:Unclassified:Unclassified:Uncl
# rRNA_AM849034_Clavibacter_michiganensis_subsp__sepedonicus_1297191-1298699_DIR+... *
# rRNA_AM849034_Clavibacter_michiganensis_subsp__sepedonicus_2742890-2744398_DIR-... at +/99.87%
# Cluster: 424
# Bacteria:Proteobacteria:Betaproteobacteria:Hydrogenophilales:Hydrogenophilaceae:Thiobacillus:Unclass
# rRNA_CP000116_Thiobacillus_denitrificans_ATCC_25259_478077-479599_DIR+... *
# rRNA_CP000116_Thiobacillus_denitrificans_ATCC_25259_1863927-1865449_DIR-... at +/100.00%
# Cluster: 379
# Bacteria:Proteobacteria:Betaproteobacteria:Methylophilales:Methylophilaceae:Methylotenera:uncultured
# rRNA_CP001672_Methylotenera_mobilis_JLW8_214628-216153_DIR+... *
# rRNA_CP001672_Methylotenera_mobilis_JLW8_691251-692776_DIR+... at +/100.00%
# Cluster: 532
# Bacteria:Firmicutes:Clostridia:Clostridiales:Family_XI_Incertae_Sedis:Incertae_Sedis:Unclassified:Un
# rRNA_CP003326_Clostridium_acidurici_9a_2471933-2473445_DIR-... at +/99.60%
# rRNA_CP003326_Clostridium_acidurici_9a_11124-12636_DIR+... at +/99.60%
# rRNA_CP003326_Clostridium_acidurici_9a_3033100-3034612_DIR-... at +/99.60%
# rRNA_CP003326_Clostridium_acidurici_9a_1003099-1004611_DIR+... at +/99.80%
# rRNA_CP003326_Clostridium_acidurici_9a_992011-993524_DIR+... *
# rRNA_CP003326_Clostridium_acidurici_9a_3020882-3022394_DIR-... at +/99.47%
# Cluster: 412
# Bacteria:Proteobacteria:Betaproteobacteria:Nitrosomonadales:Nitrosomonadaceae:Nitrosospira:Unclassif
# rRNA_CP000103_Nitrosospira_multiformis_ATCC_25196_562629-564152_DIR+... *
# Cluster: 530
# Bacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Unclassified:Unclassified:Un
# rRNA_CP006259_Streptomyces_collinus_Tu_365_1705885-1707398_DIR-... *
# rRNA_CP006259_Streptomyces_collinus_Tu_365_4844926-4846439_DIR+... at +/100.00%
# rRNA_CP006259_Streptomyces_collinus_Tu_365_3633711-3635224_DIR-... at +/100.00%
# rRNA_CP006259_Streptomyces_collinus_Tu_365_4176908-4178421_DIR-... at +/100.00%
# rRNA_CP006259_Streptomyces_collinus_Tu_365_6197651-6199164_DIR+... at +/100.00%
# rRNA_CP006259_Streptomyces_collinus_Tu_365_2182272-2183785_DIR-... at +/100.00%
# Cluster: 824
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Phyllobacteriaceae:Mesorhizobium:Unclassifie
# rRNA_CP003358_Mesorhizobium_australicum_WSM2073_1738466-1739938_DIR+... at +/99.59%
# rRNA_CP003358_Mesorhizobium_australicum_WSM2073_1746046-1747518_DIR+... at +/99.59%
# rRNA_CP002447_Mesorhizobium_ciceri_biovar_biserrulae_WSM1271_1686680-1688152_DIR+... at +/100.00%
# rRNA_CP002447_Mesorhizobium_ciceri_biovar_biserrulae_WSM1271_1694553-1696026_DIR+... *
# rRNA_BA000012_Mesorhizobium_loti_MAFF303099_DNA_2757519-2758991_DIR-... at +/98.30%
# rRNA_BA000012_Mesorhizobium_loti_MAFF303099_DNA_2750006-2751478_DIR-... at +/98.30%
# rRNA_CP002279_Mesorhizobium_opportunistum_WSM2075_1728175-1729647_DIR+... at +/98.23%
# rRNA_CP002279_Mesorhizobium_opportunistum_WSM2075_1735934-1737406_DIR+... at +/98.23%
# Cluster: 294
# Bacteria:Actinobacteria:Streptosporangiales:Unclassified:Unclassified:Unclassified:Unclassified:Uncl
# rRNA_CP001874_Thermobispora_bispora_DSM_43833_2893296-2894826_DIR-... *
# rRNA_CP001874_Thermobispora_bispora_DSM_43833_3886709-3888239_DIR-... at +/100.00%
# Cluster: 372
# Bacteria:Proteobacteria:Betaproteobacteria:Rhodocyclales:Rhodocyclaceae:Azoarcus:Unclassified:Unclas
# rRNA_CR555306_Azoarcus_aromaticum_EbN1_1845876-1847401_DIR+... *
# rRNA_CR555306_Azoarcus_aromaticum_EbN1_548904-550429_DIR-... at +/100.00%
# rRNA_CR555306_Azoarcus_aromaticum_EbN1_2620997-2622522_DIR+... at +/100.00%
# rRNA_CR555306_Azoarcus_aromaticum_EbN1_2411726-2413251_DIR+... at +/100.00%
# Cluster: 821
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhodospirillales:Rhodospirillaceae:Azospirillum:Unclassi
# rRNA_FQ311868_Azospirillum_lipoferum_4B_main_chromosome_315020-316493_DIR+... *
# rRNA_FQ311868_Azospirillum_lipoferum_4B_main_chromosome_2945293-2946764_DIR+... at +/98.98%
# Cluster: 823
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Erythrobacteraceae:uncultured:Unclassif
# rRNA_CP000157_Erythrobacter_litoralis_HTCC2594_63538-65011_DIR+... *
# Cluster: 538
# Bacteria:Bacteroidetes:Flavobacteria:Flavobacteriales:Cryomorphaceae:Fluviicola:uncultured_bacterium
# rRNA_CP002542_Fluviicola_taffensis_DSM_16823_2752771-2754283_DIR+... *
# rRNA_CP002542_Fluviicola_taffensis_DSM_16823_2876358-2877870_DIR+... at +/100.00%
# Cluster: 198
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Unclassified:Unclassified:Unclassified
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_267871-269408_DIR+... *
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_94993-96530_DIR+... at +/99.93%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_1034057-1035594_DIR+... at +/99.74%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_2896775-2898312_DIR-... at +/99.74%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_33438-34975_DIR+... at +/99.80%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_3784353-3785890_DIR-... at +/100.00%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_100831-102368_DIR+... at +/99.87%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_11387-12924_DIR+... at +/100.00%
# rRNA_CP006643_Bacillus_infantis_NRRL_B_14911_166737-168274_DIR+... at +/99.93%
# Cluster: 134
# Bacteria:Firmicutes:Bacilli:Bacillales:Planococcaceae:Solibacillus:uncultured_bacterium:Unclassified
# Bacteria:Firmicutes:Bacilli:Bacillales:Planococcaceae:Solibacillus:uncultured_bacterium:Unclassified
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_3869767-3871309_DIR-... at +/99.81%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_9633-11176_DIR-... at +/99.68%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_518568-520109_DIR+... at +/99.16%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_3654141-3655682_DIR-... at +/99.87%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_76641-78183_DIR-... at +/99.74%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_465984-467522_DIR+... at +/99.87%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_3637-5177_DIR-... at +/99.55%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_124055-125600_DIR-... *
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_730799-732344_DIR+... at +/99.74%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_290186-291730_DIR+... at +/99.87%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_68874-70419_DIR-... at +/100.00%
# rRNA_AP012157_Solibacillus_silvestris_StLB046_DNA_1186075-1187614_DIR+... at +/99.68%
# Cluster: 191
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Bacillus:Unclassified:Unclassified
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Bacillus:Unclassified:Unclassified
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Bacillus:Unclassified:Unclassified
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_904909-906446_DIR+... at +/98.24%
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_9769-11306_DIR+... at +/98.24%
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_156122-157659_DIR+... at +/98.18%
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_91536-93073_DIR+... at +/98.24%
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_3132158-3133695_DIR-... at +/98.24%
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_31505-33042_DIR+... at +/98.24%
# rRNA_CP006890_Bacillus_amyloliquefaciens_SQR9_556940-558477_DIR+... at +/98.24%
# rRNA_CP002207_Bacillus_atrophaeus_1942_3784168-3785705_DIR+... at +/98.37%
# rRNA_CP002207_Bacillus_atrophaeus_1942_95765-97302_DIR+... at +/98.37%
# rRNA_CP002207_Bacillus_atrophaeus_1942_3658835-3660372_DIR+... at +/98.31%
# rRNA_CP002207_Bacillus_atrophaeus_1942_3638263-3639800_DIR+... at +/98.31%
# rRNA_CP002207_Bacillus_atrophaeus_1942_2606102-2607639_DIR-... at +/98.24%
# rRNA_CP002207_Bacillus_atrophaeus_1942_405546-407083_DIR+... at +/98.31%
# rRNA_CP002207_Bacillus_atrophaeus_1942_3719207-3720744_DIR+... at +/98.31%
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_920785-922323_DIR+... *
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_9713-11250_DIR+... at +/99.80%
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_158109-159647_DIR+... at +/100.00%
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_95153-96691_DIR+... at +/99.81%
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_3121614-3123152_DIR-... at +/99.94%
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_34411-35948_DIR+... at +/99.80%
# rRNA_AE017333_Bacillus_licheniformis_DSM_13___ATCC_14580_611805-613342_DIR+... at +/99.74%
# rRNA_CP006881_Bacillus_subtilis_PY79_166507-168044_DIR+... at +/98.31%
# rRNA_CP006881_Bacillus_subtilis_PY79_90544-92079_DIR+... at +/98.11%
# rRNA_CP006881_Bacillus_subtilis_PY79_171509-173046_DIR+... at +/98.31%
# rRNA_CP006881_Bacillus_subtilis_PY79_909739-911276_DIR+... at +/98.31%
# rRNA_CP006881_Bacillus_subtilis_PY79_30287-31824_DIR+... at +/98.37%
# rRNA_CP006881_Bacillus_subtilis_PY79_598476-600013_DIR+... at +/98.11%
# rRNA_CP006881_Bacillus_subtilis_PY79_96398-97934_DIR+... at +/98.31%
# rRNA_CP006881_Bacillus_subtilis_PY79_9819-11356_DIR+... at +/98.31%
# rRNA_CP006881_Bacillus_subtilis_PY79_2994949-2996485_DIR-... at +/98.11%
# rRNA_CP006881_Bacillus_subtilis_PY79_160898-162435_DIR+... at +/98.24%
# Cluster: 701
# Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:uncultured_bacterium:Unclass
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_3797486-3798984_DIR-... *
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_9356-10854_DIR+... at +/99.93%
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_955391-956889_DIR+... at +/99.87%
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_833913-835411_DIR+... at +/99.93%
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_3785921-3787419_DIR-... at +/100.00%
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_171987-173485_DIR+... at +/99.73%
# rRNA_AP009049_Clostridium_kluyveri_NBRC_12016_DNA_969877-971375_DIR+... at +/99.87%
# Cluster: 192
# Bacteria:Firmicutes:Bacilli:Bacillales:Planococcaceae:Unclassified:Unclassified:Unclassified
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Bacillus:Unclassified:Unclassified
# rRNA_CP007739_Bacillus_methanolicus_MGA3_249239-250777_DIR+... *
# rRNA_CP007739_Bacillus_methanolicus_MGA3_92312-93850_DIR+... at +/99.74%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_292686-294224_DIR+... at +/99.94%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_2753934-2755472_DIR-... at +/99.87%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_31285-32823_DIR+... at +/99.94%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_693977-695515_DIR+... at +/99.87%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_98436-99974_DIR+... at +/99.87%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_10668-12206_DIR+... at +/99.87%
# rRNA_CP007739_Bacillus_methanolicus_MGA3_162425-163963_DIR+... at +/99.81%
# Cluster: 117
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfobacterales:Desulfobulbaceae:Desulfocapsa:Unclassi
# rRNA_CP003985_Desulfocapsa_sulfexigens_DSM_10523_3691502-3693049_DIR+... *
# rRNA_CP003985_Desulfocapsa_sulfexigens_DSM_10523_2137091-2138638_DIR-... at +/100.00%
# rRNA_CP003985_Desulfocapsa_sulfexigens_DSM_10523_3983919-3985466_DIR+... at +/100.00%
# Cluster: 275
# Bacteria:Proteobacteria:Gammaproteobacteria:Legionellales:Legionellaceae:Legionella:Unclassified:Unc
# Bacteria:Proteobacteria:Gammaproteobacteria:Legionellales:Legionellaceae:Legionella:Unclassified:Unc
# rRNA_FN650140_Legionella_longbeachae_NSW150_540034-541565_DIR+... *
# rRNA_FN650140_Legionella_longbeachae_NSW150_3087417-3088948_DIR-... at +/99.93%
# rRNA_FN650140_Legionella_longbeachae_NSW150_344743-346274_DIR+... at +/99.87%
# rRNA_FN650140_Legionella_longbeachae_NSW150_1117726-1119257_DIR+... at +/100.00%
# rRNA_AE017354_Legionella_pneumophila_subsp__pneumophila_str__Philadelphia_1_359868-361399_DIR+... at
# rRNA_AE017354_Legionella_pneumophila_subsp__pneumophila_str__Philadelphia_1_3101165-3102696_DIR-...
# rRNA_AE017354_Legionella_pneumophila_subsp__pneumophila_str__Philadelphia_1_608228-609759_DIR+... at
# Cluster: 113
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Geobacillus:Bacillus:Unclassified
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_276547-278092_DIR+... at +/98.25%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_89413-90958_DIR+... at +/98.12%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_519818-521363_DIR+... at +/98.12%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_2190794-2192338_DIR-... at +/98.12%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_30791-32336_DIR+... at +/98.58%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_2946097-2947642_DIR-... at +/98.06%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_154303-155848_DIR+... at +/98.19%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_10422-11966_DIR+... at +/98.25%
# rRNA_BA000043_Geobacillus_kaustophilus_HTA426_DNA_249893-251438_DIR+... at +/98.32%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_258794-260340_DIR+... at +/99.81%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_87326-88870_DIR+... at +/99.81%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_547533-549081_DIR+... *
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_2213655-2215201_DIR-... at +/99.22%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_29329-30875_DIR+... at +/99.74%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_1312223-1313769_DIR+... at +/99.68%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_150332-151876_DIR+... at +/99.68%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_10618-12166_DIR+... at +/99.29%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_2971230-2972778_DIR-... at +/99.48%
# rRNA_CP000557_Geobacillus_thermodenitrificans_NG80_2_225976-227520_DIR+... at +/99.81%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_10676-12221_DIR+... at +/97.02%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_157388-158933_DIR+... at +/97.09%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_314519-316064_DIR+... at +/98.25%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_90848-92393_DIR+... at +/98.19%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_568937-570482_DIR+... at +/97.93%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_2238525-2240070_DIR-... at +/98.25%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_29197-30742_DIR+... at +/98.19%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_3009851-3011396_DIR-... at +/98.12%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_155441-156989_DIR+... at +/97.93%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_10431-11976_DIR+... at +/97.99%
# rRNA_CP003125_Geobacillus_thermoleovorans_CCB_US3_UF5_248483-250028_DIR+... at +/98.06%
# Cluster: 399
# Bacteria:Actinobacteria:Micrococcales:Micrococcaceae:Arthrobacter:Unclassified:Unclassified:Unclassi
# rRNA_CP000910_Renibacterium_salmoninarum_ATCC_33209_364821-366345_DIR+... *
# rRNA_CP000910_Renibacterium_salmoninarum_ATCC_33209_674883-676407_DIR+... at +/100.00%
# Cluster: 398
# Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Unclassifie
# Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Unclassifie
# Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Unclassifie
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_490040-491564_DIR+... *
# rRNA_CP002727_Pseudomonas_fulva_12_X_239522-241045_DIR+... at +/98.23%
# rRNA_CP002727_Pseudomonas_fulva_12_X_2802266-2803789_DIR-... at +/98.23%
# rRNA_CP002727_Pseudomonas_fulva_12_X_936928-938451_DIR+... at +/98.16%
# rRNA_CP002727_Pseudomonas_fulva_12_X_691587-693110_DIR+... at +/98.16%
# rRNA_CP002620_Pseudomonas_mendocina_NK_01_5207855-5209379_DIR-... at +/98.16%
# rRNA_CP002620_Pseudomonas_mendocina_NK_01_3043024-3044548_DIR-... at +/98.30%
# rRNA_CP002620_Pseudomonas_mendocina_NK_01_4252678-4254202_DIR-... at +/98.16%
# rRNA_CP002620_Pseudomonas_mendocina_NK_01_4718333-4719857_DIR-... at +/98.16%
# Cluster: 118
# Bacteria:Firmicutes:Bacilli:Bacillales:Bacillaceae:Anoxybacillus:Unclassified:Unclassified
# Bacteria:Firmicutes:Bacilli:Bacillales:Family_XII_Incertae_Sedis:Incertae_Sedis:uncultured_bacterium
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_661618-663164_DIR+... at +/100.00%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_89647-91193_DIR+... at +/100.00%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_1443779-1445325_DIR+... at +/99.87%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_3585975-3587521_DIR-... at +/99.94%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_30979-32526_DIR+... *
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_3628836-3630382_DIR-... at +/99.94%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_95676-97223_DIR+... at +/99.87%
# rRNA_CP002835_Geobacillus_thermoglucosidasius_C56_YS93_3254840-3256386_DIR-... at +/99.94%
# Cluster: 832
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Methylobacteriaceae:Methylobacterium:Unclass
# rRNA_CP001510_Methylobacterium_extorquens_AM1_1255243-1256715_DIR-... *
# rRNA_CP001510_Methylobacterium_extorquens_AM1_605675-607147_DIR-... at +/100.00%
# rRNA_CP001510_Methylobacterium_extorquens_AM1_817852-819324_DIR-... at +/100.00%
# rRNA_CP001510_Methylobacterium_extorquens_AM1_1232884-1234356_DIR-... at +/100.00%
# rRNA_CP001510_Methylobacterium_extorquens_AM1_432441-433913_DIR-... at +/100.00%
# rRNA_CP001029_Methylobacterium_populi_BJ001_1453427-1454899_DIR-... at +/99.25%
# rRNA_CP001029_Methylobacterium_populi_BJ001_763314-764786_DIR-... at +/99.25%
# rRNA_CP001029_Methylobacterium_populi_BJ001_1015511-1016983_DIR-... at +/99.25%
# rRNA_CP001029_Methylobacterium_populi_BJ001_1430574-1432046_DIR-... at +/99.32%
# rRNA_CP001029_Methylobacterium_populi_BJ001_606450-607922_DIR-... at +/99.19%
# Cluster: 793
# Bacteria:Cyanobacteria:SubsectionIV:FamilyI:Anabaena:Unclassified:Unclassified:Unclassified
# rRNA_CP002059__Nostoc_azollae__0708_830919-832396_DIR+... *
# rRNA_CP002059__Nostoc_azollae__0708_979079-980555_DIR-... at +/100.00%
# rRNA_CP002059__Nostoc_azollae__0708_2979417-2980893_DIR-... at +/100.00%
# rRNA_CP002059__Nostoc_azollae__0708_2217271-2218747_DIR+... at +/100.00%
# Cluster: 834
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Novosphingobium:Uncla
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Novosphingobium:Uncla
# rRNA_CP000248_Novosphingobium_aromaticivorans_DSM_12444_2862501-2863973_DIR-... *
# rRNA_CP000248_Novosphingobium_aromaticivorans_DSM_12444_2851035-2852507_DIR-... at +/100.00%
# rRNA_CP000248_Novosphingobium_aromaticivorans_DSM_12444_2856768-2858240_DIR-... at +/100.00%
# Cluster: 838
# Bacteria:Proteobacteria:Alphaproteobacteria:Caulobacterales:Caulobacteraceae:Caulobacter:Unclassifie
# Bacteria:Proteobacteria:Alphaproteobacteria:Caulobacterales:Caulobacteraceae:Caulobacter:Unclassifie
# rRNA_CP001340_Caulobacter_crescentus_NA1000_3796172-3797643_DIR-... *
# rRNA_CP001340_Caulobacter_crescentus_NA1000_2866139-2867610_DIR-... at +/100.00%
# rRNA_CP002008_Caulobacter_segnis_ATCC_21756_180210-181681_DIR+... at +/99.73%
# rRNA_CP002008_Caulobacter_segnis_ATCC_21756_1152537-1154008_DIR+... at +/99.73%
# Cluster: 798
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Bradyrhizobiaceae:Bradyrhizobium:Unclassifie
# rRNA_BA000040_Bradyrhizobium_japonicum_USDA_110_DNA_1528234-1529710_DIR+... *
# rRNA_AP012206_Bradyrhizobium_japonicum_USDA_6_DNA_1584408-1585884_DIR+... at +/99.32%
# rRNA_AP012206_Bradyrhizobium_japonicum_USDA_6_DNA_6255008-6256484_DIR-... at +/99.32%
# rRNA_AP012603_Bradyrhizobium_oligotrophicum_S58_DNA_3187415-3188891_DIR+... at +/98.98%
# rRNA_AP012603_Bradyrhizobium_oligotrophicum_S58_DNA_7419994-7421470_DIR-... at +/98.98%
# rRNA_CP000319_Nitrobacter_hamburgensis_X14_723636-725112_DIR+... at +/97.77%
# rRNA_CP000115_Nitrobacter_winogradskyi_Nb_255_638310-639786_DIR+... at +/98.04%
# rRNA_CP002821_Oligotropha_carboxidovorans_OM4_3296392-3297868_DIR-... at +/97.83%
# rRNA_CP000283_Rhodopseudomonas_palustris_BisB5_4550893-4552369_DIR-... at +/97.36%
# rRNA_CP000283_Rhodopseudomonas_palustris_BisB5_407222-408698_DIR-... at +/97.36%
# Cluster: 526
# Bacteria:Bacteroidetes:Sphingobacteriia:Sphingobacteriales:Chitinophagaceae:Chitinophaga:uncultured_
# Bacteria:Bacteroidetes:Sphingobacteriia:Sphingobacteriales:Chitinophagaceae:Chitinophaga:uncultured_
# rRNA_CP001699_Chitinophaga_pinensis_DSM_2588_1727656-1729169_DIR+... *
# rRNA_CP001699_Chitinophaga_pinensis_DSM_2588_1700268-1701781_DIR+... at +/99.87%
# rRNA_CP001699_Chitinophaga_pinensis_DSM_2588_1720052-1721565_DIR+... at +/99.80%
# rRNA_CP001699_Chitinophaga_pinensis_DSM_2588_1711143-1712656_DIR+... at +/100.00%
# rRNA_CP001699_Chitinophaga_pinensis_DSM_2588_1705744-1707257_DIR+... at +/99.87%
# rRNA_CP001699_Chitinophaga_pinensis_DSM_2588_1725733-1727246_DIR+... at +/99.67%
# Cluster: 7
# Bacteria:Proteobacteria:Alphaproteobacteria:Rickettsiales:Rickettsiaceae:Rickettsia:Unclassified:Unc
# rRNA_CP003334_Candidatus_Rickettsia_amblyommii_str__GAT_30V_1091111-1092597_DIR-... at +/98.32%
# rRNA_CP001612_Rickettsia_africae_ESF_5_893141-894630_DIR-... at +/98.32%
# rRNA_CP000847_Rickettsia_akari_str__Hartford_864184-865670_DIR-... at +/97.85%
# rRNA_CP003338_Rickettsia_australis_str__Cutlack_558542-560029_DIR+... at +/98.32%
# rRNA_CP000087_Rickettsia_bellii_RML369_C_537812-539298_DIR+... at +/98.39%
# rRNA_CP000409_Rickettsia_canadensis_str__McKiel_385956-387442_DIR+... at +/98.05%
# rRNA_AE006914_Rickettsia_conorii_str__Malish_7_884606-886092_DIR-... at +/98.59%
# rRNA_CP000053_Rickettsia_felis_URRWXCal2_456399-457885_DIR+... at +/98.45%
# rRNA_CP002912_Rickettsia_heilongjiangensis_054_895230-896716_DIR-... at +/98.52%
# rRNA_CM001467_Rickettsia_helvetica_C9P9_chromosome__whole_genome_shotgun_sequence_522937-524423_DIR+
# rRNA_AP011533_Rickettsia_japonica_YH_DNA_889312-890798_DIR+... at +/98.45%
# rRNA_CP000683_Rickettsia_massiliae_MTU5_968396-969882_DIR-... at +/98.72%
# rRNA_CP003340_Rickettsia_montanensis_str__OSU_85_930_336478-337964_DIR-... at +/98.52%
# rRNA_CP003341_Rickettsia_parkeri_str__Portsmouth_918887-920374_DIR-... at +/98.32%
# rRNA_CP001227_Rickettsia_peacockii_str__Rustic_1191454-1192940_DIR-... at +/98.59%
# rRNA_CP003308_Rickettsia_philipii_str__364D_904418-905904_DIR-... at +/98.52%
# rRNA_CP003342_Rickettsia_rhipicephali_str__3_7_female6_CWPP_981778-983264_DIR-... at +/98.52%
# rRNA_CP003309_Rickettsia_rickettsii_str__Hino_888020-889506_DIR-... at +/98.59%
# rRNA_AABW01000001_Rickettsia_sibirica_246_chromosome__complete_sequence__whole_gen_1044189-1045677_D
# rRNA_CP003375_Rickettsia_slovaca_str__D_CWPP_892248-893734_DIR-... at +/98.52%
# rRNA_CP003397_Rickettsia_typhi_str__TH1527_778059-781256_DIR-... *
# Cluster: 369
# Bacteria:Verrucomicrobia:Verrucomicrobiae:Verrucomicrobiales:Verrucomicrobiaceae:Verrucomicrobium:un
# rRNA_ABIZ01000001_Verrucomicrobium_spinosum_DSM_4136_chromosome__whole_genome_shot_2579001-2580527_D
# rRNA_ABIZ01000001_Verrucomicrobium_spinosum_DSM_4136_chromosome__whole_genome_shot_5019488-5021014_D
# rRNA_ABIZ01000001_Verrucomicrobium_spinosum_DSM_4136_chromosome__whole_genome_shot_5471746-5473272_D
# rRNA_ABIZ01000001_Verrucomicrobium_spinosum_DSM_4136_chromosome__whole_genome_shot_8132150-8133676_D
# Cluster: 420
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Oxalobacteraceae:Herbaspirillum:Unclassif
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Oxalobacteraceae:uncultured:Unclassified:
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Oxalobacteraceae:Paucimonas:uncultured_ba
# rRNA_CP002039_Herbaspirillum_seropedicae_SmR1_519651-521172_DIR+... at +/99.87%
# rRNA_CP002039_Herbaspirillum_seropedicae_SmR1_4446607-4448129_DIR-... *
# rRNA_CP002039_Herbaspirillum_seropedicae_SmR1_5431898-5433419_DIR-... at +/99.87%
# Cluster: 425
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:Unclassified:Unclassified:
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:Rhizobacter:uncultured_bac
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:Variovorax:Unclassified:Un
# rRNA_CP002417_Variovorax_paradoxus_EPS_172901-174423_DIR+... *
# rRNA_CP002417_Variovorax_paradoxus_EPS_5899432-5900954_DIR-... at +/100.00%
# Cluster: 363
# Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Unclassifie
# rRNA_CP002585_Pseudomonas_brassicacearum_subsp__brassicacearum_NFM421_182480-184004_DIR+... at +/97.
# rRNA_CP002585_Pseudomonas_brassicacearum_subsp__brassicacearum_NFM421_5807811-5809335_DIR-... at +/9
# rRNA_CP002585_Pseudomonas_brassicacearum_subsp__brassicacearum_NFM421_6171604-6173128_DIR-... at +/9
# rRNA_CP002585_Pseudomonas_brassicacearum_subsp__brassicacearum_NFM421_844640-846164_DIR+... at +/97.
# rRNA_CP002585_Pseudomonas_brassicacearum_subsp__brassicacearum_NFM421_4844950-4846474_DIR-... at +/9
# rRNA_CP009290_Pseudomonas_chlororaphis_subsp__aurantiaca_strain_JD37_732141-733665_DIR+... at +/97.5
# rRNA_CP009290_Pseudomonas_chlororaphis_subsp__aurantiaca_strain_JD37_5825843-5827367_DIR-... at +/97
# rRNA_CP009290_Pseudomonas_chlororaphis_subsp__aurantiaca_strain_JD37_2166902-2168426_DIR+... at +/97
# rRNA_CP009290_Pseudomonas_chlororaphis_subsp__aurantiaca_strain_JD37_1114989-1116513_DIR+... at +/97
# rRNA_CP009290_Pseudomonas_chlororaphis_subsp__aurantiaca_strain_JD37_6578904-6580428_DIR-... at +/97
# rRNA_CP007039_Pseudomonas_cichorii_JBC1_5342972-5344498_DIR-... *
# rRNA_CP007039_Pseudomonas_cichorii_JBC1_735981-737507_DIR+... at +/100.00%
# rRNA_CP007039_Pseudomonas_cichorii_JBC1_2030176-2031702_DIR+... at +/100.00%
# rRNA_CP007039_Pseudomonas_cichorii_JBC1_1557599-1559125_DIR+... at +/99.93%
# rRNA_CP007039_Pseudomonas_cichorii_JBC1_921583-923109_DIR+... at +/100.00%
# rRNA_CP007039_Pseudomonas_cichorii_JBC1_5857992-5859518_DIR-... at +/100.00%
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_5002159-5003683_DIR-...
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_115499-117023_DIR+... at
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_1375553-1377077_DIR+...
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_696508-698032_DIR+... at
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_3799143-3800667_DIR-...
# rRNA_CT573326_Pseudomonas_entomophila_str__L48_chromosome_complete_sequence_2739321-2740845_DIR+...
# rRNA_CP003150_Pseudomonas_fluorescens_F113_165904-167428_DIR+... at +/97.38%
# rRNA_CP003150_Pseudomonas_fluorescens_F113_6153702-6155226_DIR-... at +/97.38%
# rRNA_CP003150_Pseudomonas_fluorescens_F113_2107401-2108925_DIR+... at +/97.38%
# rRNA_CP003150_Pseudomonas_fluorescens_F113_845030-846554_DIR+... at +/97.38%
# rRNA_CP003150_Pseudomonas_fluorescens_F113_5764934-5766458_DIR-... at +/97.38%
# rRNA_CP005960_Pseudomonas_mandelii_JR_1_1653022-1654547_DIR-... at +/98.10%
# rRNA_CP005960_Pseudomonas_mandelii_JR_1_4588939-4590465_DIR+... at +/98.10%
# rRNA_CP005960_Pseudomonas_mandelii_JR_1_3777762-3779287_DIR-... at +/98.10%
# rRNA_CP005960_Pseudomonas_mandelii_JR_1_6771750-6773275_DIR+... at +/98.10%
# rRNA_CP005960_Pseudomonas_mandelii_JR_1_4921953-4923478_DIR+... at +/98.10%
# rRNA_CP005960_Pseudomonas_mandelii_JR_1_3114938-3116463_DIR-... at +/98.10%
# rRNA_CP006979_Pseudomonas_monteilii_SB3101_4216726-4218250_DIR-... at +/97.18%
# rRNA_CP006979_Pseudomonas_monteilii_SB3101_121488-123012_DIR+... at +/97.18%
# rRNA_CP006979_Pseudomonas_monteilii_SB3101_5694782-5696306_DIR+... at +/97.18%
# rRNA_CP006979_Pseudomonas_monteilii_SB3101_1516466-1517990_DIR+... at +/97.18%
# rRNA_CP006979_Pseudomonas_monteilii_SB3101_293641-295165_DIR+... at +/97.18%
# rRNA_CP006979_Pseudomonas_monteilii_SB3101_4684656-4686180_DIR-... at +/97.18%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_3505512-3507036_DIR-... at +/97.18%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_5290892-5292416_DIR+... at +/97.05%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_4131287-4132811_DIR-... at +/97.18%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_5838052-5839576_DIR+... at +/97.18%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_2966352-2967876_DIR-... at +/97.18%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_5628577-5630101_DIR+... at +/97.18%
# rRNA_CP009365_Pseudomonas_mosselii_SJ10_4057776-4059300_DIR-... at +/97.18%
# rRNA_CP004045_Pseudomonas_poae_RE_1_1_14_1279292-1280816_DIR+... at +/97.18%
# rRNA_CP004045_Pseudomonas_poae_RE_1_1_14_4136719-4138243_DIR-... at +/97.18%
# rRNA_CP004045_Pseudomonas_poae_RE_1_1_14_5506895-5508419_DIR+... at +/97.18%
# rRNA_CP004045_Pseudomonas_poae_RE_1_1_14_4900297-4901821_DIR+... at +/97.11%
# rRNA_CP004045_Pseudomonas_poae_RE_1_1_14_3808311-3809835_DIR-... at +/97.18%
# rRNA_CP000076_Pseudomonas_protegens_Pf_5_122818-124344_DIR+... at +/97.25%
# rRNA_CP000076_Pseudomonas_protegens_Pf_5_6012600-6014126_DIR-... at +/97.25%
# rRNA_CP000076_Pseudomonas_protegens_Pf_5_6386420-6387946_DIR-... at +/97.25%
# rRNA_CP000076_Pseudomonas_protegens_Pf_5_854059-855585_DIR+... at +/97.25%
# rRNA_CP000076_Pseudomonas_protegens_Pf_5_4813648-4815174_DIR-... at +/97.18%
# rRNA_CP000712_Pseudomonas_putida_F1_3913247-3914771_DIR-... at +/97.11%
# rRNA_CP000712_Pseudomonas_putida_F1_185131-186655_DIR+... at +/97.11%
# rRNA_CP000712_Pseudomonas_putida_F1_1342820-1344344_DIR+... at +/97.05%
# rRNA_CP000712_Pseudomonas_putida_F1_717173-718697_DIR+... at +/97.11%
# rRNA_CP000712_Pseudomonas_putida_F1_539844-541368_DIR+... at +/97.11%
# rRNA_CP000712_Pseudomonas_putida_F1_5074873-5076397_DIR-... at +/97.05%
# rRNA_CP000058_Pseudomonas_syringae_pv__phaseolicola_1448A_804008-805534_DIR+... at +/98.43%
# rRNA_CP000058_Pseudomonas_syringae_pv__phaseolicola_1448A_5250702-5252228_DIR-... at +/98.43%
# rRNA_CP000058_Pseudomonas_syringae_pv__phaseolicola_1448A_5782831-5784357_DIR-... at +/98.43%
# rRNA_CP000058_Pseudomonas_syringae_pv__phaseolicola_1448A_1048743-1050269_DIR+... at +/98.43%
# rRNA_CP000058_Pseudomonas_syringae_pv__phaseolicola_1448A_3635161-3636687_DIR-... at +/98.43%
# rRNA_CP000075_Pseudomonas_syringae_pv__syringae_B728a_772102-773628_DIR+... at +/98.30%
# rRNA_CP000075_Pseudomonas_syringae_pv__syringae_B728a_5426732-5428258_DIR-... at +/98.23%
# rRNA_CP000075_Pseudomonas_syringae_pv__syringae_B728a_5951654-5953180_DIR-... at +/98.23%
# rRNA_CP000075_Pseudomonas_syringae_pv__syringae_B728a_964692-966218_DIR+... at +/98.30%
# rRNA_CP000075_Pseudomonas_syringae_pv__syringae_B728a_3851145-3852671_DIR-... at +/98.30%
# rRNA_AE016853_Pseudomonas_syringae_pv__tomato_str__DC3000_666734-668260_DIR+... at +/97.58%
# rRNA_AE016853_Pseudomonas_syringae_pv__tomato_str__DC3000_6217620-6219146_DIR-... at +/97.58%
# rRNA_AE016853_Pseudomonas_syringae_pv__tomato_str__DC3000_1072085-1073611_DIR+... at +/97.58%
# rRNA_AE016853_Pseudomonas_syringae_pv__tomato_str__DC3000_827548-829074_DIR+... at +/97.58%
# rRNA_AE016853_Pseudomonas_syringae_pv__tomato_str__DC3000_3873149-3874675_DIR-... at +/97.58%
# Cluster: 828
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Rhizobiaceae:Rhizobium:uncultured_bacterium:
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Rhizobiaceae:Ensifer:Sinorhizobium:Unclassif
# rRNA_AE007869_Agrobacterium_tumefaciens_str__C58_circular_chromosome__complete_seq_56749-58221_DIR+.
# rRNA_AE007870_Agrobacterium_tumefaciens_str__C58_linear_chromosome__complete_seque_1304317-1305789_D
# rRNA_AE007870_Agrobacterium_tumefaciens_str__C58_linear_chromosome__complete_seque_1041820-1043292_D
# rRNA_AE007869_Agrobacterium_tumefaciens_str__C58_circular_chromosome__complete_seq_2517149-2518621_D
# Cluster: 586
# Bacteria:Actinobacteria:Micrococcales:Microbacteriaceae:Microbacterium:Unclassified:Unclassified:Unc
# rRNA_AP012052_Microbacterium_testaceum_StLB037_DNA_2360815-2362324_DIR+... *
# rRNA_AP012052_Microbacterium_testaceum_StLB037_DNA_5067-6576_DIR-... at +/99.93%
# Cluster: 587
# Bacteria:Bacteroidetes:Sphingobacteriia:Sphingobacteriales:Sphingobacteriaceae:Pedobacter:uncultured
# rRNA_CP001681_Pedobacter_heparinus_DSM_2366_1368500-1370009_DIR+... *
# rRNA_CP001681_Pedobacter_heparinus_DSM_2366_4298721-4300230_DIR-... at +/100.00%
# rRNA_CP001681_Pedobacter_heparinus_DSM_2366_4306042-4307551_DIR-... at +/100.00%
# Cluster: 585
# Bacteria:Actinobacteria:Micrococcales:Intrasporangiaceae:Unclassified:Unclassified:Unclassified:Uncl
# rRNA_CP002343_Intrasporangium_calvum_DSM_43043_1359051-1360560_DIR+... *
# rRNA_CP002343_Intrasporangium_calvum_DSM_43043_1760237-1761746_DIR+... at +/99.93%
# Cluster: 443
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:uncultured:uncultured_bact
# rRNA_CP000884_Delftia_acidovorans_SPH_1_723807-725327_DIR+... *
# rRNA_CP000884_Delftia_acidovorans_SPH_1_6692893-6694413_DIR-... at +/100.00%
# rRNA_CP000884_Delftia_acidovorans_SPH_1_2776169-2777689_DIR+... at +/100.00%
# rRNA_CP000884_Delftia_acidovorans_SPH_1_729453-730973_DIR+... at +/100.00%
# rRNA_CP000884_Delftia_acidovorans_SPH_1_6687247-6688767_DIR-... at +/100.00%
# Cluster: 442
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:Unclassified:Unclassified:
# rRNA_CP006704_Comamonas_testosteroni_TK102_1457919-1459439_DIR+... *
# rRNA_CP006704_Comamonas_testosteroni_TK102_552885-554405_DIR+... at +/99.93%
# rRNA_CP006704_Comamonas_testosteroni_TK102_5757544-5759064_DIR-... at +/99.93%
# rRNA_CP006704_Comamonas_testosteroni_TK102_5746092-5747612_DIR-... at +/99.93%
# rRNA_CP006704_Comamonas_testosteroni_TK102_547158-548678_DIR+... at +/99.93%
# rRNA_CP006704_Comamonas_testosteroni_TK102_5751818-5753338_DIR-... at +/99.93%
# rRNA_CP006704_Comamonas_testosteroni_TK102_558611-560131_DIR+... at +/99.93%
# rRNA_CP006704_Comamonas_testosteroni_TK102_541432-542952_DIR+... at +/99.87%
# rRNA_CP006704_Comamonas_testosteroni_TK102_1452192-1453712_DIR+... at +/99.87%
# Cluster: 441
# Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Cellulosilyticum:uncultured_organism:Un
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_151628-153148_DIR+... *
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_3624239-3625752_DIR-... at +/98.75%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_76847-78359_DIR+... at +/97.55%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_422560-424073_DIR+... at +/98.35%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_602287-603800_DIR+... at +/98.94%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_46244-47755_DIR+... at +/98.41%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_571993-573507_DIR+... at +/97.43%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_84401-85917_DIR+... at +/97.69%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_10458-11969_DIR+... at +/98.02%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_1229193-1230706_DIR+... at +/97.95%
# rRNA_CP002582_Clostridium_lentocellum_DSM_5427_141508-143021_DIR+... at +/99.93%
# Cluster: 380
# Bacteria:Proteobacteria:Betaproteobacteria:Unclassified:Unclassified:Unclassified:Unclassified:Uncla
# rRNA_CP002056_Methylotenera_versatilis_301_127113-128638_DIR+... *
# rRNA_CP002056_Methylotenera_versatilis_301_726526-728051_DIR+... at +/100.00%
# rRNA_CP002056_Methylotenera_versatilis_301_133281-134806_DIR+... at +/100.00%
# Cluster: 381
# Bacteria:Proteobacteria:Deltaproteobacteria:Myxococcales:Cystobacterineae:Myxococcaceae:Myxococcus:M
# Bacteria:Proteobacteria:Deltaproteobacteria:Myxococcales:Cystobacterineae:Myxococcaceae:Unclassified
# rRNA_CP003389_Corallococcus_coralloides_DSM_2259_128437-129960_DIR+... at +/97.83%
# rRNA_CP003389_Corallococcus_coralloides_DSM_2259_9896798-9898322_DIR-... at +/97.84%
# rRNA_CP003389_Corallococcus_coralloides_DSM_2259_3335495-3337018_DIR+... at +/97.97%
# ...
# rRNA_CP001111_Stenotrophomonas_maltophilia_R551_3_4511457-4512991_DIR-... at +/99.93%
# rRNA_CP001111_Stenotrophomonas_maltophilia_R551_3_358704-360238_DIR+... at +/100.00%
# rRNA_CP004399_Xanthomonas_axonopodis_Xac29_1_5048970-5050504_DIR-... at +/97.07%
# rRNA_CP004399_Xanthomonas_axonopodis_Xac29_1_4587171-4588705_DIR-... at +/97.07%
# rRNA_AE008923_Xanthomonas_axonopodis_pv__citri_str__306_5069302-5070836_DIR-... at +/97.07%
# rRNA_AE008923_Xanthomonas_axonopodis_pv__citri_str__306_4580060-4581594_DIR-... at +/97.07%
# rRNA_CP002914_Xanthomonas_axonopodis_pv__citrumelo_F1_4846024-4847558_DIR-... at +/97.13%
# rRNA_CP002914_Xanthomonas_axonopodis_pv__citrumelo_F1_4382879-4384413_DIR-... at +/97.13%
# rRNA_CP002789_Xanthomonas_campestris_pv__raphani_756C_480035-481569_DIR+... at +/97.13%
# rRNA_CP002789_Xanthomonas_campestris_pv__raphani_756C_4814368-4815902_DIR-... at +/97.13%
# rRNA_AM039952_Xanthomonas_campestris_pv__vesicatoria_5058746-5060280_DIR-... at +/97.13%
# rRNA_AM039952_Xanthomonas_campestris_pv__vesicatoria_4604567-4606101_DIR-... at +/97.13%
# rRNA_CP000967_Xanthomonas_oryzae_pv__oryzae_PXO99A_5086803-5088337_DIR-... at +/97.07%
# rRNA_CP000967_Xanthomonas_oryzae_pv__oryzae_PXO99A_4861404-4862938_DIR-... at +/97.07%
# Cluster: 233
# Bacteria:Proteobacteria:Deltaproteobacteria:Myxococcales:Cystobacterineae:Unclassified:Unclassified:
# rRNA_CP002271_Stigmatella_aurantiaca_DW4_3_1_575190-576724_DIR+... *
# rRNA_CP002271_Stigmatella_aurantiaca_DW4_3_1_6869294-6870828_DIR-... at +/99.93%
# Cluster: 874
# Bacteria:Proteobacteria:Alphaproteobacteria:Caulobacterales:Caulobacteraceae:Brevundimonas:unculture
# rRNA_CP002102_Brevundimonas_subvibrioides_ATCC_15264_2980512-2981960_DIR-... *
# rRNA_CP002102_Brevundimonas_subvibrioides_ATCC_15264_2754224-2755672_DIR-... at +/100.00%
# Cluster: 871
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhodobacterales:Rhodobacteraceae:Unclassified:Unclassifi
# rRNA_CP006650_Paracoccus_aminophilus_JCM_7686_69111-70561_DIR+... *
# rRNA_CP006650_Paracoccus_aminophilus_JCM_7686_2914359-2915809_DIR-... at +/100.00%
# rRNA_CP006650_Paracoccus_aminophilus_JCM_7686_156329-157779_DIR+... at +/100.00%
# rRNA_CP000490_Paracoccus_denitrificans_PD1222_chromosome_2__complete_sequence_141988-143438_DIR+...
# rRNA_CP000489_Paracoccus_denitrificans_PD1222_chromosome_1__complete_sequence_1978375-1979825_DIR-..
# rRNA_CP000489_Paracoccus_denitrificans_PD1222_chromosome_1__complete_sequence_58447-59897_DIR+... at
# Cluster: 638
# Bacteria:Actinobacteria:Corynebacteriales:Nocardiaceae:Rhodococcus:Unclassified:Unclassified:Unclass
# Bacteria:Actinobacteria:Corynebacteriales:Nocardiaceae:Rhodococcus:Unclassified:Unclassified:Unclass
# rRNA_AP008957_Rhodococcus_erythropolis_PR4_DNA_572200-573705_DIR+... *
# rRNA_AP008957_Rhodococcus_erythropolis_PR4_DNA_4279564-4281069_DIR-... at +/100.00%
# rRNA_AP008957_Rhodococcus_erythropolis_PR4_DNA_4470268-4471773_DIR-... at +/100.00%
# rRNA_AP008957_Rhodococcus_erythropolis_PR4_DNA_590246-591751_DIR+... at +/100.00%
# rRNA_AP008957_Rhodococcus_erythropolis_PR4_DNA_3549708-3551213_DIR-... at +/100.00%
# Cluster: 471
# Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Comamonadaceae:uncultured:uncultured_bact
# rRNA_CP000555_Methylibium_petroleiphilum_PM1_352308-353826_DIR+... *
# Cluster: 675
# Bacteria:Bacteroidetes:Flavobacteria:Flavobacteriales:Flavobacteriaceae:Flavobacterium:uncultured_ba
# Bacteria:Bacteroidetes:Flavobacteria:Flavobacteriales:Flavobacteriaceae:Flavobacterium:Unclassified:
# rRNA_CP000685_Flavobacterium_johnsoniae_UW101_27889-29390_DIR-... *
# rRNA_CP000685_Flavobacterium_johnsoniae_UW101_2304230-2305731_DIR+... at +/99.87%
# rRNA_CP000685_Flavobacterium_johnsoniae_UW101_5122307-5123808_DIR-... at +/99.87%
# rRNA_CP000685_Flavobacterium_johnsoniae_UW101_3263832-3265333_DIR+... at +/99.87%
# rRNA_CP000685_Flavobacterium_johnsoniae_UW101_2544899-2546400_DIR+... at +/99.87%
# rRNA_CP000685_Flavobacterium_johnsoniae_UW101_504229-505730_DIR-... at +/99.73%
# Cluster: 144
# Bacteria:Firmicutes:Bacilli:Bacillales:Paenibacillaceae:Paenibacillus:Unclassified:Unclassified
# rRNA_CP004078_Paenibacillus_sabinae_T27_4734994-4736538_DIR-... *
# rRNA_CP004078_Paenibacillus_sabinae_T27_128776-130318_DIR+... at +/98.57%
# rRNA_CP004078_Paenibacillus_sabinae_T27_4664719-4666262_DIR-... at +/98.70%
# rRNA_CP004078_Paenibacillus_sabinae_T27_3961582-3963124_DIR-... at +/99.42%
# rRNA_CP004078_Paenibacillus_sabinae_T27_78678-80220_DIR+... at +/98.51%
# rRNA_CP004078_Paenibacillus_sabinae_T27_4493284-4494828_DIR-... at +/99.61%
# rRNA_CP004078_Paenibacillus_sabinae_T27_658837-660380_DIR+... at +/98.77%
# rRNA_CP004078_Paenibacillus_sabinae_T27_12008-13552_DIR+... at +/98.96%
# rRNA_CP004078_Paenibacillus_sabinae_T27_974132-975674_DIR+... at +/98.51%
# Cluster: 771
# Bacteria:Cyanobacteria:SubsectionIII:FamilyI:Microcoleus:Unclassified:Unclassified:Unclassified
# rRNA_CP003614_Oscillatoria_nigro_viridis_PCC_7112_566533-568020_DIR+... *
# rRNA_CP003614_Oscillatoria_nigro_viridis_PCC_7112_4288160-4289647_DIR-... at +/100.00%
# Cluster: 616
# Bacteria:Bacteroidetes:Sphingobacteriia:Sphingobacteriales:Sphingobacteriaceae:Solitalea:uncultured_
# rRNA_CP003349_Solitalea_canadensis_DSM_3403_7707-9214_DIR+... *
# rRNA_CP003349_Solitalea_canadensis_DSM_3403_1464128-1465635_DIR+... at +/100.00%
# rRNA_CP003349_Solitalea_canadensis_DSM_3403_736595-738102_DIR+... at +/100.00%
# rRNA_CP003349_Solitalea_canadensis_DSM_3403_38623-40130_DIR+... at +/100.00%
# Cluster: 614
# Bacteria:Actinobacteria:Pseudonocardiales:Pseudonocardiaceae:Pseudonocardia:uncultured_bacterium:Unc
# rRNA_CP002593_Pseudonocardia_dioxanivorans_CB1190_577609-579116_DIR+... *
# rRNA_CP002593_Pseudonocardia_dioxanivorans_CB1190_4088454-4089961_DIR-... at +/100.00%
# rRNA_CP002593_Pseudonocardia_dioxanivorans_CB1190_5160377-5161884_DIR-... at +/100.00%
# Cluster: 149
# Bacteria:Proteobacteria:Deltaproteobacteria:Desulfuromonadales:Geobacteraceae:Geobacter:uncultured_b
# rRNA_CP000148_Geobacter_metallireducens_GS_15_1310044-1311587_DIR+... *
# rRNA_CP000148_Geobacter_metallireducens_GS_15_3244516-3246059_DIR-... at +/100.00%
# Cluster: 487
# Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Oscillibacter:uncultured_Oscillospirace
# rRNA_AP012044_Oscillibacter_valericigenes_Sjm18_20_DNA_420895-422412_DIR+... *
# rRNA_AP012044_Oscillibacter_valericigenes_Sjm18_20_DNA_1864527-1866044_DIR+... at +/100.00%
# rRNA_AP012044_Oscillibacter_valericigenes_Sjm18_20_DNA_1260699-1262216_DIR+... at +/100.00%
# Cluster: 836
# Bacteria:Proteobacteria:Alphaproteobacteria:Rhizobiales:Xanthobacteraceae:Unclassified:Unclassified:
# rRNA_CP002026_Starkeya_novella_DSM_506_3442778-3444250_DIR-... *
# Cluster: 478
# Bacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Unclassified:Unclassified:Un
# Bacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Kitasatospora:Unclassified:Unclassified:U
# rRNA_BA000030_Streptomyces_avermitilis_MA_4680___NBRC_14893_DNA_3077215-3078728_DIR-... at +/98.02%
# rRNA_BA000030_Streptomyces_avermitilis_MA_4680___NBRC_14893_DNA_5759351-5760864_DIR+... at +/98.02%
# rRNA_BA000030_Streptomyces_avermitilis_MA_4680___NBRC_14893_DNA_8328605-8330118_DIR+... at +/98.02%
# rRNA_BA000030_Streptomyces_avermitilis_MA_4680___NBRC_14893_DNA_7765522-7767035_DIR+... at +/98.02%
# rRNA_BA000030_Streptomyces_avermitilis_MA_4680___NBRC_14893_DNA_6124395-6125908_DIR+... at +/98.02%
# rRNA_BA000030_Streptomyces_avermitilis_MA_4680___NBRC_14893_DNA_5027755-5029268_DIR-... at +/98.02%
# rRNA_CP005080_Streptomyces_fulvissimus_DSM_40593_1042653-1044166_DIR-... at +/99.80%
# rRNA_CP005080_Streptomyces_fulvissimus_DSM_40593_4355830-4357343_DIR+... at +/99.80%
# rRNA_CP005080_Streptomyces_fulvissimus_DSM_40593_2971569-2973082_DIR-... at +/99.80%
# rRNA_CP005080_Streptomyces_fulvissimus_DSM_40593_3423347-3424860_DIR-... at +/99.80%
# rRNA_CP005080_Streptomyces_fulvissimus_DSM_40593_6254343-6255856_DIR+... at +/99.80%
# rRNA_CP005080_Streptomyces_fulvissimus_DSM_40593_1541996-1543509_DIR-... at +/99.80%
# rRNA_AP009493_Streptomyces_griseus_subsp__griseus_NBRC_13350_DNA_2102307-2103820_DIR-... at +/99.80%
# rRNA_AP009493_Streptomyces_griseus_subsp__griseus_NBRC_13350_DNA_4592155-4593668_DIR+... at +/99.80%
# rRNA_AP009493_Streptomyces_griseus_subsp__griseus_NBRC_13350_DNA_6683065-6684578_DIR+... at +/99.80%
# rRNA_AP009493_Streptomyces_griseus_subsp__griseus_NBRC_13350_DNA_5288085-5289598_DIR+... at +/99.80%
# rRNA_AP009493_Streptomyces_griseus_subsp__griseus_NBRC_13350_DNA_4842381-4843894_DIR+... at +/99.80%
# rRNA_AP009493_Streptomyces_griseus_subsp__griseus_NBRC_13350_DNA_7243314-7244827_DIR+... at +/99.80%
# rRNA_CP003275_Streptomyces_hygroscopicus_subsp__jinggangensis_5008_3321915-3323428_DIR-... at +/97.5
# rRNA_CP003275_Streptomyces_hygroscopicus_subsp__jinggangensis_5008_6383574-6385087_DIR+... at +/97.4
# rRNA_CP003275_Streptomyces_hygroscopicus_subsp__jinggangensis_5008_5169935-5171448_DIR-... at +/97.4
# rRNA_CP003275_Streptomyces_hygroscopicus_subsp__jinggangensis_5008_5685744-5687257_DIR-... at +/97.4
# rRNA_CP003275_Streptomyces_hygroscopicus_subsp__jinggangensis_5008_7774429-7775942_DIR+... at +/97.4
# rRNA_CP003275_Streptomyces_hygroscopicus_subsp__jinggangensis_5008_3797027-3798540_DIR-... at +/97.5
# rRNA_CP002475_Streptomyces_pratensis_ATCC_33331_1964777-1966290_DIR-... at +/99.93%
# rRNA_CP002475_Streptomyces_pratensis_ATCC_33331_4085105-4086618_DIR+... at +/99.93%
# rRNA_CP002475_Streptomyces_pratensis_ATCC_33331_6290327-6291840_DIR+... at +/99.93%
# rRNA_CP002475_Streptomyces_pratensis_ATCC_33331_5778352-5779865_DIR+... at +/99.87%
# rRNA_CP002475_Streptomyces_pratensis_ATCC_33331_4476406-4477924_DIR+... *
# rRNA_CP002475_Streptomyces_pratensis_ATCC_33331_3410739-3412252_DIR-... at +/99.93%
# rRNA_FN554889_Streptomyces_scabiei_87_22_2859189-2860700_DIR-... at +/97.02%
# rRNA_FN554889_Streptomyces_scabiei_87_22_5487038-5488551_DIR+... at +/97.09%
# rRNA_FN554889_Streptomyces_scabiei_87_22_8426445-8427958_DIR+... at +/97.09%
# rRNA_FN554889_Streptomyces_scabiei_87_22_7917815-7919328_DIR+... at +/97.09%
# rRNA_FN554889_Streptomyces_scabiei_87_22_6141556-6143069_DIR+... at +/97.09%
# rRNA_FN554889_Streptomyces_scabiei_87_22_4403297-4404810_DIR-... at +/97.09%
# rRNA_CP002994_Streptomyces_violaceusniger_Tu_4113_373994-375508_DIR+... at +/97.03%
# rRNA_CP002994_Streptomyces_violaceusniger_Tu_4113_2020050-2021564_DIR+... at +/97.03%
# Cluster: 481
# Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Incertae_Sedis:Unclassified:Unclassifie
# rRNA_CP002109_Clostridium_saccharolyticum_WM1_3681375-3682893_DIR-... *
# rRNA_CP002109_Clostridium_saccharolyticum_WM1_18567-20085_DIR+... at +/99.67%
# rRNA_CP002109_Clostridium_saccharolyticum_WM1_704325-705843_DIR+... at +/99.67%
# rRNA_CP002109_Clostridium_saccharolyticum_WM1_397549-399067_DIR+... at +/99.74%
# rRNA_CP002109_Clostridium_saccharolyticum_WM1_196661-198179_DIR+... at +/99.74%
# rRNA_CP002109_Clostridium_saccharolyticum_WM1_795041-796559_DIR+... at +/99.67%
# Cluster: 681
# Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:uncultured_bacterium:Unclass
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_2254710-2256209_DIR+... at +/98.53%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_5748917-5750416_DIR-... at +/98.60%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_446133-447632_DIR+... at +/98.67%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_2266365-2267864_DIR+... at +/98.73%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_5772147-5773646_DIR-... at +/98.47%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_142453-143952_DIR+... at +/98.47%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_5739864-5741363_DIR-... at +/98.53%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_3402721-3404220_DIR-... at +/98.67%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_5929877-5931376_DIR-... at +/98.73%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_924919-926418_DIR+... at +/98.67%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_9623-11122_DIR+... at +/98.47%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_5766210-5767709_DIR-... at +/98.67%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_4546433-4547932_DIR-... at +/98.47%
# rRNA_CP006777_Clostridium_beijerinckii_ATCC_35702_2031250-2032749_DIR+... at +/98.40%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_5049451-5050951_DIR-... *
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_4902275-4903775_DIR-... at +/99.80%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_473730-475230_DIR+... at +/99.87%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_5043345-5044845_DIR-... at +/100.00%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_4928069-4929569_DIR-... at +/100.00%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_168690-170190_DIR+... at +/99.87%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_4894153-4895653_DIR-... at +/99.67%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_5037619-5039119_DIR-... at +/100.00%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_1140029-1141529_DIR+... at +/99.60%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_9515-11015_DIR+... at +/99.87%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_4911371-4912871_DIR-... at +/100.00%
# rRNA_CP006721_Clostridium_saccharobutylicum_DSM_13864_2089597-2091097_DIR+... at +/99.80%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_6252854-6254354_DIR-... at +/98.80%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_5788910-5790410_DIR-... at +/98.80%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_560682-562182_DIR+... at +/98.93%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_6236066-6237566_DIR-... at +/98.80%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_5763217-5764717_DIR-... at +/98.87%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_149180-150680_DIR+... at +/98.87%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_6226852-6228352_DIR-... at +/98.80%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_802658-804158_DIR+... at +/98.87%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_9446-10946_DIR+... at +/98.73%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_4257786-4259286_DIR-... at +/98.60%
# rRNA_CP004121_Clostridium_saccharoperbutylacetonicum_N1_4_HMT_6437713-6439213_DIR-... at +/98.87%
# Cluster: 808
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Sphingopyxis:Unclassi
# rRNA_CP000356_Sphingopyxis_alaskensis_RB2256_2851573-2853049_DIR-... *
# Cluster: 687
# Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Alkaliphilus:Unclassified:Unclassified
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_2608522-2610021_DIR-... *
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_63174-64673_DIR+... at +/99.93%
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_2601979-2603478_DIR-... at +/99.93%
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_49919-51418_DIR+... at +/99.93%
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_1927901-1929400_DIR-... at +/99.93%
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_507715-509214_DIR+... at +/99.93%
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_11368-12867_DIR+... at +/99.93%
# rRNA_CP000853_Alkaliphilus_oremlandii_OhILAs_2615936-2617435_DIR-... at +/99.93%
# Cluster: 807
# Bacteria:Proteobacteria:Alphaproteobacteria:Sphingomonadales:Sphingomonadaceae:Novosphingobium:Uncla
# rRNA_CP009291_Novosphingobium_pentaromativorans_US6_1_2516124-2517600_DIR+... *
# rRNA_CP009291_Novosphingobium_pentaromativorans_US6_1_1254654-1256130_DIR-... at +/100.00%
# rRNA_CP009291_Novosphingobium_pentaromativorans_US6_1_2263898-2265374_DIR-... at +/100.00%
# Cluster: 806
# Bacteria:Cyanobacteria:SubsectionIV:FamilyI:Nostoc:Unclassified:Unclassified:Unclassified
# rRNA_CP001037_Nostoc_punctiforme_PCC_73102_2021496-2022972_DIR+... *
# rRNA_CP001037_Nostoc_punctiforme_PCC_73102_5515634-5517110_DIR-... at +/100.00%
# rRNA_CP001037_Nostoc_punctiforme_PCC_73102_6502978-6504454_DIR-... at +/99.86%
# rRNA_CP001037_Nostoc_punctiforme_PCC_73102_6085177-6086653_DIR+... at +/100.00%

# %% [markdown]
# __Notes:__
#
# * At least most of the taxonomic classifications make sense for the genomes in each cluster

# %% [markdown]
# ### Writing out a list of target genomes and their corresponding OTUs

# %%
def write_targets(tbl, fh):
    fh.write('\t'.join(['cluster', 'ssu_ID', 'target_genome', 'OTU', 'OTU_taxonomy']) + '\n')
    for clstr,x in tbl.items():
        # parsing cluster
        targets = []
        otus = []
        for y in x:
            ID = y[2].lstrip('>')
            ID = re.sub('\.\.\..+','', ID)        
            if ID.startswith('OTU'):
                otu = [ID, ':'.join(y[3])]
                otus.append(otu)
            elif ID.startswith('rRNA'):
                targets.append(ID)
        # writing out list
        for target in targets:
            for otu in otus:
                genome = target.lstrip('rRNA_')
                genome = re.sub('_\d+-\d+_DIR.+', '', genome)
                fh.write('\t'.join([clstr, target, genome] + otu) + '\n')

# %%
outFile = os.path.join(workDir, 'target_taxa.txt')
with open(outFile, 'wb') as oFH:
    write_targets(tbl_f, oFH)

# %% [markdown]
# #### Number of target genomes

# %%
# !printf "Number of target genomes: "
# !cd $workDir; \
    tail -n +2 target_taxa.txt | cut -f 3 | sort -u | wc -l
# Out:
# Number of target genomes: 329

# %% [markdown]
# ### Get genome files with associated genome sequence names

# %%
# making table of genome file names & genome sequence IDs
p = os.path.join(genomeDir, '*.fasta')
genomeFiles = glob.glob(p)

assert len(genomeFiles) == 1210, 'There should be 1210 genome files'

# %%
fileSeq = {}
cnt = 0
for f in genomeFiles:
    fileSeq[f] = []
    with open(f, 'rb') as iFH:
        for line in iFH:
            if line.startswith('>'):
                line = line.lstrip('>').rstrip()
                fileSeq[f].append(line)
    cnt += 1
    if cnt % 100 == 0:
        sys.stderr.write('Number of files processed: {}\n'.format(cnt))
# Out:
# Number of files processed: 100
# Number of files processed: 200
# Number of files processed: 300
# Number of files processed: 400
# Number of files processed: 500
# Number of files processed: 600
# Number of files processed: 700
# Number of files processed: 800
# Number of files processed: 900
# Number of files processed: 1000
# Number of files processed: 1100
# Number of files processed: 1200

# %%
printDict(fileSeq, n=5)
# Out:
# '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Rhizobium_etli_bv_phaseoli_str_IE4803.fasta'
# ['CP007641_Rhizobium_etli_bv__phaseoli_str__IE4803']
# '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Prosthecochloris_aestuarii_DSM_271.fasta'
# ['CP001108_Prosthecochloris_aestuarii_DSM_271']
# '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Phaeobacter_inhibens_DSM_17395.fasta'
# ['CP002976_Phaeobacter_inhibens_DSM_17395']
# '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Paludibacter_propionicigenes_WB4.fasta'
# ['CP002345_Paludibacter_propionicigenes_WB4']
# '/home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Thermodesulfobacterium_geofontis_OPF15.fasta'
# ['CP002829_Thermodesulfobacterium_geofontis_OPF15']

# %%
outFile = os.path.join(workDir, 'genomeFile_seqID.txt')

with open(outFile, 'wb') as oFH:
    for f,seqIDs in fileSeq.items():
        for seqID in seqIDs:
            line = '\t'.join([seqID, f])
            oFH.write(line + '\n')

# %% [markdown]
# ### Filtering genome file list by target genomes

# %%
# %%bash -s "$workDir"
# cd $1
#
# grep -f <(tail -n +2 target_taxa.txt| cut -f 3) genomeFile_seqID.txt > genomeFile_seqID_filt.txt
#
# wc -l genomeFile_seqID_filt.txt
# Out:
# 329 genomeFile_seqID_filt.txt

# %% [markdown]
# ### symlinking genome files (& associated files)

# %%
newGenomeDir = os.path.join(workDir, '../genomes')

if not os.path.isdir(newGenomeDir):
    os.makedirs(newGenomeDir)

# %%
inFile = os.path.join(workDir, 'genomeFile_seqID_filt.txt')

exts = ['.fasta','.fasta.2bit','.fasta.flat','.fasta.gdx','.fasta.sqlite3.db','.fasta.uni']

with open(inFile, 'rb') as iFH:
    for line in iFH:        
        seqID,fastaFile = line.rstrip().split('\t')
        assert os.path.isfile(fastaFile), '"{}" not found'.format(fastaFile)
        
        base,ext = os.path.splitext(fastaFile)
        path,fileBase = os.path.split(base)
        newBase = os.path.join(newGenomeDir, fileBase)

        for x in exts:
            if not os.path.islink(newBase + x):
                os.symlink(base + '.fasta', newBase + x)

# %%
# !printf "Number of fasta files in genomes dir: "
# !cd $newGenomeDir; \
    ls *fasta | wc -l
# Out:
# Number of fasta files in genomes dir: 306

# %% [markdown]
# #### Notes:
#
# * Number of genome files is < number of taxa in genomeFile_seqID_filt.txt because:
#   * each taxon name can correspond to 1 of multiple chromosomes in the taxon file
#
# * All genomes files set
# * TODO:
#   * Create simulation of community

# %% [markdown]
# ## Making a table of genome (taxon) relative abundances
#
# * Will be used for community simulation

# %%
taxonMapFile = os.path.join(workDir, 'target_taxa.txt')
genomeFilterFile = os.path.join(workDir, 'genomeFile_seqID_filt.txt')
abundFile = os.path.join(workDir, '../exp_info', 'bulk_OTU_abund_stats.txt')

# %%
# %%R -i taxonMapFile -i abundFile -i genomeFilterFile
#
# taxonMap = read.delim(taxonMapFile, sep='\t') %>%
#     select(target_genome, OTU)
# taxonMap %>% nrow %>% print
# taxonMap %>% head(n=3) %>% print
#
# message('----------------')
#
# genomeFilter = read.delim(genomeFilterFile, sep='\t', header=F)
# genomeFilter %>% nrow %>% print
# genomeFilter %>% head(n=3) %>% print
#
# message('----------------')
#
# abund = read.delim(abundFile, sep='\t')
# abund %>% nrow %>% print
# abund %>% head(n=3) %>% print
# Out:
# [1] 1817
#                                   target_genome      OTU
# 1      CP003093_Pseudoxanthomonas_spadix_BD_a59   OTU.77
# 2 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.2347
# 3 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.1364
# ----------------
# [1] 329
#                                                        V1
# 1        CP007641_Rhizobium_etli_bv__phaseoli_str__IE4803
# 2                CP003093_Pseudoxanthomonas_spadix_BD_a59
# 3 CP001918_Enterobacter_cloacae_subsp__cloacae_ATCC_13047
#                                                                                                          V2
# 1         /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Rhizobium_etli_bv_phaseoli_str_IE4803.fasta
# 2               /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Pseudoxanthomonas_spadix_BD-a59.fasta
# 3 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Enterobacter_cloacae_subsp_cloacae_ATCC_13047.fasta
# ----------------
# [1] 5695
#     OTUId total_count  mean_count median_count   sd_count
# 1   OTU.1        2084 160.3076923           87 166.997198
# 2  OTU.10          11   0.8461538            0   1.344504
# 3 OTU.100         608  46.7692308           28  52.800180

# %%
# %%R
#
# tbl.j = inner_join(taxonMap, genomeFilter, c('target_genome' = 'V1'))
# tbl.j %>% nrow %>% print
# tbl.j %>% head
# Out:
# [1] 1638
#                                   target_genome      OTU
# 1      CP003093_Pseudoxanthomonas_spadix_BD_a59   OTU.77
# 2 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.2347
# 3 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.1364
# 4 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.3475
# 5 CP002162_Micromonospora_aurantiaca_ATCC_27029  OTU.388
# 6 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.1147
#                                                                                                 V2
# 1      /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Pseudoxanthomonas_spadix_BD-a59.fasta
# 2 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 3 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 4 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 5 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 6 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta

# %%
# %%R
#
# tbl.j2 = inner_join(tbl.j, abund, c('OTU' = 'OTUId'))
# tbl.j2 %>% nrow %>% print
# tbl.j2 %>% head
# Out:
# [1] 1638
#                                   target_genome      OTU
# 1      CP003093_Pseudoxanthomonas_spadix_BD_a59   OTU.77
# 2 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.2347
# 3 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.1364
# 4 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.3475
# 5 CP002162_Micromonospora_aurantiaca_ATCC_27029  OTU.388
# 6 CP002162_Micromonospora_aurantiaca_ATCC_27029 OTU.1147
#                                                                                                 V2
# 1      /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Pseudoxanthomonas_spadix_BD-a59.fasta
# 2 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 3 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 4 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 5 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
# 6 /home/nick/notebook/SIPSim/dev/bac_genome1210/genomes/Micromonospora_aurantiaca_ATCC_27029.fasta
#   total_count mean_count median_count sd_count
# 1          40  3.0769231            1 3.546396
# 2          36  2.7692308            2 2.650593
# 3          19  1.4615385            1 1.941451
# 4           7  0.5384615            0 1.126601
# 5          61  4.6923077            2 7.398025
# 6          36  2.7692308            2 3.166329

# %%
# %%R -i workDir
# outFile = paste(c(workDir, 'taxa_bulk-comm_abunds.txt'), collapse='/')
# write.table(tbl.j2, outFile, sep='\t', quote=F, row.names=F)

# %% [markdown]
# #### Notes
#
# * __USING this file for community simulation__
#   * associating OTUs with genome files & abundances

# %% [markdown]
# ### Creating a genome-file index

# %%
# !cd $workDir; \
    tail -n +2 taxa_bulk-comm_abunds.txt | cut -f 2,3 > ../genomes/genome_index_bulkSoil_OTU.txt
